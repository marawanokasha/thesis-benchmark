# %%
import json
import nltk
from nltk.tokenize import RegexpTokenizer
import string
import math
import os
import time
from collections import namedtuple
import cPickle as pickle
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import random

from multiprocessing.dummy import Pool as ThreadPool
import itertools

from sklearn.metrics import coverage_error
import sklearn.metrics
from sklearn.multiclass import OneVsRestClassifier
from sklearn import linear_model
from sklearn.preprocessing import MultiLabelBinarizer

from gensim.models.doc2vec import Doc2Vec, LabeledSentence

import logging
from logging import info
from functools import partial

from thesis.utils.metrics import *

# %%
root = logging.getLogger()
for handler in root.handlers[:]:
    root.removeHandler(handler)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # adds a default StreamHanlder
#root.addHandler(logging.StreamHandler())

# %%
IS_SAMPLE = False

# %%
SVM_SEED = 1234
DOC2VEC_SEED = 1234
WORD2VEC_SEED = 1234

# %%
NUMBER_INDICATOR = "number_inidicator"
CURRENCY_INDICATOR = "currency_inidicator"
CHEMICAL_INDICATOR = "chemical_inidicator"
MIN_WORD_COUNT = 50
MIN_SIZE = 0
NUM_CORES = 22

# %%
GLOBAL_VARS = namedtuple('GLOBAL_VARS', ['MODEL_NAME', 'DOC2VEC_MODEL_NAME', 'DOC2VEC_MODEL', 
                                         'SVM_MODEL_NAME', 'NN_MODEL_NAME'])

# %%
VOCAB_MODEL = "vocab_model"
MODEL_PREFIX = "model"
VALIDATION_MATRIX = "validation_matrix.pkl"
VALIDATION_DICT = "validation_dict.pkl"
TEST_MATRIX = "test_matrix.pkl"
METRICS = "metrics.pkl"
CLASSIFIER = "classifier.pkl"
TYPE_CLASSIFIER= "{}_classifier.pkl"

# %%
root_location = "/big/s/shalaby/"
exports_location = root_location + "exported_data/"

doc2vec_model_save_location = os.path.join(root_location, "parameter_search_doc2vec_models_extended", "full")
if not os.path.exists(doc2vec_model_save_location):
    os.makedirs(doc2vec_model_save_location)
if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL)):
    os.makedirs(os.path.join(doc2vec_model_save_location, VOCAB_MODEL))

#training_file = root_location + "docs_output.json"
training_file = root_location + 'docs_output.json'

doc_classifications_map_file = exports_location + "doc_classification_map.pkl"
sections_file = exports_location + "sections.pkl"
classes_file = exports_location + "classes.pkl"
subclasses_file = exports_location + "subclasses.pkl"
valid_classes_file = exports_location + "valid_classes.pkl"
valid_subclasses_file = exports_location + "valid_subclasses.pkl"
classifications_output = exports_location + "classifications.pkl"
training_docs_list_file = exports_location + "extended_pv_training_docs_list.pkl"
validation_docs_list_file = exports_location + "extended_pv_validation_docs_list.pkl"
test_docs_list_file = exports_location + "extended_pv_test_docs_list.pkl"

preprocessed_location = root_location + "preprocessed_data/"

training_preprocessed_files_prefix = preprocessed_location + "extended_pv_all/extended_pv_training_docs_data_preprocessed-"
validation_preprocessed_files_prefix = preprocessed_location + "extended_pv_all/extended_pv_validation_docs_data_preprocessed-"
test_preprocessed_files_prefix = preprocessed_location + "extended_pv_all/extended_pv_test_docs_data_preprocessed-"

word2vec_questions_file = result = root_location + 'tensorflow/word2vec/questions-words.txt'

# %%
# %%time
doc_classification_map = pickle.load(open(doc_classifications_map_file))
sections = pickle.load(open(sections_file))
classes = pickle.load(open(classes_file))
subclasses = pickle.load(open(subclasses_file))
valid_classes = pickle.load(open(valid_classes_file))
valid_subclasses = pickle.load(open(valid_subclasses_file))
training_docs_list = pickle.load(open(training_docs_list_file))
validation_docs_list = pickle.load(open(validation_docs_list_file))
test_docs_list = pickle.load(open(test_docs_list_file))
# Out:
# CPU times: user 25.8 s, sys: 748 ms, total: 26.6 s
# Wall time: 27 s

# %%
len(training_docs_list)
# Out:
# 120156

# %%
len(validation_docs_list)
# Out:
# 29675

# %%
len(test_docs_list)
# Out:
# 37771

# %%
def ensure_disk_location_exists(location):
    if not os.path.exists(location):
        os.makedirs(location)

# %%
VALIDATION_MINI_BATCH_SIZE = 10000
def get_extended_docs_with_inference(doc2vec_model, doc_classification_map, classifications,
                                           docs_list, file_to_write, preprocessed_files_prefix):
    """
    Use the trained doc2vec model to get the paragraph vector representations of the validation or test documents
    """

    def infer_one_doc(doc_tuple):
        # doc2vec_model.random = np.random.RandomState(DOC2VEC_SEED)
        doc_id, doc_tokens = doc_tuple
        rep = doc2vec_model.infer_vector(doc_tokens)
        return (doc_id, rep)

    one_hot_encoder = OneHotEncoder(classifications)
    classifications_set = set(classifications)
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write)):
        info("===== Loading inference vectors")
        inference_documents_reps = pickle.load(open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write)))
        info("Loaded inference vectors matrix")
    else:
        inference_documents_reps = {}
        info("===== Getting vectors with inference")

        # Multi-threaded inference
        inference_docs_iterator = ExtendedPVDocumentBatchGenerator(preprocessed_files_prefix, batch_size=None)
        generator_func = inference_docs_iterator.__iter__()
        pool = ThreadPool(NUM_CORES)
        # map consumes the whole iterator on the spot, so we have to use itertools.islice to fake mini-batching
        mini_batch_size = VALIDATION_MINI_BATCH_SIZE
        while True:
            threaded_reps_partial = pool.map(infer_one_doc, itertools.islice(generator_func, mini_batch_size))
            info("Finished: {} tags".format(str(inference_docs_iterator.curr_index + 1)))
            if threaded_reps_partial:
                # threaded_reps.extend(threaded_reps_partial)
                inference_documents_reps.update(threaded_reps_partial)
            else:
                break

        pickle.dump(inference_documents_reps,
                    open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write), 'w'))

    return inference_documents_reps

# %%
class OneHotEncoder():
    
    def __init__(self, classifications):
        self.classifications = classifications
        self.one_hot_indices = {}

        # convert character classifications to bit vectors
        for i, clssf in enumerate(classifications):
            bits = [0] * len(classifications)
            bits[i] = 1
            self.one_hot_indices[clssf] = i
    
    def get_label_vector(self, labels):
        """
        classes: array of string with the classes assigned to the instance
        """
        output_vector = [0] * len(self.classifications)
        for label in labels:
            index = self.one_hot_indices[label]
            output_vector[index] = 1
            
        return output_vector

def get_training_data(doc2vec_model, classifications):
    one_hot_encoder = OneHotEncoder(classifications)
    classifications_set = set(classifications)
    training_data = []
    training_labels_mat = np.zeros((len(training_docs_list), len(classifications)), dtype=np.int8)
    for i,doc_id in enumerate(training_docs_list):
        normal_array = doc2vec_model.docvecs[doc_id]
        training_data.append(normal_array)
        eligible_classifications = set(doc_classification_map[doc_id]) & classifications_set
        training_labels_mat[i][:] = one_hot_encoder.get_label_vector(eligible_classifications)
        if i % 100000 == 0:
            info("Finished {} in training".format(i))
    info("doing matrix creation")
    training_data_mat = np.array(training_data)
    del training_data
    return training_data_mat, training_labels_mat

# %%
class ExtendedPVDocumentBatchGenerator(object):
    def __init__(self, filename_prefix, batch_size=10000 ):
        """
        batch_size cant be > 10,000 due to a limitation in doc2vec training, 
        None means no batching (only use for inference)
        """
        assert batch_size <= 10000 or batch_size is None
        self.filename_prefix = filename_prefix
        self.curr_lines = []
        self.curr_docids = []
        self.batch_size = batch_size
        self.curr_index = 0
        self.curr_doc_index = 0
        self.batch_end = -1
    def load_new_batch_in_memory(self):
        del self.curr_lines, self.curr_docids
        self.curr_lines, self.curr_docids = [], []
        info("Loading new batch for index: {}".format(self.curr_doc_index))
        #if self.curr_doc_index > 0: self.curr_doc_index -= 1
        true_docs_count = 0
        try:
            with open(self.filename_prefix + str(self.curr_doc_index)) as preproc_file:
                for line in preproc_file:
                    line_array = line.split(" ")
                    doc_id = line_array[0]
                    doc_tokens = line_array[1:]
                    self.curr_lines.append(doc_tokens)
                    self.curr_docids.append(doc_id)
                    if is_real_doc(doc_id):
                        true_docs_count+= 1
            self.batch_end = self.curr_doc_index + true_docs_count - 1 
            info("Finished loading new batch of {} documents".format(true_docs_count))
        except IOError:
            info("No more batches to load, exiting at index: {}".format(self.curr_index))
            raise StopIteration()
    def __iter__(self):
        while True:
            if self.curr_doc_index > self.batch_end:
                self.load_new_batch_in_memory()
            for (doc_id, tokens) in zip(self.curr_docids, self.curr_lines):
                if self.batch_size is not None:
                    curr_batch_iter = 0
                    # divide the document to batches according to the batch size
                    while curr_batch_iter < len(tokens):
                        yield LabeledSentence(words=tokens[curr_batch_iter: curr_batch_iter + self.batch_size], tags=[doc_id])
                        curr_batch_iter += self.batch_size
                else:
                    yield doc_id, tokens
                self.curr_index += 1
                # increment only for full docs
                if is_real_doc(doc_id):
                    self.curr_doc_index += 1
                    if self.curr_doc_index % 1000 == 0:
                        info("New Doc: {:5}, Batch End: {:5}".format(self.curr_doc_index, self.batch_end))

def is_real_doc(doc_id):
    return doc_id.find("_") == -1

# %% [markdown]
# ### Doc2vec and SVM Parameters

# %%
DOC2VEC_SIZE = 200
DOC2VEC_WINDOW = 2
DOC2VEC_MAX_VOCAB_SIZE = None
DOC2VEC_SAMPLE = 1e-3
DOC2VEC_TYPE = 1
DOC2VEC_HIERARCHICAL_SAMPLE = 0
DOC2VEC_NEGATIVE_SAMPLE_SIZE = 10
DOC2VEC_CONCAT = 0
DOC2VEC_MEAN = 1
DOC2VEC_TRAIN_WORDS = 0
DOC2VEC_EPOCHS = 1 # we do our training manually one epoch at a time
DOC2VEC_MAX_EPOCHS = 8
REPORT_DELAY = 20 # report the progress every x seconds
REPORT_VOCAB_PROGRESS = 100000 # report vocab progress every x documents

# %%
SVM_ITERATIONS = 10
SVM_CONVERGENCE = 0.001
SVM_REG = 0.001
SVM_CLASS_WEIGHTS = None
GLOBAL_VARS.SVM_MODEL_NAME = 'svm_iter_{}_reg_{}_classweights_{}'.format(SVM_ITERATIONS, SVM_REG, str(SVM_CLASS_WEIGHTS))

# %% [markdown]
# ## Create the Doc2vec model

# %%
placeholder_model_name = 'doc2vec_size_{}_w_{}_type_{}_concat_{}_mean_{}_trainwords_{}_hs_{}_neg_{}_vocabsize_{}'.format(DOC2VEC_SIZE, 
                                                                DOC2VEC_WINDOW, 
                                                                'dm' if DOC2VEC_TYPE == 1 else 'pv-dbow',
                                                                DOC2VEC_CONCAT, DOC2VEC_MEAN,
                                                                DOC2VEC_TRAIN_WORDS,
                                                                DOC2VEC_HIERARCHICAL_SAMPLE,DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                                                                str(DOC2VEC_MAX_VOCAB_SIZE))
GLOBAL_VARS.DOC2VEC_MODEL_NAME = placeholder_model_name
placeholder_model_name = os.path.join(placeholder_model_name, "epoch_{}")
placeholder_model_name
# Out:
# 'doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_{}'

# %%
doc2vec_model = Doc2Vec(size=DOC2VEC_SIZE , window=DOC2VEC_WINDOW, min_count=MIN_WORD_COUNT, 
                max_vocab_size= DOC2VEC_MAX_VOCAB_SIZE,
                sample=DOC2VEC_SAMPLE, seed=DOC2VEC_SEED, workers=NUM_CORES,
                # doc2vec algorithm dm=1 => PV-DM, dm=2 => PV-DBOW, PV-DM dictates CBOW for words
                dm=DOC2VEC_TYPE,
                # hs=0 => negative sampling, hs=1 => hierarchical softmax
                hs=DOC2VEC_HIERARCHICAL_SAMPLE, negative=DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                dm_concat=DOC2VEC_CONCAT,
                # would train words with skip-gram on top of cbow, we don't need that for now
                dbow_words=DOC2VEC_TRAIN_WORDS,
                iter=DOC2VEC_EPOCHS)

GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model

# %%
# %%time
training_docs_iterator = ExtendedPVDocumentBatchGenerator(training_preprocessed_files_prefix, batch_size=10000)
if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX)):
    doc2vec_model.build_vocab(sentences=training_docs_iterator, progress_per=REPORT_VOCAB_PROGRESS)
    doc2vec_model.save(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
else:
    doc2vec_model_vocab_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
    doc2vec_model.reset_from(doc2vec_model_vocab_model)
# Out:
# 2017-03-08 12:20:24,904 : INFO : loading Doc2Vec object from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model
# 2017-03-08 12:28:29,054 : INFO : loading docvecs recursively from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model.docvecs.* with mmap=None
# 2017-03-08 12:28:29,057 : INFO : loading doctag_syn0 from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model.docvecs.doctag_syn0.npy with mmap=None
# 2017-03-08 12:31:24,280 : INFO : loading doctag_syn0_lockf from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model.docvecs.doctag_syn0_lockf.npy with mmap=None
# 2017-03-08 12:31:28,110 : INFO : loading syn1neg from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model.syn1neg.npy with mmap=None
# 2017-03-08 12:31:29,432 : INFO : loading syn0 from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/vocab_model/model.syn0.npy with mmap=None
# 2017-03-08 12:31:30,816 : INFO : setting ignored attribute syn0norm to None
# 2017-03-08 12:31:30,817 : INFO : setting ignored attribute cum_table to None
# 2017-03-08 12:31:32,630 : INFO : resetting layer weights
# CPU times: user 26min 19s, sys: 4min 12s, total: 30min 31s
# Wall time: 35min 19s

# %%
# vocab_counts = {k:doc2vec_model.vocab[k].count for k in doc2vec_model.vocab.keys()}
# dd = sorted(vocab_counts, key=vocab_counts.get)

# %% [markdown]
# ## Actual Training, validation and Metrics Loop

# %%
doc2vec_model.min_alpha = 0.025
DOC2VEC_ALPHA_DECREASE = 0.001
epoch_validation_metrics = []
epoch_training_metrics = []
epoch_word2vec_metrics = []
classifications = sections
classifications_type = 'sections'
classifier_file = TYPE_CLASSIFIER.format(classifications_type)

# %%
VALIDATION_METRICS_FILENAME= '{}_validation_metrics.pkl'.format(classifications_type)
TRAINING_METRICS_FILENAME = '{}_training_metrics.pkl'.format(classifications_type)
METRICS_FIG_PNG_FILENAME = '{}_validation_metrics.png'.format(classifications_type)
METRICS_FIG_PDF_FILENAME = '{}_validation_metrics.pdf'.format(classifications_type)
WORD2VEC_METRICS_FILENAME = 'word2vec_metrics.pkl'

# for epoch in range(DOC2VEC_MAX_EPOCHS):
#     GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)
#     ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
#                                              GLOBAL_VARS.SVM_MODEL_NAME))
#     pickle.dump(metrics, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, GLOBAL_VARS.SVM_MODEL_NAME, METRICS), 'w'))
# fig_save_location = placeholder_model_name.format('run')
# plt.savefig(os.path.join(fig_save_location))

# %%
# %%time
# when resuming, resume from an epoch with a previously created doc2vec model to get the learning rate right
start_from = 5
for epoch in range(start_from, DOC2VEC_MAX_EPOCHS+1):
    GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)
    info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))
    
    # if we have the model, just load it, otherwise train the previous model
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):
        doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        doc2vec_model.workers = NUM_CORES
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
    else:
        # train the doc2vec model
        training_docs_iterator = ExtendedPVDocumentBatchGenerator(training_preprocessed_files_prefix, batch_size=10000)
        # %time doc2vec_model.train(sentences=training_docs_iterator, report_delay=REPORT_DELAY)
        doc2vec_model.alpha -= DOC2VEC_ALPHA_DECREASE  # decrease the learning rate
        doc2vec_model.min_alpha = doc2vec_model.alpha  # fix the learning rate, no decay
        ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))
        doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
    
    if epoch > 2:
        # Validation Embeddings
        info('Getting Validation Embeddings')
        Xv = get_extended_docs_with_inference(doc2vec_model, doc_classification_map, classifications, 
                                         validation_docs_list, VALIDATION_DICT, 
                                         validation_preprocessed_files_prefix)
# Out:
# 2017-03-10 00:24:22,917 : INFO : ****************** Epoch 5 --- Working on doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5 *******************
# 2017-03-10 00:24:22,920 : INFO : loading Doc2Vec object from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model
# 2017-03-10 00:28:26,519 : INFO : loading docvecs recursively from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model.docvecs.* with mmap=None
# 2017-03-10 00:28:26,520 : INFO : loading doctag_syn0 from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model.docvecs.doctag_syn0.npy with mmap=None
# 2017-03-10 00:35:36,347 : INFO : loading doctag_syn0_lockf from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model.docvecs.doctag_syn0_lockf.npy with mmap=None
# 2017-03-10 00:35:42,351 : INFO : loading syn1neg from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model.syn1neg.npy with mmap=None
# 2017-03-10 00:35:51,719 : INFO : loading syn0 from /big/s/shalaby/parameter_search_doc2vec_models_extended/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_5/model.syn0.npy with mmap=None
# 2017-03-10 00:36:01,555 : INFO : setting ignored attribute syn0norm to None
# 2017-03-10 00:36:01,556 : INFO : setting ignored attribute cum_table to None
# 2017-03-10 00:36:02,634 : INFO : Getting Validation Embeddings
# 2017-03-10 00:36:02,635 : INFO : ===== Loading inference vectors
# 2017-03-10 00:58:28,924 : INFO : Loaded inference vectors matrix
# 2017-03-10 00:58:28,927 : INFO : ****************** Epoch 6 --- Working on doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6 *******************
# 2017-03-10 00:58:28,931 : INFO : training model with 22 workers on 333388 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=10
# 2017-03-10 00:58:28,932 : INFO : expecting 41247946 sentences, matching count from corpus used for vocabulary survey
# 2017-03-10 00:58:28,945 : INFO : Loading new batch for index: 0
# 2017-03-10 01:00:17,127 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 01:00:18,902 : INFO : PROGRESS: at 0.00% examples, 64 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:00:38,924 : INFO : PROGRESS: at 0.22% examples, 37922 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:00:58,974 : INFO : PROGRESS: at 0.44% examples, 66925 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:01:18,977 : INFO : PROGRESS: at 0.66% examples, 88232 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:01:21,685 : INFO : New Doc:  1000, Batch End:  9999
# 2017-03-10 01:01:38,999 : INFO : PROGRESS: at 0.89% examples, 105575 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:01:59,005 : INFO : PROGRESS: at 1.12% examples, 120059 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:02:18,840 : INFO : New Doc:  2000, Batch End:  9999
# 2017-03-10 01:02:19,020 : INFO : PROGRESS: at 1.36% examples, 131991 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:02:39,032 : INFO : PROGRESS: at 1.58% examples, 142368 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:02:59,035 : INFO : PROGRESS: at 1.82% examples, 151432 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:03:19,060 : INFO : PROGRESS: at 2.05% examples, 159044 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:03:20,830 : INFO : New Doc:  3000, Batch End:  9999
# 2017-03-10 01:03:39,076 : INFO : PROGRESS: at 2.28% examples, 165302 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:03:59,091 : INFO : PROGRESS: at 2.52% examples, 171011 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:04:19,129 : INFO : PROGRESS: at 2.75% examples, 175979 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:04:28,071 : INFO : New Doc:  4000, Batch End:  9999
# 2017-03-10 01:04:39,155 : INFO : PROGRESS: at 2.98% examples, 180296 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:04:59,154 : INFO : PROGRESS: at 3.22% examples, 184177 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:05:19,161 : INFO : PROGRESS: at 3.45% examples, 187883 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:05:34,393 : INFO : New Doc:  5000, Batch End:  9999
# 2017-03-10 01:05:39,204 : INFO : PROGRESS: at 3.68% examples, 191257 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:05:59,212 : INFO : PROGRESS: at 3.91% examples, 194182 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:06:19,223 : INFO : PROGRESS: at 4.14% examples, 196953 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:06:39,235 : INFO : PROGRESS: at 4.37% examples, 199585 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:06:53,917 : INFO : New Doc:  6000, Batch End:  9999
# 2017-03-10 01:06:59,253 : INFO : PROGRESS: at 4.60% examples, 201662 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:07:19,252 : INFO : PROGRESS: at 4.83% examples, 204169 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:07:39,261 : INFO : PROGRESS: at 5.07% examples, 205967 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:07:59,267 : INFO : PROGRESS: at 5.30% examples, 207858 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:08:00,580 : INFO : New Doc:  7000, Batch End:  9999
# 2017-03-10 01:08:19,295 : INFO : PROGRESS: at 5.53% examples, 209684 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:08:39,311 : INFO : PROGRESS: at 5.77% examples, 211343 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:08:59,312 : INFO : PROGRESS: at 6.00% examples, 212977 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:09:02,204 : INFO : New Doc:  8000, Batch End:  9999
# 2017-03-10 01:09:19,335 : INFO : PROGRESS: at 6.23% examples, 214550 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:09:39,340 : INFO : PROGRESS: at 6.47% examples, 215730 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:09:59,343 : INFO : PROGRESS: at 6.70% examples, 216984 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:10:55,391 : INFO : PROGRESS: at 6.74% examples, 201820 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:11:09,574 : INFO : New Doc:  9000, Batch End:  9999
# 2017-03-10 01:11:15,402 : INFO : PROGRESS: at 6.98% examples, 203252 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:11:35,428 : INFO : PROGRESS: at 7.21% examples, 204679 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:11:55,450 : INFO : PROGRESS: at 7.44% examples, 206033 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:12:15,450 : INFO : PROGRESS: at 7.67% examples, 207409 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:12:16,036 : INFO : New Doc: 10000, Batch End:  9999
# 2017-03-10 01:12:32,763 : INFO : Loading new batch for index: 10000
# 2017-03-10 01:12:35,526 : INFO : PROGRESS: at 7.69% examples, 202824 words/s, in_qsize 24, out_qsize 0
# 2017-03-10 01:13:27,083 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 01:13:28,452 : INFO : PROGRESS: at 7.70% examples, 191235 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:13:48,468 : INFO : PROGRESS: at 7.92% examples, 192578 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:14:08,482 : INFO : PROGRESS: at 8.15% examples, 194014 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:14:28,483 : INFO : PROGRESS: at 8.38% examples, 195415 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:14:39,026 : INFO : New Doc: 11000, Batch End: 19999
# 2017-03-10 01:14:48,499 : INFO : PROGRESS: at 8.61% examples, 196752 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:15:08,510 : INFO : PROGRESS: at 8.84% examples, 198036 words/s, in_qsize 43, out_qsize 1
# 2017-03-10 01:15:28,536 : INFO : PROGRESS: at 9.07% examples, 199131 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:15:44,099 : INFO : New Doc: 12000, Batch End: 19999
# 2017-03-10 01:15:48,568 : INFO : PROGRESS: at 9.30% examples, 200374 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:16:08,572 : INFO : PROGRESS: at 9.53% examples, 201505 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:16:28,583 : INFO : PROGRESS: at 9.76% examples, 202637 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:16:48,584 : INFO : PROGRESS: at 9.99% examples, 203687 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:16:52,790 : INFO : New Doc: 13000, Batch End: 19999
# 2017-03-10 01:17:08,602 : INFO : PROGRESS: at 10.23% examples, 204715 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:17:28,606 : INFO : PROGRESS: at 10.46% examples, 205663 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:17:48,619 : INFO : PROGRESS: at 10.69% examples, 206570 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:17:56,219 : INFO : New Doc: 14000, Batch End: 19999
# 2017-03-10 01:18:08,627 : INFO : PROGRESS: at 10.92% examples, 207603 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:18:28,683 : INFO : PROGRESS: at 11.15% examples, 208449 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:18:48,686 : INFO : PROGRESS: at 11.38% examples, 209367 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:18:57,531 : INFO : New Doc: 15000, Batch End: 19999
# 2017-03-10 01:19:08,686 : INFO : PROGRESS: at 11.62% examples, 210174 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:20:04,109 : INFO : PROGRESS: at 11.69% examples, 202594 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:20:24,118 : INFO : PROGRESS: at 11.93% examples, 203510 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:20:44,123 : INFO : PROGRESS: at 12.16% examples, 204353 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:20:57,749 : INFO : New Doc: 16000, Batch End: 19999
# 2017-03-10 01:21:04,124 : INFO : PROGRESS: at 12.39% examples, 205051 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:21:24,178 : INFO : PROGRESS: at 12.62% examples, 205834 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:21:44,200 : INFO : PROGRESS: at 12.85% examples, 206648 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:22:04,216 : INFO : PROGRESS: at 13.08% examples, 207361 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:22:08,678 : INFO : New Doc: 17000, Batch End: 19999
# 2017-03-10 01:22:24,224 : INFO : PROGRESS: at 13.31% examples, 208112 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:22:44,228 : INFO : PROGRESS: at 13.54% examples, 208757 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:23:04,238 : INFO : PROGRESS: at 13.77% examples, 209441 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:23:18,803 : INFO : New Doc: 18000, Batch End: 19999
# 2017-03-10 01:23:24,241 : INFO : PROGRESS: at 14.00% examples, 210133 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:23:44,244 : INFO : PROGRESS: at 14.24% examples, 210795 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:24:04,251 : INFO : PROGRESS: at 14.47% examples, 211377 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:24:24,260 : INFO : PROGRESS: at 14.69% examples, 212094 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:24:24,845 : INFO : New Doc: 19000, Batch End: 19999
# 2017-03-10 01:24:44,269 : INFO : PROGRESS: at 14.92% examples, 212808 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:25:04,303 : INFO : PROGRESS: at 15.16% examples, 213428 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:25:24,309 : INFO : PROGRESS: at 15.38% examples, 213999 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:25:28,666 : INFO : New Doc: 20000, Batch End: 19999
# 2017-03-10 01:25:46,740 : INFO : Loading new batch for index: 20000
# 2017-03-10 01:25:46,788 : INFO : PROGRESS: at 15.44% examples, 211747 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:26:39,862 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 01:26:41,299 : INFO : PROGRESS: at 15.46% examples, 205178 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:27:01,337 : INFO : PROGRESS: at 15.68% examples, 205785 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:27:21,346 : INFO : PROGRESS: at 15.91% examples, 206305 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:27:41,352 : INFO : PROGRESS: at 16.13% examples, 206854 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:27:49,750 : INFO : New Doc: 21000, Batch End: 29999
# 2017-03-10 01:28:01,353 : INFO : PROGRESS: at 16.36% examples, 207408 words/s, in_qsize 42, out_qsize 1
# 2017-03-10 01:28:21,372 : INFO : PROGRESS: at 16.60% examples, 208005 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:29:14,679 : INFO : PROGRESS: at 16.64% examples, 202571 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:29:34,720 : INFO : PROGRESS: at 16.88% examples, 203281 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:29:47,342 : INFO : New Doc: 22000, Batch End: 29999
# 2017-03-10 01:29:54,729 : INFO : PROGRESS: at 17.11% examples, 203963 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:30:14,735 : INFO : PROGRESS: at 17.35% examples, 204634 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:30:34,769 : INFO : PROGRESS: at 17.58% examples, 205253 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:30:52,081 : INFO : New Doc: 23000, Batch End: 29999
# 2017-03-10 01:30:54,827 : INFO : PROGRESS: at 17.81% examples, 205802 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:31:14,832 : INFO : PROGRESS: at 18.04% examples, 206405 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:31:34,888 : INFO : PROGRESS: at 18.28% examples, 206936 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:31:54,904 : INFO : PROGRESS: at 18.52% examples, 207550 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:32:01,247 : INFO : New Doc: 24000, Batch End: 29999
# 2017-03-10 01:32:14,928 : INFO : PROGRESS: at 18.75% examples, 208021 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:32:34,945 : INFO : PROGRESS: at 18.98% examples, 208538 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:32:54,972 : INFO : PROGRESS: at 19.22% examples, 209096 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:33:05,714 : INFO : New Doc: 25000, Batch End: 29999
# 2017-03-10 01:33:15,004 : INFO : PROGRESS: at 19.45% examples, 209575 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:33:35,014 : INFO : PROGRESS: at 19.68% examples, 210080 words/s, in_qsize 44, out_qsize 1
# 2017-03-10 01:33:55,010 : INFO : PROGRESS: at 19.91% examples, 210667 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:34:14,082 : INFO : New Doc: 26000, Batch End: 29999
# 2017-03-10 01:34:15,013 : INFO : PROGRESS: at 20.15% examples, 211150 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:34:35,052 : INFO : PROGRESS: at 20.38% examples, 211644 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:34:55,084 : INFO : PROGRESS: at 20.61% examples, 212095 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:35:15,096 : INFO : PROGRESS: at 20.85% examples, 212566 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:35:19,500 : INFO : New Doc: 27000, Batch End: 29999
# 2017-03-10 01:35:35,105 : INFO : PROGRESS: at 21.08% examples, 213020 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:35:55,162 : INFO : PROGRESS: at 21.31% examples, 213483 words/s, in_qsize 44, out_qsize 1
# 2017-03-10 01:36:15,193 : INFO : PROGRESS: at 21.54% examples, 213870 words/s, in_qsize 44, out_qsize 1
# 2017-03-10 01:36:26,318 : INFO : New Doc: 28000, Batch End: 29999
# 2017-03-10 01:36:35,194 : INFO : PROGRESS: at 21.78% examples, 214294 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:36:55,243 : INFO : PROGRESS: at 22.01% examples, 214695 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:37:15,250 : INFO : PROGRESS: at 22.24% examples, 215070 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:37:30,424 : INFO : New Doc: 29000, Batch End: 29999
# 2017-03-10 01:37:35,382 : INFO : PROGRESS: at 22.47% examples, 215446 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:37:55,404 : INFO : PROGRESS: at 22.70% examples, 215889 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:38:15,440 : INFO : PROGRESS: at 22.94% examples, 216295 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:38:35,471 : INFO : PROGRESS: at 23.17% examples, 216639 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:38:38,380 : INFO : New Doc: 30000, Batch End: 29999
# 2017-03-10 01:38:56,767 : INFO : Loading new batch for index: 30000
# 2017-03-10 01:38:56,774 : INFO : PROGRESS: at 23.20% examples, 215085 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:39:48,292 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 01:40:38,032 : INFO : PROGRESS: at 23.23% examples, 206644 words/s, in_qsize 6, out_qsize 0
# 2017-03-10 01:40:58,051 : INFO : PROGRESS: at 23.45% examples, 207047 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:41:18,068 : INFO : PROGRESS: at 23.68% examples, 207491 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:41:38,077 : INFO : PROGRESS: at 23.91% examples, 207851 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:41:47,433 : INFO : New Doc: 31000, Batch End: 39999
# 2017-03-10 01:41:58,098 : INFO : PROGRESS: at 24.14% examples, 208247 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:42:18,110 : INFO : PROGRESS: at 24.38% examples, 208649 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:42:38,128 : INFO : PROGRESS: at 24.60% examples, 209075 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:42:52,739 : INFO : New Doc: 32000, Batch End: 39999
# 2017-03-10 01:42:58,141 : INFO : PROGRESS: at 24.84% examples, 209481 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:43:18,143 : INFO : PROGRESS: at 25.07% examples, 209883 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:43:38,177 : INFO : PROGRESS: at 25.30% examples, 210276 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:43:58,231 : INFO : PROGRESS: at 25.53% examples, 210700 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:44:00,827 : INFO : New Doc: 33000, Batch End: 39999
# 2017-03-10 01:44:18,232 : INFO : PROGRESS: at 25.77% examples, 211071 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:44:38,256 : INFO : PROGRESS: at 26.01% examples, 211455 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:44:58,269 : INFO : PROGRESS: at 26.24% examples, 211841 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:45:11,527 : INFO : New Doc: 34000, Batch End: 39999
# 2017-03-10 01:45:18,270 : INFO : PROGRESS: at 26.47% examples, 212194 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:45:38,277 : INFO : PROGRESS: at 26.71% examples, 212534 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:45:58,282 : INFO : PROGRESS: at 26.94% examples, 212882 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:46:18,315 : INFO : PROGRESS: at 27.17% examples, 213243 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:46:18,397 : INFO : New Doc: 35000, Batch End: 39999
# 2017-03-10 01:46:38,359 : INFO : PROGRESS: at 27.41% examples, 213592 words/s, in_qsize 44, out_qsize 1
# 2017-03-10 01:46:58,368 : INFO : PROGRESS: at 27.65% examples, 213895 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:47:18,418 : INFO : PROGRESS: at 27.88% examples, 214252 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:47:32,487 : INFO : New Doc: 36000, Batch End: 39999
# 2017-03-10 01:47:38,451 : INFO : PROGRESS: at 28.11% examples, 214619 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:47:58,475 : INFO : PROGRESS: at 28.34% examples, 215042 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:48:18,476 : INFO : PROGRESS: at 28.58% examples, 215357 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:48:38,486 : INFO : PROGRESS: at 28.81% examples, 215707 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:48:41,141 : INFO : New Doc: 37000, Batch End: 39999
# 2017-03-10 01:48:58,503 : INFO : PROGRESS: at 29.04% examples, 216034 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:49:18,503 : INFO : PROGRESS: at 29.27% examples, 216336 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:49:38,549 : INFO : PROGRESS: at 29.50% examples, 216644 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:49:50,402 : INFO : New Doc: 38000, Batch End: 39999
# 2017-03-10 01:49:58,569 : INFO : PROGRESS: at 29.74% examples, 216951 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:50:18,599 : INFO : PROGRESS: at 29.97% examples, 217243 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:50:38,615 : INFO : PROGRESS: at 30.20% examples, 217488 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:50:55,908 : INFO : New Doc: 39000, Batch End: 39999
# 2017-03-10 01:50:58,625 : INFO : PROGRESS: at 30.44% examples, 217804 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:51:18,676 : INFO : PROGRESS: at 30.67% examples, 218050 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:51:38,690 : INFO : PROGRESS: at 30.91% examples, 218290 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:51:58,698 : INFO : PROGRESS: at 31.14% examples, 218550 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:52:47,691 : INFO : PROGRESS: at 31.15% examples, 215354 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:52:55,217 : INFO : New Doc: 40000, Batch End: 39999
# 2017-03-10 01:53:14,571 : INFO : Loading new batch for index: 40000
# 2017-03-10 01:53:14,716 : INFO : PROGRESS: at 31.24% examples, 214180 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:54:09,608 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 01:54:10,830 : INFO : PROGRESS: at 31.26% examples, 210712 words/s, in_qsize 2, out_qsize 0
# 2017-03-10 01:54:30,834 : INFO : PROGRESS: at 31.49% examples, 211006 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:54:50,828 : INFO : PROGRESS: at 31.73% examples, 211331 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:55:10,837 : INFO : PROGRESS: at 31.95% examples, 211587 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:55:16,909 : INFO : New Doc: 41000, Batch End: 49999
# 2017-03-10 01:55:30,921 : INFO : PROGRESS: at 32.19% examples, 211892 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:55:50,929 : INFO : PROGRESS: at 32.42% examples, 212162 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:56:10,960 : INFO : PROGRESS: at 32.65% examples, 212441 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:56:31,035 : INFO : PROGRESS: at 32.89% examples, 212745 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:56:34,625 : INFO : New Doc: 42000, Batch End: 49999
# 2017-03-10 01:56:51,038 : INFO : PROGRESS: at 33.12% examples, 213030 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:57:11,048 : INFO : PROGRESS: at 33.35% examples, 213338 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:57:31,102 : INFO : PROGRESS: at 33.59% examples, 213651 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:57:41,270 : INFO : New Doc: 43000, Batch End: 49999
# 2017-03-10 01:57:51,114 : INFO : PROGRESS: at 33.82% examples, 213946 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:58:11,149 : INFO : PROGRESS: at 34.06% examples, 214260 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:58:31,152 : INFO : PROGRESS: at 34.29% examples, 214547 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:58:51,170 : INFO : PROGRESS: at 34.53% examples, 214853 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 01:58:51,419 : INFO : New Doc: 44000, Batch End: 49999
# 2017-03-10 01:59:11,182 : INFO : PROGRESS: at 34.77% examples, 215110 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:59:31,191 : INFO : PROGRESS: at 35.00% examples, 215381 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 01:59:51,281 : INFO : PROGRESS: at 35.24% examples, 215681 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:00:03,393 : INFO : New Doc: 45000, Batch End: 49999
# 2017-03-10 02:00:11,256 : INFO : PROGRESS: at 35.46% examples, 215938 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:00:31,266 : INFO : PROGRESS: at 35.70% examples, 216196 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:01:25,717 : INFO : PROGRESS: at 35.77% examples, 213450 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:01:45,736 : INFO : PROGRESS: at 36.00% examples, 213746 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:02:03,118 : INFO : New Doc: 46000, Batch End: 49999
# 2017-03-10 02:02:05,793 : INFO : PROGRESS: at 36.23% examples, 214059 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:02:25,807 : INFO : PROGRESS: at 36.47% examples, 214311 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:02:45,797 : INFO : PROGRESS: at 36.70% examples, 214574 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:03:05,833 : INFO : PROGRESS: at 36.93% examples, 214902 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:03:15,974 : INFO : New Doc: 47000, Batch End: 49999
# 2017-03-10 02:03:25,867 : INFO : PROGRESS: at 37.17% examples, 215166 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:03:45,881 : INFO : PROGRESS: at 37.40% examples, 215423 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:04:05,909 : INFO : PROGRESS: at 37.63% examples, 215651 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:04:25,963 : INFO : PROGRESS: at 37.87% examples, 215908 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:04:28,537 : INFO : New Doc: 48000, Batch End: 49999
# 2017-03-10 02:04:45,980 : INFO : PROGRESS: at 38.09% examples, 216175 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:05:05,989 : INFO : PROGRESS: at 38.33% examples, 216392 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:05:26,029 : INFO : PROGRESS: at 38.57% examples, 216596 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:05:43,075 : INFO : New Doc: 49000, Batch End: 49999
# 2017-03-10 02:05:46,064 : INFO : PROGRESS: at 38.80% examples, 216836 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:06:06,081 : INFO : PROGRESS: at 39.03% examples, 217087 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:06:26,099 : INFO : PROGRESS: at 39.27% examples, 217325 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:06:46,110 : INFO : PROGRESS: at 39.51% examples, 217545 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:06:52,934 : INFO : New Doc: 50000, Batch End: 49999
# 2017-03-10 02:07:13,673 : INFO : Loading new batch for index: 50000
# 2017-03-10 02:07:13,776 : INFO : PROGRESS: at 39.59% examples, 216516 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:08:07,010 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 02:08:08,624 : INFO : PROGRESS: at 39.61% examples, 213776 words/s, in_qsize 41, out_qsize 0
# 2017-03-10 02:08:28,630 : INFO : PROGRESS: at 39.83% examples, 214010 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:08:48,656 : INFO : PROGRESS: at 40.06% examples, 214200 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:09:08,672 : INFO : PROGRESS: at 40.29% examples, 214414 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:09:16,290 : INFO : New Doc: 51000, Batch End: 59999
# 2017-03-10 02:10:08,271 : INFO : PROGRESS: at 40.44% examples, 212140 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:10:28,297 : INFO : PROGRESS: at 40.68% examples, 212399 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:10:48,362 : INFO : PROGRESS: at 40.92% examples, 212663 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:11:08,364 : INFO : PROGRESS: at 41.16% examples, 212918 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:11:12,167 : INFO : New Doc: 52000, Batch End: 59999
# 2017-03-10 02:11:28,377 : INFO : PROGRESS: at 41.39% examples, 213158 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:11:48,391 : INFO : PROGRESS: at 41.63% examples, 213381 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:12:08,411 : INFO : PROGRESS: at 41.86% examples, 213582 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:12:19,498 : INFO : New Doc: 53000, Batch End: 59999
# 2017-03-10 02:12:28,418 : INFO : PROGRESS: at 42.09% examples, 213803 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:12:48,421 : INFO : PROGRESS: at 42.33% examples, 214079 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:13:08,436 : INFO : PROGRESS: at 42.56% examples, 214336 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:13:28,457 : INFO : PROGRESS: at 42.80% examples, 214538 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:13:33,515 : INFO : New Doc: 54000, Batch End: 59999
# 2017-03-10 02:13:48,463 : INFO : PROGRESS: at 43.03% examples, 214784 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:14:08,486 : INFO : PROGRESS: at 43.27% examples, 215023 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:14:28,494 : INFO : PROGRESS: at 43.51% examples, 215246 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:14:43,524 : INFO : New Doc: 55000, Batch End: 59999
# 2017-03-10 02:14:48,512 : INFO : PROGRESS: at 43.74% examples, 215464 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:15:08,526 : INFO : PROGRESS: at 43.98% examples, 215674 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:15:28,528 : INFO : PROGRESS: at 44.21% examples, 215904 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:15:48,546 : INFO : PROGRESS: at 44.44% examples, 216153 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:15:55,977 : INFO : New Doc: 56000, Batch End: 59999
# 2017-03-10 02:16:08,605 : INFO : PROGRESS: at 44.67% examples, 216349 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:16:28,615 : INFO : PROGRESS: at 44.91% examples, 216553 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:16:48,628 : INFO : PROGRESS: at 45.14% examples, 216774 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:17:08,650 : INFO : PROGRESS: at 45.37% examples, 216956 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:17:11,641 : INFO : New Doc: 57000, Batch End: 59999
# 2017-03-10 02:17:28,688 : INFO : PROGRESS: at 45.61% examples, 217175 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:17:48,704 : INFO : PROGRESS: at 45.85% examples, 217368 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:18:08,717 : INFO : PROGRESS: at 46.08% examples, 217556 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:18:23,579 : INFO : New Doc: 58000, Batch End: 59999
# 2017-03-10 02:18:28,727 : INFO : PROGRESS: at 46.32% examples, 217783 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:18:48,741 : INFO : PROGRESS: at 46.55% examples, 217964 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:19:08,747 : INFO : PROGRESS: at 46.78% examples, 218172 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:19:28,761 : INFO : PROGRESS: at 47.02% examples, 218363 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:19:32,710 : INFO : New Doc: 59000, Batch End: 59999
# 2017-03-10 02:19:48,776 : INFO : PROGRESS: at 47.25% examples, 218556 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:20:08,772 : INFO : PROGRESS: at 47.48% examples, 218738 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:20:28,815 : INFO : PROGRESS: at 47.72% examples, 218920 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:20:46,200 : INFO : New Doc: 60000, Batch End: 59999
# 2017-03-10 02:21:07,154 : INFO : Loading new batch for index: 60000
# 2017-03-10 02:21:07,159 : INFO : PROGRESS: at 47.92% examples, 218163 words/s, in_qsize 44, out_qsize 1
# 2017-03-10 02:22:50,785 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 02:22:52,082 : INFO : PROGRESS: at 47.95% examples, 213728 words/s, in_qsize 34, out_qsize 0
# 2017-03-10 02:23:12,088 : INFO : PROGRESS: at 48.17% examples, 213916 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:23:32,091 : INFO : PROGRESS: at 48.40% examples, 214101 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:23:52,097 : INFO : PROGRESS: at 48.64% examples, 214289 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:24:07,275 : INFO : New Doc: 61000, Batch End: 69999
# 2017-03-10 02:24:12,126 : INFO : PROGRESS: at 48.87% examples, 214507 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:24:32,136 : INFO : PROGRESS: at 49.10% examples, 214710 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:24:52,185 : INFO : PROGRESS: at 49.34% examples, 214925 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:25:12,208 : INFO : PROGRESS: at 49.58% examples, 215141 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:25:12,700 : INFO : New Doc: 62000, Batch End: 69999
# 2017-03-10 02:25:32,265 : INFO : PROGRESS: at 49.81% examples, 215334 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:25:52,305 : INFO : PROGRESS: at 50.04% examples, 215503 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:26:12,309 : INFO : PROGRESS: at 50.28% examples, 215665 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:26:25,993 : INFO : New Doc: 63000, Batch End: 69999
# 2017-03-10 02:26:32,326 : INFO : PROGRESS: at 50.51% examples, 215851 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:26:52,316 : INFO : PROGRESS: at 50.75% examples, 216043 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:27:12,426 : INFO : PROGRESS: at 50.99% examples, 216230 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:27:32,446 : INFO : PROGRESS: at 51.22% examples, 216430 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:27:37,244 : INFO : New Doc: 64000, Batch End: 69999
# 2017-03-10 02:27:52,455 : INFO : PROGRESS: at 51.45% examples, 216613 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:28:12,485 : INFO : PROGRESS: at 51.69% examples, 216790 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:28:32,491 : INFO : PROGRESS: at 51.92% examples, 216997 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:28:47,232 : INFO : New Doc: 65000, Batch End: 69999
# 2017-03-10 02:28:52,502 : INFO : PROGRESS: at 52.15% examples, 217166 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:29:12,529 : INFO : PROGRESS: at 52.39% examples, 217347 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:29:32,540 : INFO : PROGRESS: at 52.62% examples, 217521 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:29:52,548 : INFO : PROGRESS: at 52.86% examples, 217699 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:29:57,366 : INFO : New Doc: 66000, Batch End: 69999
# 2017-03-10 02:30:12,582 : INFO : PROGRESS: at 53.10% examples, 217887 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:30:32,592 : INFO : PROGRESS: at 53.33% examples, 218089 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:30:52,597 : INFO : PROGRESS: at 53.57% examples, 218244 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:31:05,120 : INFO : New Doc: 67000, Batch End: 69999
# 2017-03-10 02:31:12,602 : INFO : PROGRESS: at 53.80% examples, 218448 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:31:32,649 : INFO : PROGRESS: at 54.04% examples, 218604 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:31:52,664 : INFO : PROGRESS: at 54.27% examples, 218769 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:32:12,723 : INFO : PROGRESS: at 54.51% examples, 218946 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:33:07,374 : INFO : PROGRESS: at 54.56% examples, 217058 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:33:14,866 : INFO : New Doc: 68000, Batch End: 69999
# 2017-03-10 02:33:27,396 : INFO : PROGRESS: at 54.80% examples, 217250 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:33:47,410 : INFO : PROGRESS: at 55.04% examples, 217433 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:34:07,438 : INFO : PROGRESS: at 55.28% examples, 217605 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:34:20,903 : INFO : New Doc: 69000, Batch End: 69999
# 2017-03-10 02:34:27,457 : INFO : PROGRESS: at 55.50% examples, 217775 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:34:47,459 : INFO : PROGRESS: at 55.74% examples, 217948 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:35:07,462 : INFO : PROGRESS: at 55.97% examples, 218110 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:35:27,466 : INFO : PROGRESS: at 56.21% examples, 218286 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:35:34,546 : INFO : New Doc: 70000, Batch End: 69999
# 2017-03-10 02:35:55,771 : INFO : Loading new batch for index: 70000
# 2017-03-10 02:35:55,814 : INFO : PROGRESS: at 56.29% examples, 217545 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:36:49,475 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 02:36:50,902 : INFO : PROGRESS: at 56.31% examples, 215585 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:37:10,919 : INFO : PROGRESS: at 56.54% examples, 215723 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:37:30,930 : INFO : PROGRESS: at 56.77% examples, 215879 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:37:50,981 : INFO : PROGRESS: at 57.01% examples, 216037 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:38:02,601 : INFO : New Doc: 71000, Batch End: 79999
# 2017-03-10 02:38:11,011 : INFO : PROGRESS: at 57.24% examples, 216214 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:38:31,044 : INFO : PROGRESS: at 57.48% examples, 216394 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:38:51,054 : INFO : PROGRESS: at 57.71% examples, 216569 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:39:11,078 : INFO : PROGRESS: at 57.95% examples, 216768 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:39:11,323 : INFO : New Doc: 72000, Batch End: 79999
# 2017-03-10 02:39:31,098 : INFO : PROGRESS: at 58.19% examples, 216932 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:39:51,110 : INFO : PROGRESS: at 58.43% examples, 217115 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:40:11,158 : INFO : PROGRESS: at 58.67% examples, 217286 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:40:24,426 : INFO : New Doc: 73000, Batch End: 79999
# 2017-03-10 02:40:31,178 : INFO : PROGRESS: at 58.90% examples, 217451 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:40:51,183 : INFO : PROGRESS: at 59.13% examples, 217607 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:41:41,585 : INFO : PROGRESS: at 59.17% examples, 215953 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:42:01,592 : INFO : PROGRESS: at 59.41% examples, 216125 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:42:20,206 : INFO : New Doc: 74000, Batch End: 79999
# 2017-03-10 02:42:21,605 : INFO : PROGRESS: at 59.65% examples, 216326 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:42:41,615 : INFO : PROGRESS: at 59.88% examples, 216502 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:43:01,626 : INFO : PROGRESS: at 60.12% examples, 216645 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:43:21,668 : INFO : PROGRESS: at 60.35% examples, 216796 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:43:35,630 : INFO : New Doc: 75000, Batch End: 79999
# 2017-03-10 02:43:41,668 : INFO : PROGRESS: at 60.58% examples, 216956 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:44:01,689 : INFO : PROGRESS: at 60.82% examples, 217126 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:44:21,719 : INFO : PROGRESS: at 61.06% examples, 217288 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:44:41,772 : INFO : PROGRESS: at 61.29% examples, 217456 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:44:45,595 : INFO : New Doc: 76000, Batch End: 79999
# 2017-03-10 02:45:01,776 : INFO : PROGRESS: at 61.53% examples, 217619 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:45:21,779 : INFO : PROGRESS: at 61.76% examples, 217791 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:45:41,873 : INFO : PROGRESS: at 61.99% examples, 217935 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:45:56,363 : INFO : New Doc: 77000, Batch End: 79999
# 2017-03-10 02:46:01,875 : INFO : PROGRESS: at 62.23% examples, 218084 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:46:21,881 : INFO : PROGRESS: at 62.46% examples, 218234 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:46:41,885 : INFO : PROGRESS: at 62.70% examples, 218388 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:47:01,894 : INFO : PROGRESS: at 62.94% examples, 218533 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:47:10,947 : INFO : New Doc: 78000, Batch End: 79999
# 2017-03-10 02:47:21,910 : INFO : PROGRESS: at 63.17% examples, 218704 words/s, in_qsize 42, out_qsize 1
# 2017-03-10 02:47:41,914 : INFO : PROGRESS: at 63.40% examples, 218837 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:48:01,940 : INFO : PROGRESS: at 63.64% examples, 218985 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:48:21,965 : INFO : PROGRESS: at 63.89% examples, 219147 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:48:25,386 : INFO : New Doc: 79000, Batch End: 79999
# 2017-03-10 02:48:41,993 : INFO : PROGRESS: at 64.12% examples, 219287 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:49:02,055 : INFO : PROGRESS: at 64.36% examples, 219421 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:49:22,059 : INFO : PROGRESS: at 64.59% examples, 219565 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:49:34,991 : INFO : New Doc: 80000, Batch End: 79999
# 2017-03-10 02:49:56,490 : INFO : Loading new batch for index: 80000
# 2017-03-10 02:49:56,600 : INFO : PROGRESS: at 64.74% examples, 218956 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:50:51,454 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 02:51:39,134 : INFO : PROGRESS: at 64.77% examples, 215708 words/s, in_qsize 0, out_qsize 0
# 2017-03-10 02:51:59,148 : INFO : PROGRESS: at 64.99% examples, 215841 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:52:19,165 : INFO : PROGRESS: at 65.22% examples, 215979 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:52:39,178 : INFO : PROGRESS: at 65.46% examples, 216122 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:52:49,133 : INFO : New Doc: 81000, Batch End: 89999
# 2017-03-10 02:52:59,209 : INFO : PROGRESS: at 65.70% examples, 216258 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:53:19,221 : INFO : PROGRESS: at 65.93% examples, 216415 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:53:39,254 : INFO : PROGRESS: at 66.17% examples, 216565 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:53:59,266 : INFO : PROGRESS: at 66.41% examples, 216736 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:54:04,732 : INFO : New Doc: 82000, Batch End: 89999
# 2017-03-10 02:54:19,276 : INFO : PROGRESS: at 66.64% examples, 216890 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:54:39,277 : INFO : PROGRESS: at 66.88% examples, 217034 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:54:59,319 : INFO : PROGRESS: at 67.11% examples, 217185 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:55:13,561 : INFO : New Doc: 83000, Batch End: 89999
# 2017-03-10 02:55:19,327 : INFO : PROGRESS: at 67.35% examples, 217338 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:55:39,343 : INFO : PROGRESS: at 67.60% examples, 217490 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:55:59,409 : INFO : PROGRESS: at 67.83% examples, 217650 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:56:19,426 : INFO : PROGRESS: at 68.07% examples, 217795 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:56:30,535 : INFO : New Doc: 84000, Batch End: 89999
# 2017-03-10 02:56:39,441 : INFO : PROGRESS: at 68.31% examples, 217946 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:56:59,449 : INFO : PROGRESS: at 68.55% examples, 218096 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:57:19,469 : INFO : PROGRESS: at 68.78% examples, 218240 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:57:39,271 : INFO : New Doc: 85000, Batch End: 89999
# 2017-03-10 02:57:39,490 : INFO : PROGRESS: at 69.02% examples, 218394 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:57:59,498 : INFO : PROGRESS: at 69.26% examples, 218537 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:58:19,511 : INFO : PROGRESS: at 69.50% examples, 218673 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:58:39,515 : INFO : PROGRESS: at 69.73% examples, 218813 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:58:49,878 : INFO : New Doc: 86000, Batch End: 89999
# 2017-03-10 02:58:59,523 : INFO : PROGRESS: at 69.97% examples, 218966 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:59:19,544 : INFO : PROGRESS: at 70.21% examples, 219101 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 02:59:39,584 : INFO : PROGRESS: at 70.45% examples, 219218 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 02:59:59,601 : INFO : PROGRESS: at 70.69% examples, 219360 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:00:04,794 : INFO : New Doc: 87000, Batch End: 89999
# 2017-03-10 03:00:19,617 : INFO : PROGRESS: at 70.93% examples, 219512 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:00:39,665 : INFO : PROGRESS: at 71.17% examples, 219638 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:00:59,680 : INFO : PROGRESS: at 71.41% examples, 219781 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:01:16,748 : INFO : New Doc: 88000, Batch End: 89999
# 2017-03-10 03:01:19,712 : INFO : PROGRESS: at 71.65% examples, 219898 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:01:39,721 : INFO : PROGRESS: at 71.88% examples, 220024 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:01:59,742 : INFO : PROGRESS: at 72.11% examples, 220204 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:02:19,742 : INFO : PROGRESS: at 72.35% examples, 220330 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:02:29,182 : INFO : New Doc: 89000, Batch End: 89999
# 2017-03-10 03:02:39,756 : INFO : PROGRESS: at 72.58% examples, 220456 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:02:59,806 : INFO : PROGRESS: at 72.82% examples, 220582 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:03:19,827 : INFO : PROGRESS: at 73.06% examples, 220708 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:03:39,833 : INFO : PROGRESS: at 73.30% examples, 220827 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:03:47,760 : INFO : New Doc: 90000, Batch End: 89999
# 2017-03-10 03:04:10,049 : INFO : Loading new batch for index: 90000
# 2017-03-10 03:04:10,056 : INFO : PROGRESS: at 73.39% examples, 220228 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:05:46,267 : INFO : Finished loading new batch of 10000 documents
# 2017-03-10 03:05:47,835 : INFO : PROGRESS: at 73.41% examples, 217466 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:06:07,835 : INFO : PROGRESS: at 73.64% examples, 217596 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:06:27,836 : INFO : PROGRESS: at 73.87% examples, 217728 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:06:47,841 : INFO : PROGRESS: at 74.10% examples, 217848 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:06:58,053 : INFO : New Doc: 91000, Batch End: 99999
# 2017-03-10 03:07:07,846 : INFO : PROGRESS: at 74.34% examples, 217992 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:07:27,848 : INFO : PROGRESS: at 74.58% examples, 218124 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:07:47,857 : INFO : PROGRESS: at 74.81% examples, 218270 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:08:07,877 : INFO : PROGRESS: at 75.04% examples, 218409 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:08:11,104 : INFO : New Doc: 92000, Batch End: 99999
# 2017-03-10 03:08:27,907 : INFO : PROGRESS: at 75.29% examples, 218545 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:08:47,916 : INFO : PROGRESS: at 75.52% examples, 218680 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:09:07,941 : INFO : PROGRESS: at 75.76% examples, 218808 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:09:25,005 : INFO : New Doc: 93000, Batch End: 99999
# 2017-03-10 03:09:27,955 : INFO : PROGRESS: at 76.00% examples, 218947 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:09:47,959 : INFO : PROGRESS: at 76.24% examples, 219087 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:10:08,005 : INFO : PROGRESS: at 76.48% examples, 219206 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:11:14,338 : INFO : PROGRESS: at 76.70% examples, 218013 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:11:29,455 : INFO : New Doc: 94000, Batch End: 99999
# 2017-03-10 03:11:34,340 : INFO : PROGRESS: at 76.94% examples, 218160 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:11:54,373 : INFO : PROGRESS: at 77.18% examples, 218283 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:12:14,393 : INFO : PROGRESS: at 77.42% examples, 218418 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:12:34,401 : INFO : PROGRESS: at 77.66% examples, 218544 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:12:46,531 : INFO : New Doc: 95000, Batch End: 99999
# 2017-03-10 03:12:54,406 : INFO : PROGRESS: at 77.89% examples, 218661 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:13:14,408 : INFO : PROGRESS: at 78.13% examples, 218791 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:13:34,442 : INFO : PROGRESS: at 78.37% examples, 218914 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:13:54,523 : INFO : PROGRESS: at 78.61% examples, 219041 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:13:59,055 : INFO : New Doc: 96000, Batch End: 99999
# 2017-03-10 03:14:14,527 : INFO : PROGRESS: at 78.85% examples, 219167 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:14:34,530 : INFO : PROGRESS: at 79.09% examples, 219280 words/s, in_qsize 43, out_qsize 0
# 2017-03-10 03:14:54,539 : INFO : PROGRESS: at 79.32% examples, 219413 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:15:10,358 : INFO : New Doc: 97000, Batch End: 99999
# 2017-03-10 03:15:14,542 : INFO : PROGRESS: at 79.56% examples, 219515 words/s, in_qsize 44, out_qsize 0
# 2017-03-10 03:15:34,546 : INFO : PROGRESS: at 79.79% examples, 219649 words/s, in_qsize 43, out_qsize 0
# ...
# 2017-03-10 18:07:24,651 : INFO : New Doc: 22000, Batch End: 29674
# 2017-03-10 18:07:33,973 : INFO : Finished: 7060000 tags
# 2017-03-10 18:07:43,195 : INFO : Finished: 7070000 tags
# 2017-03-10 18:07:52,645 : INFO : Finished: 7080000 tags
# 2017-03-10 18:08:02,035 : INFO : Finished: 7090000 tags
# 2017-03-10 18:08:11,655 : INFO : Finished: 7100000 tags
# 2017-03-10 18:08:21,025 : INFO : Finished: 7110000 tags
# 2017-03-10 18:08:30,149 : INFO : Finished: 7120000 tags
# 2017-03-10 18:08:39,749 : INFO : Finished: 7130000 tags
# 2017-03-10 18:08:49,239 : INFO : Finished: 7140000 tags
# 2017-03-10 18:08:58,700 : INFO : Finished: 7150000 tags
# 2017-03-10 18:09:08,046 : INFO : Finished: 7160000 tags
# 2017-03-10 18:09:16,643 : INFO : Finished: 7170000 tags
# 2017-03-10 18:09:25,984 : INFO : Finished: 7180000 tags
# 2017-03-10 18:09:35,173 : INFO : Finished: 7190000 tags
# 2017-03-10 18:09:44,582 : INFO : Finished: 7200000 tags
# 2017-03-10 18:09:53,954 : INFO : Finished: 7210000 tags
# 2017-03-10 18:10:02,985 : INFO : Finished: 7220000 tags
# 2017-03-10 18:10:12,558 : INFO : Finished: 7230000 tags
# 2017-03-10 18:10:21,070 : INFO : Finished: 7240000 tags
# 2017-03-10 18:10:29,718 : INFO : Finished: 7250000 tags
# 2017-03-10 18:10:38,654 : INFO : Finished: 7260000 tags
# 2017-03-10 18:10:47,400 : INFO : Finished: 7270000 tags
# 2017-03-10 18:10:56,510 : INFO : Finished: 7280000 tags
# 2017-03-10 18:11:05,760 : INFO : Finished: 7290000 tags
# 2017-03-10 18:11:14,776 : INFO : Finished: 7300000 tags
# 2017-03-10 18:11:23,704 : INFO : Finished: 7310000 tags
# 2017-03-10 18:11:32,676 : INFO : Finished: 7320000 tags
# 2017-03-10 18:11:42,036 : INFO : Finished: 7330000 tags
# 2017-03-10 18:11:51,549 : INFO : Finished: 7340000 tags
# 2017-03-10 18:12:00,971 : INFO : Finished: 7350000 tags
# 2017-03-10 18:12:10,379 : INFO : Finished: 7360000 tags
# 2017-03-10 18:12:19,343 : INFO : Finished: 7370000 tags
# 2017-03-10 18:12:28,792 : INFO : Finished: 7380000 tags
# 2017-03-10 18:12:38,227 : INFO : Finished: 7390000 tags
# 2017-03-10 18:12:47,168 : INFO : Finished: 7400000 tags
# 2017-03-10 18:12:47,183 : INFO : New Doc: 23000, Batch End: 29674
# 2017-03-10 18:12:56,527 : INFO : Finished: 7410000 tags
# 2017-03-10 18:13:05,764 : INFO : Finished: 7420000 tags
# 2017-03-10 18:13:14,687 : INFO : Finished: 7430000 tags
# 2017-03-10 18:13:23,458 : INFO : Finished: 7440000 tags
# 2017-03-10 18:13:32,251 : INFO : Finished: 7450000 tags
# 2017-03-10 18:13:41,496 : INFO : Finished: 7460000 tags
# 2017-03-10 18:13:50,615 : INFO : Finished: 7470000 tags
# 2017-03-10 18:13:59,654 : INFO : Finished: 7480000 tags
# 2017-03-10 18:14:08,840 : INFO : Finished: 7490000 tags
# 2017-03-10 18:14:17,705 : INFO : Finished: 7500000 tags
# 2017-03-10 18:14:26,744 : INFO : Finished: 7510000 tags
# 2017-03-10 18:14:36,306 : INFO : Finished: 7520000 tags
# 2017-03-10 18:14:45,594 : INFO : Finished: 7530000 tags
# 2017-03-10 18:14:54,575 : INFO : Finished: 7540000 tags
# 2017-03-10 18:15:03,988 : INFO : Finished: 7550000 tags
# 2017-03-10 18:15:13,461 : INFO : Finished: 7560000 tags
# 2017-03-10 18:15:22,327 : INFO : Finished: 7570000 tags
# 2017-03-10 18:15:31,690 : INFO : Finished: 7580000 tags
# 2017-03-10 18:15:41,077 : INFO : Finished: 7590000 tags
# 2017-03-10 18:15:50,118 : INFO : Finished: 7600000 tags
# 2017-03-10 18:15:58,908 : INFO : Finished: 7610000 tags
# 2017-03-10 18:16:08,061 : INFO : Finished: 7620000 tags
# 2017-03-10 18:16:17,586 : INFO : Finished: 7630000 tags
# 2017-03-10 18:16:26,884 : INFO : Finished: 7640000 tags
# 2017-03-10 18:16:36,150 : INFO : Finished: 7650000 tags
# 2017-03-10 18:16:44,908 : INFO : Finished: 7660000 tags
# 2017-03-10 18:16:54,338 : INFO : Finished: 7670000 tags
# 2017-03-10 18:17:03,961 : INFO : Finished: 7680000 tags
# 2017-03-10 18:17:13,293 : INFO : Finished: 7690000 tags
# 2017-03-10 18:17:22,548 : INFO : Finished: 7700000 tags
# 2017-03-10 18:17:31,950 : INFO : Finished: 7710000 tags
# 2017-03-10 18:17:41,334 : INFO : Finished: 7720000 tags
# 2017-03-10 18:17:50,989 : INFO : Finished: 7730000 tags
# 2017-03-10 18:18:00,095 : INFO : Finished: 7740000 tags
# 2017-03-10 18:18:08,143 : INFO : Finished: 7750000 tags
# 2017-03-10 18:18:17,208 : INFO : Finished: 7760000 tags
# 2017-03-10 18:18:17,225 : INFO : New Doc: 24000, Batch End: 29674
# 2017-03-10 18:18:26,333 : INFO : Finished: 7770000 tags
# 2017-03-10 18:18:34,979 : INFO : Finished: 7780000 tags
# 2017-03-10 18:18:43,358 : INFO : Finished: 7790000 tags
# 2017-03-10 18:18:52,523 : INFO : Finished: 7800000 tags
# 2017-03-10 18:19:01,800 : INFO : Finished: 7810000 tags
# 2017-03-10 18:19:11,456 : INFO : Finished: 7820000 tags
# 2017-03-10 18:19:20,670 : INFO : Finished: 7830000 tags
# 2017-03-10 18:19:30,116 : INFO : Finished: 7840000 tags
# 2017-03-10 18:19:39,405 : INFO : Finished: 7850000 tags
# 2017-03-10 18:19:48,660 : INFO : Finished: 7860000 tags
# 2017-03-10 18:19:57,796 : INFO : Finished: 7870000 tags
# 2017-03-10 18:20:07,106 : INFO : Finished: 7880000 tags
# 2017-03-10 18:20:16,750 : INFO : Finished: 7890000 tags
# 2017-03-10 18:20:26,008 : INFO : Finished: 7900000 tags
# 2017-03-10 18:20:34,984 : INFO : Finished: 7910000 tags
# 2017-03-10 18:20:44,220 : INFO : Finished: 7920000 tags
# 2017-03-10 18:20:52,927 : INFO : Finished: 7930000 tags
# 2017-03-10 18:21:01,974 : INFO : Finished: 7940000 tags
# 2017-03-10 18:21:11,205 : INFO : Finished: 7950000 tags
# 2017-03-10 18:21:20,294 : INFO : Finished: 7960000 tags
# 2017-03-10 18:21:29,383 : INFO : Finished: 7970000 tags
# 2017-03-10 18:21:38,258 : INFO : Finished: 7980000 tags
# 2017-03-10 18:21:47,252 : INFO : Finished: 7990000 tags
# 2017-03-10 18:21:56,079 : INFO : Finished: 8000000 tags
# 2017-03-10 18:22:05,492 : INFO : Finished: 8010000 tags
# 2017-03-10 18:22:14,688 : INFO : Finished: 8020000 tags
# 2017-03-10 18:22:23,827 : INFO : Finished: 8030000 tags
# 2017-03-10 18:22:32,885 : INFO : Finished: 8040000 tags
# 2017-03-10 18:22:41,807 : INFO : Finished: 8050000 tags
# 2017-03-10 18:22:50,776 : INFO : Finished: 8060000 tags
# 2017-03-10 18:23:00,176 : INFO : Finished: 8070000 tags
# 2017-03-10 18:23:09,427 : INFO : Finished: 8080000 tags
# 2017-03-10 18:23:18,426 : INFO : Finished: 8090000 tags
# 2017-03-10 18:23:27,843 : INFO : Finished: 8100000 tags
# 2017-03-10 18:23:37,559 : INFO : Finished: 8110000 tags
# 2017-03-10 18:23:46,915 : INFO : Finished: 8120000 tags
# 2017-03-10 18:23:46,940 : INFO : New Doc: 25000, Batch End: 29674
# 2017-03-10 18:23:56,122 : INFO : Finished: 8130000 tags
# 2017-03-10 18:24:05,242 : INFO : Finished: 8140000 tags
# 2017-03-10 18:24:14,587 : INFO : Finished: 8150000 tags
# 2017-03-10 18:24:23,867 : INFO : Finished: 8160000 tags
# 2017-03-10 18:24:33,535 : INFO : Finished: 8170000 tags
# 2017-03-10 18:24:42,906 : INFO : Finished: 8180000 tags
# 2017-03-10 18:24:52,532 : INFO : Finished: 8190000 tags
# 2017-03-10 18:25:01,814 : INFO : Finished: 8200000 tags
# 2017-03-10 18:25:10,765 : INFO : Finished: 8210000 tags
# 2017-03-10 18:25:20,161 : INFO : Finished: 8220000 tags
# 2017-03-10 18:25:29,549 : INFO : Finished: 8230000 tags
# 2017-03-10 18:25:38,021 : INFO : Finished: 8240000 tags
# 2017-03-10 18:25:46,826 : INFO : Finished: 8250000 tags
# 2017-03-10 18:25:55,937 : INFO : Finished: 8260000 tags
# 2017-03-10 18:26:05,188 : INFO : Finished: 8270000 tags
# 2017-03-10 18:26:14,182 : INFO : Finished: 8280000 tags
# 2017-03-10 18:26:23,732 : INFO : Finished: 8290000 tags
# 2017-03-10 18:26:33,022 : INFO : Finished: 8300000 tags
# 2017-03-10 18:26:42,145 : INFO : Finished: 8310000 tags
# 2017-03-10 18:26:51,535 : INFO : Finished: 8320000 tags
# 2017-03-10 18:27:00,515 : INFO : Finished: 8330000 tags
# 2017-03-10 18:27:09,235 : INFO : Finished: 8340000 tags
# 2017-03-10 18:27:18,059 : INFO : Finished: 8350000 tags
# 2017-03-10 18:27:27,556 : INFO : Finished: 8360000 tags
# 2017-03-10 18:27:36,751 : INFO : Finished: 8370000 tags
# 2017-03-10 18:27:46,049 : INFO : Finished: 8380000 tags
# 2017-03-10 18:27:55,615 : INFO : Finished: 8390000 tags
# 2017-03-10 18:28:04,839 : INFO : Finished: 8400000 tags
# 2017-03-10 18:28:13,684 : INFO : Finished: 8410000 tags
# 2017-03-10 18:28:23,068 : INFO : Finished: 8420000 tags
# 2017-03-10 18:28:31,994 : INFO : Finished: 8430000 tags
# 2017-03-10 18:28:40,895 : INFO : Finished: 8440000 tags
# 2017-03-10 18:28:50,489 : INFO : Finished: 8450000 tags
# 2017-03-10 18:28:59,803 : INFO : Finished: 8460000 tags
# 2017-03-10 18:28:59,825 : INFO : New Doc: 26000, Batch End: 29674
# 2017-03-10 18:29:09,259 : INFO : Finished: 8470000 tags
# 2017-03-10 18:29:17,482 : INFO : Finished: 8480000 tags
# 2017-03-10 18:29:26,872 : INFO : Finished: 8490000 tags
# 2017-03-10 18:29:37,150 : INFO : Finished: 8500000 tags
# 2017-03-10 18:29:45,823 : INFO : Finished: 8510000 tags
# 2017-03-10 18:29:54,712 : INFO : Finished: 8520000 tags
# 2017-03-10 18:30:03,709 : INFO : Finished: 8530000 tags
# 2017-03-10 18:30:11,706 : INFO : Finished: 8540000 tags
# 2017-03-10 18:30:21,002 : INFO : Finished: 8550000 tags
# 2017-03-10 18:30:30,129 : INFO : Finished: 8560000 tags
# 2017-03-10 18:30:39,324 : INFO : Finished: 8570000 tags
# 2017-03-10 18:30:48,871 : INFO : Finished: 8580000 tags
# 2017-03-10 18:30:58,102 : INFO : Finished: 8590000 tags
# 2017-03-10 18:31:07,395 : INFO : Finished: 8600000 tags
# 2017-03-10 18:31:16,557 : INFO : Finished: 8610000 tags
# 2017-03-10 18:31:25,777 : INFO : Finished: 8620000 tags
# 2017-03-10 18:31:34,757 : INFO : Finished: 8630000 tags
# 2017-03-10 18:31:43,935 : INFO : Finished: 8640000 tags
# 2017-03-10 18:31:53,173 : INFO : Finished: 8650000 tags
# 2017-03-10 18:32:02,233 : INFO : Finished: 8660000 tags
# 2017-03-10 18:32:11,774 : INFO : Finished: 8670000 tags
# 2017-03-10 18:32:20,961 : INFO : Finished: 8680000 tags
# 2017-03-10 18:32:30,446 : INFO : Finished: 8690000 tags
# 2017-03-10 18:32:39,669 : INFO : Finished: 8700000 tags
# 2017-03-10 18:32:49,012 : INFO : Finished: 8710000 tags
# 2017-03-10 18:32:57,897 : INFO : Finished: 8720000 tags
# 2017-03-10 18:33:07,535 : INFO : Finished: 8730000 tags
# 2017-03-10 18:33:16,463 : INFO : Finished: 8740000 tags
# 2017-03-10 18:33:25,698 : INFO : Finished: 8750000 tags
# 2017-03-10 18:33:35,247 : INFO : Finished: 8760000 tags
# 2017-03-10 18:33:44,222 : INFO : Finished: 8770000 tags
# 2017-03-10 18:33:53,451 : INFO : Finished: 8780000 tags
# 2017-03-10 18:34:02,424 : INFO : Finished: 8790000 tags
# 2017-03-10 18:34:11,898 : INFO : Finished: 8800000 tags
# 2017-03-10 18:34:20,839 : INFO : Finished: 8810000 tags
# 2017-03-10 18:34:29,686 : INFO : Finished: 8820000 tags
# 2017-03-10 18:34:38,991 : INFO : Finished: 8830000 tags
# 2017-03-10 18:34:48,284 : INFO : Finished: 8840000 tags
# 2017-03-10 18:34:48,293 : INFO : New Doc: 27000, Batch End: 29674
# 2017-03-10 18:34:57,499 : INFO : Finished: 8850000 tags
# 2017-03-10 18:35:07,275 : INFO : Finished: 8860000 tags
# 2017-03-10 18:35:16,481 : INFO : Finished: 8870000 tags
# 2017-03-10 18:35:25,618 : INFO : Finished: 8880000 tags
# 2017-03-10 18:35:35,149 : INFO : Finished: 8890000 tags
# 2017-03-10 18:35:44,255 : INFO : Finished: 8900000 tags
# 2017-03-10 18:35:53,542 : INFO : Finished: 8910000 tags
# 2017-03-10 18:36:02,364 : INFO : Finished: 8920000 tags
# 2017-03-10 18:36:11,688 : INFO : Finished: 8930000 tags
# 2017-03-10 18:36:20,593 : INFO : Finished: 8940000 tags
# 2017-03-10 18:36:29,853 : INFO : Finished: 8950000 tags
# 2017-03-10 18:36:39,032 : INFO : Finished: 8960000 tags
# 2017-03-10 18:36:48,256 : INFO : Finished: 8970000 tags
# 2017-03-10 18:36:57,261 : INFO : Finished: 8980000 tags
# 2017-03-10 18:37:06,028 : INFO : Finished: 8990000 tags
# 2017-03-10 18:37:14,826 : INFO : Finished: 9000000 tags
# 2017-03-10 18:37:23,746 : INFO : Finished: 9010000 tags
# 2017-03-10 18:37:32,686 : INFO : Finished: 9020000 tags
# 2017-03-10 18:37:41,707 : INFO : Finished: 9030000 tags
# 2017-03-10 18:37:51,097 : INFO : Finished: 9040000 tags
# 2017-03-10 18:38:00,293 : INFO : Finished: 9050000 tags
# 2017-03-10 18:38:09,315 : INFO : Finished: 9060000 tags
# 2017-03-10 18:38:18,333 : INFO : Finished: 9070000 tags
# 2017-03-10 18:38:27,538 : INFO : Finished: 9080000 tags
# 2017-03-10 18:38:36,565 : INFO : Finished: 9090000 tags
# 2017-03-10 18:38:46,149 : INFO : Finished: 9100000 tags
# 2017-03-10 18:38:55,332 : INFO : Finished: 9110000 tags
# 2017-03-10 18:39:04,403 : INFO : Finished: 9120000 tags
# 2017-03-10 18:39:13,090 : INFO : Finished: 9130000 tags
# 2017-03-10 18:39:21,806 : INFO : Finished: 9140000 tags
# 2017-03-10 18:39:30,877 : INFO : Finished: 9150000 tags
# 2017-03-10 18:39:40,197 : INFO : Finished: 9160000 tags
# 2017-03-10 18:39:49,547 : INFO : Finished: 9170000 tags
# 2017-03-10 18:39:58,741 : INFO : Finished: 9180000 tags
# 2017-03-10 18:40:08,185 : INFO : Finished: 9190000 tags
# 2017-03-10 18:40:08,190 : INFO : New Doc: 28000, Batch End: 29674
# 2017-03-10 18:40:17,584 : INFO : Finished: 9200000 tags
# 2017-03-10 18:40:26,952 : INFO : Finished: 9210000 tags
# 2017-03-10 18:40:36,155 : INFO : Finished: 9220000 tags
# 2017-03-10 18:40:45,507 : INFO : Finished: 9230000 tags
# 2017-03-10 18:40:54,271 : INFO : Finished: 9240000 tags
# 2017-03-10 18:41:03,568 : INFO : Finished: 9250000 tags
# 2017-03-10 18:41:12,520 : INFO : Finished: 9260000 tags
# 2017-03-10 18:41:21,396 : INFO : Finished: 9270000 tags
# 2017-03-10 18:41:30,524 : INFO : Finished: 9280000 tags
# 2017-03-10 18:41:39,714 : INFO : Finished: 9290000 tags
# 2017-03-10 18:41:48,869 : INFO : Finished: 9300000 tags
# 2017-03-10 18:41:57,520 : INFO : Finished: 9310000 tags
# 2017-03-10 18:42:06,942 : INFO : Finished: 9320000 tags
# 2017-03-10 18:42:16,309 : INFO : Finished: 9330000 tags
# 2017-03-10 18:42:25,390 : INFO : Finished: 9340000 tags
# 2017-03-10 18:42:35,110 : INFO : Finished: 9350000 tags
# 2017-03-10 18:42:44,291 : INFO : Finished: 9360000 tags
# 2017-03-10 18:42:53,630 : INFO : Finished: 9370000 tags
# 2017-03-10 18:43:02,457 : INFO : Finished: 9380000 tags
# 2017-03-10 18:43:11,504 : INFO : Finished: 9390000 tags
# 2017-03-10 18:43:20,123 : INFO : Finished: 9400000 tags
# 2017-03-10 18:43:29,168 : INFO : Finished: 9410000 tags
# 2017-03-10 18:43:38,186 : INFO : Finished: 9420000 tags
# 2017-03-10 18:43:47,531 : INFO : Finished: 9430000 tags
# 2017-03-10 18:43:56,714 : INFO : Finished: 9440000 tags
# 2017-03-10 18:44:06,016 : INFO : Finished: 9450000 tags
# 2017-03-10 18:44:15,066 : INFO : Finished: 9460000 tags
# 2017-03-10 18:44:24,293 : INFO : Finished: 9470000 tags
# 2017-03-10 18:44:34,024 : INFO : Finished: 9480000 tags
# 2017-03-10 18:44:42,541 : INFO : Finished: 9490000 tags
# 2017-03-10 18:44:51,352 : INFO : Finished: 9500000 tags
# 2017-03-10 18:45:00,944 : INFO : Finished: 9510000 tags
# 2017-03-10 18:45:09,831 : INFO : Finished: 9520000 tags
# 2017-03-10 18:45:19,046 : INFO : Finished: 9530000 tags
# 2017-03-10 18:45:27,931 : INFO : Finished: 9540000 tags
# 2017-03-10 18:45:27,955 : INFO : New Doc: 29000, Batch End: 29674
# 2017-03-10 18:45:37,018 : INFO : Finished: 9550000 tags
# 2017-03-10 18:45:45,952 : INFO : Finished: 9560000 tags
# 2017-03-10 18:45:55,345 : INFO : Finished: 9570000 tags
# 2017-03-10 18:46:04,508 : INFO : Finished: 9580000 tags
# 2017-03-10 18:46:13,618 : INFO : Finished: 9590000 tags
# 2017-03-10 18:46:23,272 : INFO : Finished: 9600000 tags
# 2017-03-10 18:46:32,331 : INFO : Finished: 9610000 tags
# 2017-03-10 18:46:41,589 : INFO : Finished: 9620000 tags
# 2017-03-10 18:46:50,497 : INFO : Finished: 9630000 tags
# 2017-03-10 18:46:59,804 : INFO : Finished: 9640000 tags
# 2017-03-10 18:47:09,047 : INFO : Finished: 9650000 tags
# 2017-03-10 18:47:17,810 : INFO : Finished: 9660000 tags
# 2017-03-10 18:47:27,002 : INFO : Finished: 9670000 tags
# 2017-03-10 18:47:36,507 : INFO : Finished: 9680000 tags
# 2017-03-10 18:47:46,078 : INFO : Finished: 9690000 tags
# 2017-03-10 18:47:54,943 : INFO : Finished: 9700000 tags
# 2017-03-10 18:48:03,626 : INFO : Finished: 9710000 tags
# 2017-03-10 18:48:12,959 : INFO : Finished: 9720000 tags
# 2017-03-10 18:48:22,585 : INFO : Finished: 9730000 tags
# 2017-03-10 18:48:32,004 : INFO : Finished: 9740000 tags
# 2017-03-10 18:48:43,256 : INFO : Loading new batch for index: 29675
# 2017-03-10 18:48:43,262 : INFO : No more batches to load, exiting at index: 9749556
# 2017-03-10 18:48:52,429 : INFO : Finished: 9749557 tags
# 2017-03-10 18:48:52,435 : INFO : Finished: 9749557 tags
# CPU times: user 1d 21h 15min 54s, sys: 4h 16min 8s, total: 2d 1h 32min 2s
# Wall time: 18h 44min 39s
