# %%
import json
import nltk
from nltk.tokenize import RegexpTokenizer
import string
import math
import os
import time
from collections import namedtuple
import cPickle as pickle
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import random

from multiprocessing.dummy import Pool as ThreadPool
import itertools

from sklearn.metrics import coverage_error
import sklearn.metrics
from sklearn.multiclass import OneVsRestClassifier
from sklearn import linear_model
from sklearn.preprocessing import MultiLabelBinarizer

from gensim.models.doc2vec import Doc2Vec, LabeledSentence

import logging
from logging import info
from functools import partial

from thesis.utils.metrics import *

# %%
root = logging.getLogger()
for handler in root.handlers[:]:
    root.removeHandler(handler)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # adds a default StreamHanlder
#root.addHandler(logging.StreamHandler())

# %%
IS_SAMPLE = False

# %%
SVM_SEED = 1234
DOC2VEC_SEED = 1234
WORD2VEC_SEED = 1234

# %%
NUMBER_INDICATOR = "number_inidicator"
CURRENCY_INDICATOR = "currency_inidicator"
CHEMICAL_INDICATOR = "chemical_inidicator"
MIN_WORD_COUNT = 100
MIN_SIZE = 0
NUM_CORES = 24

# %%
GLOBAL_VARS = namedtuple('GLOBAL_VARS', ['MODEL_NAME', 'DOC2VEC_MODEL_NAME', 'DOC2VEC_MODEL', 
                                         'SVM_MODEL_NAME', 'NN_MODEL_NAME'])

# %%
VOCAB_MODEL = "vocab_model"
MODEL_PREFIX = "model"
VALIDATION_MATRIX = "validation_matrix.pkl"
METRICS = "metrics.pkl"
CLASSIFIER = "classifier.pkl"

# %%
#training_file = "/home/local/shalaby/docs_output_sample_100.json"

root_location = "/big/s/shalaby/"
exports_location = root_location + "exported_data/"

doc2vec_model_save_location = os.path.join(root_location, "parameter_search_doc2vec_models_new", "full")
if not os.path.exists(doc2vec_model_save_location):
    os.makedirs(doc2vec_model_save_location)
if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL)):
    os.makedirs(os.path.join(doc2vec_model_save_location, VOCAB_MODEL))

training_file = root_location + "docs_output.json"

doc_classifications_map_file = exports_location + "doc_classification_map.pkl"
sections_file = exports_location + "sections.pkl"
classes_file = exports_location + "classes.pkl"
subclasses_file = exports_location + "subclasses.pkl"
classifications_output = exports_location + "classifications.pkl"
training_docs_list_file = exports_location + "training_docs_list.pkl"
validation_docs_list_file = exports_location + "validation_docs_list.pkl"
test_docs_list_file = exports_location + "test_docs_list.pkl"

preprocessed_location = root_location + "preprocessed_data/"

training_preprocessed_files_prefix = preprocessed_location + "training_docs_merged_data_preprocessed-"
training_preprocessed_docids_files_prefix = preprocessed_location + "training_docs_merged_docids_preprocessed-"
validation_preprocessed_files_prefix = preprocessed_location + "validation_docs_merged_data_preprocessed-"
validation_preprocessed_docids_files_prefix = preprocessed_location + "validation_docs_merged_docids_preprocessed-"

word2vec_questions_file = result = root_location + 'tensorflow/word2vec/questions-words.txt'

# %%
# %%time
doc_classification_map = pickle.load(open(doc_classifications_map_file))
sections = pickle.load(open(sections_file))
classes = pickle.load(open(classes_file))
subclasses = pickle.load(open(subclasses_file))
training_docs_list = pickle.load(open(training_docs_list_file))
validation_docs_list = pickle.load(open(validation_docs_list_file))
#test_docs_list = pickle.load(open(test_docs_list_file))
# Out:
# CPU times: user 27.9 s, sys: 1.07 s, total: 28.9 s
# Wall time: 29.1 s

# %%
len(training_docs_list)
# Out:
# 1286325

# %%
len(validation_docs_list)
# Out:
# 321473

# %%
def stemtokenizer(text):
    """ MAIN FUNCTION to get clean stems out of a text. A list of clean stems are returned """
    tokenizer = RegexpTokenizer(r'\s+', gaps=True)
    tokens = tokenizer.tokenize(text)
    stems = []  # result
    for token in tokens:
        stem = token.lower()
        stem = stem.strip(string.punctuation)
        if stem:
            if is_number(stem):
                stem = NUMBER_INDICATOR
            elif is_currency(stem):
                stem = CURRENCY_INDICATOR
            elif is_chemical(stem):
                stem = CHEMICAL_INDICATOR
            else:
                stem = stem.strip(string.punctuation)
            if stem and len(stem) >= MIN_SIZE:
                # extract uni-grams
                stems.append(stem)
    del tokens
    return stems

def is_number(str):
    """ Returns true if given string is a number (float or int)"""
    try:
        float(str.replace(",", ""))
        return True
    except ValueError:
        return False

def is_currency(str):
    return str[0] == "$"

def is_chemical(str):
    return str.count("-") > 3

# %%
def ensure_disk_location_exists(location):
    if not os.path.exists(location):
        os.makedirs(location)

# %%
def get_validation_docs_with_inference(doc2vec_model, doc_classification_map):
    """
    Use the trained doc2vec model to get the paragraph vector representations of the validation documents
    """
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX)):
        info("===== Loading validation vectors")
        validation_vectors_matrix = pickle.load(open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX)))
    else:
        validation_documents_reps = {}
        validation_vectors = []
        validation_labels = []
        info("===== Getting validation vectors with inference")

        # do inference and store results in dict
        i = 0
        for (doc_id, doc_contents_array) in ValidationDocumentGenerator(training_file, validation_docs_list):
            i += 1
            if i % 1000 == 0: info("Finished: {}".format(str(i)))
            validation_documents_reps[doc_id] = doc2vec_model.infer_vector(doc_contents_array)

        # create matrix for the validation vectors
        for validation_doc_id in validation_docs_list:
            validation_vectors.append(validation_documents_reps[validation_doc_id])
            validation_labels.append([classf for classf in doc_classification_map[validation_doc_id] if classf in sections])
        validation_vectors_matrix = np.array(validation_vectors)
        pickle.dump(validation_vectors_matrix, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX), 'w'))
    
    return validation_vectors_matrix

# %%
def get_validation_docs_with_inference_new(doc2vec_model, doc_classification_map, classifications, 
                                           val_docs_list, val_preprocessed_files_prefix, val_preprocessed_docids_files_prefix):
    """
    Use the trained doc2vec model to get the paragraph vector representations of the validation documents
    """

    def infer_one_doc(doc_tuple):
        #doc2vec_model.random = np.random.RandomState(DOC2VEC_SEED)
        doc_id, doc_tokens = doc_tuple
        rep = doc2vec_model.infer_vector(doc_tokens)
        return (doc_id, rep)

    one_hot_encoder = OneHotEncoder(classifications)
    classifications_set = set(classifications)
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX)):
        info("===== Loading validation vectors")
        validation_labels = []
        validation_vectors_matrix = pickle.load(open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX)))
        for validation_doc_id in val_docs_list:
            val_labels = set(doc_classification_map[validation_doc_id]) & classifications_set
            validation_labels.append(one_hot_encoder.get_label_vector(val_labels))
        validation_labels = np.array(validation_labels, dtype=np.int8)
    else:
        validation_documents_reps = {}
        validation_vectors = []
        validation_labels = []
        info("===== Getting validation vectors with inference")

        # Single-threaded inference
        # do inference and store results in dict
#         i = 0
        
#         validation_docs_iterator = DocumentBatchGenerator(val_preprocessed_files_prefix, 
#                                                         val_preprocessed_docids_files_prefix, batch_size=None)
#         for (doc_id, doc_contents_array) in validation_docs_iterator:
#             i += 1
#             if i % 1000 == 0: info("Finished: {}".format(str(i)))
#             validation_documents_reps[doc_id] = doc2vec_model.infer_vector(doc_contents_array)
        
        # Multi-threaded inference
        validation_docs_iterator = DocumentBatchGenerator(validation_preprocessed_files_prefix, 
                                                          validation_preprocessed_docids_files_prefix, batch_size=None)
        generator_func = validation_docs_iterator.__iter__()
        pool = ThreadPool(NUM_CORES)
        # map consumes the whole iterator on the spot, so we have to use itertools.islice to fake mini-batching
        validation_documents_reps = {}
        mini_batch_size = 1000
        while True:
            threaded_reps_partial = pool.map(infer_one_doc, itertools.islice(generator_func, mini_batch_size))
            info("Finished: {}".format(str(validation_docs_iterator.curr_index)))
            if threaded_reps_partial:
                #threaded_reps.extend(threaded_reps_partial)
                validation_documents_reps.update(threaded_reps_partial)
            else:
                break

                
        # create matrix for the validation vectors
        for validation_doc_id in val_docs_list:
            validation_vectors.append(validation_documents_reps[validation_doc_id])
            val_labels = set(doc_classification_map[validation_doc_id]) & classifications_set
            validation_labels.append(one_hot_encoder.get_label_vector(val_labels))
        validation_vectors_matrix = np.array(validation_vectors, dtype=np.int8)
        validation_labels = np.array(validation_labels)
        pickle.dump(validation_vectors_matrix, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, VALIDATION_MATRIX), 'w'))
    
    return validation_vectors_matrix, validation_labels

# %%
class OneHotEncoder():
    
    def __init__(self, classifications):
        self.classifications = classifications
        self.one_hot_indices = {}

        # convert character classifications to bit vectors
        for i, clssf in enumerate(classifications):
            bits = [0] * len(classifications)
            bits[i] = 1
            self.one_hot_indices[clssf] = i
    
    def get_label_vector(self, labels):
        """
        classes: array of string with the classes assigned to the instance
        """
        output_vector = [0] * len(self.classifications)
        for label in labels:
            index = self.one_hot_indices[label]
            output_vector[index] = 1
            
        return output_vector

def get_training_data(doc2vec_model, classifications):
    one_hot_encoder = OneHotEncoder(classifications)
    classifications_set = set(classifications)
    training_data = []
    training_labels_mat = np.zeros((len(training_docs_list), len(classifications)), dtype=np.int8)
    for i,doc_id in enumerate(training_docs_list):
        normal_array = doc2vec_model.docvecs[doc_id]
        training_data.append(normal_array)
        eligible_classifications = set(doc_classification_map[doc_id]) & classifications_set
        training_labels_mat[i][:] = one_hot_encoder.get_label_vector(eligible_classifications)
        if i % 100000 == 0:
            info("Finished {} in training".format(i))
    info("doing matrix creation")
    training_data_mat = np.array(training_data)
    del training_data
    return training_data_mat, training_labels_mat

# %%
class TrainingDocumentGenerator(object):
    def __init__(self, filename, training_docs_list):
        self.filename = filename
        self.training_docs_list = training_docs_list
    def __iter__(self):
        with open(self.filename) as file_obj:
            for line in file_obj:
                if not line.strip(): continue
                (doc_id, text) = eval(line)
                if doc_id in self.training_docs_list:
                    yield LabeledSentence(words=stemtokenizer(text), tags=[doc_id])
                    
class DocumentBatchGenerator(object):
    def __init__(self, filename_prefix, filename_docids_prefix, batch_size=10000 ):
        """
        batch_size cant be > 10,000 due to a limitation in doc2vec training, 
        None means no batching (only use for inference)
        """
        assert batch_size <= 10000 or batch_size is None
        self.filename_prefix = filename_prefix
        self.filename_docids_prefix = filename_docids_prefix
        self.curr_lines = []
        self.curr_docids = []
        self.batch_size = batch_size
        self.curr_index = 0
        self.batch_end = -1
    def load_new_batch_in_memory(self):
        del self.curr_lines, self.curr_docids
        self.curr_lines, self.curr_docids = [], []
        info("Loading new batch for index: {}".format(self.curr_index) )
        try:
            with open(self.filename_prefix + str(self.curr_index)) as preproc_file:
                for line in preproc_file:
                    self.curr_lines.append(line.split(" "))
#                     if i % 1000 == 0:
#                         print i
            self.curr_docids = pickle.load(open(self.filename_docids_prefix + str(self.curr_index), "r"))
            self.batch_end = self.curr_index + len(self.curr_lines) -1 
            info("Finished loading new batch")
        except IOError:
            info("No more batches to load, exiting at index: {}".format(self.curr_index))
            raise StopIteration()
    def __iter__(self):
        while True:
            if self.curr_index > self.batch_end:
                self.load_new_batch_in_memory()
            for (doc_id, tokens) in zip(self.curr_docids, self.curr_lines):
                if self.batch_size is not None:
                    curr_batch_iter = 0
                    # divide the document to batches according to the batch size
                    while curr_batch_iter < len(tokens):
                        yield LabeledSentence(words=tokens[curr_batch_iter: curr_batch_iter + self.batch_size], tags=[doc_id])
                        curr_batch_iter += self.batch_size
                else:
                    yield doc_id, tokens
                self.curr_index += 1

class Word2VecTrainingDocumentGenerator(object):
    def __init__(self, filename, training_docs_list):
        self.filename = filename
        self.training_docs_list = training_docs_list
    def __iter__(self):
        with open(self.filename) as file_obj:
            for line in file_obj:
                if not line.strip(): continue
                (doc_id, text) = eval(line)
                if doc_id in self.training_docs_list:
                    yield stemtokenizer(text)
                
class ValidationDocumentGenerator(object):
    def __init__(self, filename, validation_docs_list):
        self.filename = filename
        self.validation_docs_list = validation_docs_list
    def __iter__(self):
        with open(self.filename) as file_obj:
            for line in file_obj:
                if not line.strip(): continue
                (doc_id, text) = eval(line)
                if doc_id in self.validation_docs_list:
                    yield doc_id, stemtokenizer(text)
                    
class StochasticDocumentGenerator(object):
    """
    Randomly shuffle rows while reading them
    """
    def __init__(self, filename, training_docs_list, line_positions):
        self.filename = filename
        self.training_docs_list = training_docs_list
        self.line_positions = line_positions
        self.lines = set(line_positions.keys())
    def __iter__(self):
        with open(self.filename) as file_obj:
            while len(self.lines) > 0:
                random_line = random.sample(self.lines,1)[0]
                self.lines.remove(random_line)
                file_obj.seek(self.line_positions[random_line])
                line = file_obj.readline()
                if not line.strip(): continue
#                 print random_line, self.line_positions[random_line], line[:30]
                (doc_id, text) = eval(line)
                # print random_line , doc_id
                if doc_id in self.training_docs_list:
                    yield LabeledSentence(words=stemtokenizer(text), tags=[doc_id])
#                     yield doc_id

# %% [markdown]
# ### Doc2vec and SVM Parameters

# %%
DOC2VEC_SIZE = 300
DOC2VEC_WINDOW = 2
DOC2VEC_MAX_VOCAB_SIZE = None
DOC2VEC_SAMPLE = 1e-3
DOC2VEC_TYPE = 1
DOC2VEC_HIERARCHICAL_SAMPLE = 0
DOC2VEC_NEGATIVE_SAMPLE_SIZE = 10
DOC2VEC_CONCAT = 0
DOC2VEC_MEAN = 1
DOC2VEC_TRAIN_WORDS = 0
DOC2VEC_EPOCHS = 1 # we do our training manually one epoch at a time
DOC2VEC_MAX_EPOCHS = 20
REPORT_DELAY = 20 # report the progress every x seconds
REPORT_VOCAB_PROGRESS = 10000 # report vocab progress every x documents

# %%
SVM_ITERATIONS = 10
SVM_CONVERGENCE = 0.001
SVM_REG = 0.001
SVM_CLASS_WEIGHTS = None
GLOBAL_VARS.SVM_MODEL_NAME = 'svm_iter_{}_reg_{}_classweights_{}'.format(SVM_ITERATIONS, SVM_REG, str(SVM_CLASS_WEIGHTS))

# %%
def get_svm_model_path(method, classification, reg=SVM_REG, iterations=SVM_ITERATIONS):
    location = os.path.join(save_parent_location, "models", method, 
                            "iter_" + str(iterations) + "_reg_" + str(reg),
                            classification + "_model.svm")
    ensure_hdfs_location_exists(location)
    return location

# %% [markdown]
# ## Create the Doc2vec model

# %%
placeholder_model_name = 'doc2vec_size_{}_w_{}_type_{}_concat_{}_mean_{}_trainwords_{}_hs_{}_neg_{}_vocabsize_{}'.format(DOC2VEC_SIZE, 
                                                                DOC2VEC_WINDOW, 
                                                                'dm' if DOC2VEC_TYPE == 1 else 'pv-dbow',
                                                                DOC2VEC_CONCAT, DOC2VEC_MEAN,
                                                                DOC2VEC_TRAIN_WORDS,
                                                                DOC2VEC_HIERARCHICAL_SAMPLE,DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                                                                str(DOC2VEC_MAX_VOCAB_SIZE))
GLOBAL_VARS.DOC2VEC_MODEL_NAME = placeholder_model_name
placeholder_model_name = os.path.join(placeholder_model_name, "epoch_{}")
placeholder_model_name
# Out:
# 'doc2vec_size_300_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_{}'

# %%
doc2vec_model = Doc2Vec(size=DOC2VEC_SIZE , window=DOC2VEC_WINDOW, min_count=MIN_WORD_COUNT, 
                max_vocab_size= DOC2VEC_MAX_VOCAB_SIZE,
                sample=DOC2VEC_SAMPLE, seed=DOC2VEC_SEED, workers=NUM_CORES,
                # doc2vec algorithm dm=1 => PV-DM, dm=2 => PV-DBOW, PV-DM dictates CBOW for words
                dm=DOC2VEC_TYPE,
                # hs=0 => negative sampling, hs=1 => hierarchical softmax
                hs=DOC2VEC_HIERARCHICAL_SAMPLE, negative=DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                dm_concat=DOC2VEC_CONCAT,
                # 0 for sum, 1 for mean
#                 dm_mean=0 if DOC2VEC_MEAN != 2 else 1,
                # would train words with skip-gram on top of cbow, we don't need that for now
                dbow_words=DOC2VEC_TRAIN_WORDS,
                iter=DOC2VEC_EPOCHS)

GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model

# %%
# %%time
training_docs_iterator = DocumentBatchGenerator(training_preprocessed_files_prefix, 
                                                        training_preprocessed_docids_files_prefix, batch_size=10000)
if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX)):
    doc2vec_model.build_vocab(sentences=training_docs_iterator, progress_per=REPORT_VOCAB_PROGRESS)
    doc2vec_model.save(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
else:
    doc2vec_model_vocab_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
    doc2vec_model.reset_from(doc2vec_model_vocab_model)
# Out:
# 2017-03-03 10:41:38,824 : INFO : loading Doc2Vec object from /big/s/shalaby/parameter_search_doc2vec_models_new/full/vocab_model/model
# 2017-03-03 10:41:48,106 : INFO : loading docvecs recursively from /big/s/shalaby/parameter_search_doc2vec_models_new/full/vocab_model/model.docvecs.* with mmap=None
# 2017-03-03 10:41:48,107 : INFO : loading doctag_syn0 from /big/s/shalaby/parameter_search_doc2vec_models_new/full/vocab_model/model.docvecs.doctag_syn0.npy with mmap=None
# 2017-03-03 10:41:52,116 : INFO : loading syn1neg from /big/s/shalaby/parameter_search_doc2vec_models_new/full/vocab_model/model.syn1neg.npy with mmap=None
# 2017-03-03 10:42:11,927 : INFO : loading syn0 from /big/s/shalaby/parameter_search_doc2vec_models_new/full/vocab_model/model.syn0.npy with mmap=None
# 2017-03-03 10:42:13,055 : INFO : setting ignored attribute syn0norm to None
# 2017-03-03 10:42:13,056 : INFO : setting ignored attribute cum_table to None
# 2017-03-03 10:42:14,307 : INFO : resetting layer weights
# CPU times: user 1min 5s, sys: 4.1 s, total: 1min 9s
# Wall time: 1min 32s

# %%
# vocab_counts = {k:doc2vec_model.vocab[k].count for k in doc2vec_model.vocab.keys()}
# dd = sorted(vocab_counts, key=vocab_counts.get)

# %% [markdown]
# ## Actual Training, validation and Metrics Loop

# %%
doc2vec_model.alpha = 0.025
doc2vec_model.min_alpha = 0.025
DOC2VEC_ALPHA_DECREASE = 0.001
epoch_validation_metrics = []
epoch_training_metrics = []
epoch_word2vec_metrics = []
classifications = sections
classifications_type = 'sections'

# %%
VALIDATION_METRICS_FILENAME= '{}_validation_metrics.pkl'.format(classifications_type)
TRAINING_METRICS_FILENAME = '{}_training_metrics.pkl'.format(classifications_type)
METRICS_FIG_PNG_FILENAME = '{}_validation_metrics.png'.format(classifications_type)
METRICS_FIG_PDF_FILENAME = '{}_validation_metrics.pdf'.format(classifications_type)
WORD2VEC_METRICS_FILENAME = 'word2vec_metrics.pkl'

# for epoch in range(DOC2VEC_MAX_EPOCHS):
#     GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)
#     ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
#                                              GLOBAL_VARS.SVM_MODEL_NAME))
#     pickle.dump(metrics, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, GLOBAL_VARS.SVM_MODEL_NAME, METRICS), 'w'))
# fig_save_location = placeholder_model_name.format('run')
# plt.savefig(os.path.join(fig_save_location))

# %%
# %%time
# %matplotlib notebook
graph = MetricsGraph()
graph.init_graph(len(classifications) +2)
# when resuming, resume from an epoch with a previously created doc2vec model to get the learning rate right
start_from = 1
for epoch in range(start_from, DOC2VEC_MAX_EPOCHS+1):
    GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)
    info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))
    
    # if we have the model, just load it, otherwise train the previous model
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):
        doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
    else:
        # train the doc2vec model
        training_docs_iterator = DocumentBatchGenerator(training_preprocessed_files_prefix, 
                                                        training_preprocessed_docids_files_prefix, batch_size=10000)
        doc2vec_model.train(sentences=training_docs_iterator, report_delay=REPORT_DELAY)
        doc2vec_model.alpha -= DOC2VEC_ALPHA_DECREASE  # decrease the learning rate
        doc2vec_model.min_alpha = doc2vec_model.alpha  # fix the learning rate, no decay
        ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))
        doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
        
        # get the word2vec analogy accuracy score
        word2vec_result = doc2vec_model.accuracy(word2vec_questions_file, restrict_vocab=None)
        epoch_word2vec_metrics.append(word2vec_result)
        pickle.dump(word2vec_result, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME,
                                                       WORD2VEC_METRICS_FILENAME), 'w'))


    ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
                                             GLOBAL_VARS.SVM_MODEL_NAME))
    
    if not os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
                                                          GLOBAL_VARS.SVM_MODEL_NAME, CLASSIFIER)):

        info('Getting training Data')
        X, y = get_training_data(doc2vec_model, classifications)
        
        info('Training Classifier')
        clf = OneVsRestClassifier(linear_model.SGDClassifier(loss='hinge', penalty='l2', 
                                                             #alpha is the 1/nC parameter
                                                             alpha=SVM_REG, fit_intercept=True, n_iter=SVM_ITERATIONS,
                                                             #n_jobs=-1 means use all cpus
                                                             shuffle=True, verbose=0, n_jobs=1,
                                                             #eta0 is the learning rate when we use constant configuration
                                                             random_state=SVM_SEED, learning_rate='optimal', eta0=0.0, 
                                                             class_weight=SVM_CLASS_WEIGHTS, warm_start=False), n_jobs=1)


        # Training of a classifier
        clf.fit(X,y)
        pickle.dump(clf, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
                                                              GLOBAL_VARS.SVM_MODEL_NAME, CLASSIFIER), 'w'))
        
    #     # Training Metrics
    #     info('Evaluating on Training Data')
    #     yp = clf.predict(X)
    #     yp_score = clf.decision_function(X)
    #     print yp
    #     training_metrics = get_metrics(y, yp_score, yp)
    #     print "** Training Metrics: Cov Err: {:.3f}, Avg Labels: {:.3f}, \n\t\t Top 1: {:.3f}, Top 3: {:.3f}, Top 5: {:.3f}, \n\t\t F1 Micro: {:.3f}, F1 Macro: {:.3f}, Total Pos: {:,d}".format(
    #         training_metrics['coverage_error'], training_metrics['average_num_of_labels'], 
    #         training_metrics['top_1'], training_metrics['top_3'], training_metrics['top_5'], 
    #         training_metrics['f1_micro'], training_metrics['f1_macro'], training_metrics['total_positive'])

    #     epoch_training_metrics.append(training_metrics)
          # Saving the metrics
    #     pickle.dump(training_metrics, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
    #                                                           GLOBAL_VARS.SVM_MODEL_NAME, TRAINING_METRICS_FILENAME), 'w'))
        del X, y

    else:
        info('Loading Classifier')
        clf = pickle.load(open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
                                                          GLOBAL_VARS.SVM_MODEL_NAME, CLASSIFIER), 'r'))

    # Validation Metrics
    info('Getting Validation Embeddings')
    Xv, yv = get_validation_docs_with_inference_new(doc2vec_model, doc_classification_map, classifications, 
                                                    validation_docs_list, validation_preprocessed_files_prefix,
                                                    validation_preprocessed_docids_files_prefix)
    info('Evaluating on Validation Data')
    yvp = clf.predict(Xv)
    yvp_score = clf.decision_function(Xv)
    print yvp
    validation_metrics = get_metrics(yv, yvp_score, yvp)
    print "** Validation Metrics: Cov Err: {:.3f}, Avg Labels: {:.3f}, \n\t\t Top 1: {:.3f}, Top 3: {:.3f}, Top 5: {:.3f}, \n\t\t F1 Micro: {:.3f}, F1 Macro: {:.3f}, Total Pos: {:,d}".format(
        validation_metrics['coverage_error'], validation_metrics['average_num_of_labels'], 
        validation_metrics['top_1'], validation_metrics['top_3'], validation_metrics['top_5'], 
        validation_metrics['f1_micro'], validation_metrics['f1_macro'], validation_metrics['total_positive'])
    
    graph.add_metrics_to_graph(validation_metrics, epoch)
    
    epoch_validation_metrics.append(validation_metrics)
    
    
    # Saving the metrics
#     pickle.dump(training_metrics, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
#                                                           GLOBAL_VARS.SVM_MODEL_NAME, TRAINING_METRICS_FILENAME), 'w'))
    pickle.dump(validation_metrics, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, 
                                                          GLOBAL_VARS.SVM_MODEL_NAME, VALIDATION_METRICS_FILENAME), 'w'))
# Out:
# <img src="data:image/png;base64,...">
# 2017-03-03 10:44:59,102 : INFO : ****************** Epoch 1 --- Working on doc2vec_size_300_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_1 *******************
# 2017-03-03 10:44:59,104 : INFO : training model with 24 workers on 391521 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=10
# 2017-03-03 10:44:59,105 : INFO : expecting 1651226 sentences, matching count from corpus used for vocabulary survey
# 2017-03-03 10:44:59,116 : INFO : Loading new batch for index: 0
# 2017-03-03 10:45:11,081 : INFO : Finished loading new batch
# 2017-03-03 10:45:11,913 : INFO : PROGRESS: at 0.00% examples, 208 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 10:45:31,919 : INFO : PROGRESS: at 0.12% examples, 257045 words/s, in_qsize 45, out_qsize 0
# 2017-03-03 10:45:51,919 : INFO : PROGRESS: at 0.26% examples, 351990 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:46:11,925 : INFO : PROGRESS: at 0.43% examples, 412393 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:46:31,931 : INFO : PROGRESS: at 0.61% examples, 454208 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 10:46:53,946 : INFO : Loading new batch for index: 10000
# 2017-03-03 10:46:53,977 : INFO : PROGRESS: at 0.78% examples, 467615 words/s, in_qsize 43, out_qsize 10
# 2017-03-03 10:47:05,810 : INFO : Finished loading new batch
# 2017-03-03 10:47:13,982 : INFO : PROGRESS: at 0.84% examples, 430442 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:47:33,984 : INFO : PROGRESS: at 1.01% examples, 449227 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 10:47:53,992 : INFO : PROGRESS: at 1.18% examples, 464588 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:48:14,008 : INFO : PROGRESS: at 1.38% examples, 486860 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:48:34,902 : INFO : Loading new batch for index: 20000
# 2017-03-03 10:48:34,903 : INFO : PROGRESS: at 1.56% examples, 496726 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:48:45,895 : INFO : Finished loading new batch
# 2017-03-03 10:48:54,904 : INFO : PROGRESS: at 1.64% examples, 477695 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 10:49:14,915 : INFO : PROGRESS: at 1.86% examples, 496773 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:49:34,915 : INFO : PROGRESS: at 2.06% examples, 511750 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:49:54,925 : INFO : PROGRESS: at 2.27% examples, 526453 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:50:03,811 : INFO : Loading new batch for index: 30000
# 2017-03-03 10:50:13,611 : INFO : Finished loading new batch
# 2017-03-03 10:50:15,476 : INFO : PROGRESS: at 2.34% examples, 507055 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:50:35,482 : INFO : PROGRESS: at 2.51% examples, 509854 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 10:50:55,535 : INFO : PROGRESS: at 2.66% examples, 512069 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:51:15,544 : INFO : PROGRESS: at 2.82% examples, 514090 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:51:35,579 : INFO : PROGRESS: at 2.98% examples, 515898 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:51:54,079 : INFO : Loading new batch for index: 40000
# 2017-03-03 10:52:07,328 : INFO : Finished loading new batch
# 2017-03-03 10:52:07,654 : INFO : PROGRESS: at 3.12% examples, 497761 words/s, in_qsize 14, out_qsize 0
# 2017-03-03 10:52:27,661 : INFO : PROGRESS: at 3.29% examples, 500646 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 10:52:47,669 : INFO : PROGRESS: at 3.46% examples, 504438 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 10:53:07,673 : INFO : PROGRESS: at 3.64% examples, 508543 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:53:27,674 : INFO : PROGRESS: at 3.82% examples, 512499 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:53:37,302 : INFO : Loading new batch for index: 50000
# 2017-03-03 10:53:50,373 : INFO : Finished loading new batch
# 2017-03-03 10:53:50,926 : INFO : PROGRESS: at 3.89% examples, 498356 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 10:54:10,934 : INFO : PROGRESS: at 4.06% examples, 502503 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 10:54:30,939 : INFO : PROGRESS: at 4.24% examples, 507365 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:54:50,941 : INFO : PROGRESS: at 4.43% examples, 512159 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:55:10,956 : INFO : PROGRESS: at 4.62% examples, 517070 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:55:21,026 : INFO : Loading new batch for index: 60000
# 2017-03-03 10:55:32,132 : INFO : Finished loading new batch
# 2017-03-03 10:55:32,894 : INFO : PROGRESS: at 4.68% examples, 506755 words/s, in_qsize 1, out_qsize 0
# 2017-03-03 10:55:52,900 : INFO : PROGRESS: at 4.86% examples, 509970 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:56:12,922 : INFO : PROGRESS: at 5.03% examples, 512596 words/s, in_qsize 46, out_qsize 3
# 2017-03-03 10:56:32,931 : INFO : PROGRESS: at 5.20% examples, 514748 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 10:56:52,939 : INFO : PROGRESS: at 5.37% examples, 516413 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:57:07,945 : INFO : Loading new batch for index: 70000
# 2017-03-03 10:57:19,613 : INFO : Finished loading new batch
# 2017-03-03 10:57:20,974 : INFO : PROGRESS: at 5.47% examples, 506007 words/s, in_qsize 11, out_qsize 0
# 2017-03-03 10:57:40,995 : INFO : PROGRESS: at 5.66% examples, 509559 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 10:58:01,013 : INFO : PROGRESS: at 5.89% examples, 515179 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 10:58:21,017 : INFO : PROGRESS: at 6.09% examples, 520456 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 10:58:37,847 : INFO : Loading new batch for index: 80000
# 2017-03-03 10:58:47,680 : INFO : Finished loading new batch
# 2017-03-03 10:58:48,908 : INFO : PROGRESS: at 6.25% examples, 515790 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 10:59:08,913 : INFO : PROGRESS: at 6.47% examples, 520195 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 10:59:28,931 : INFO : PROGRESS: at 6.69% examples, 524515 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 10:59:48,956 : INFO : PROGRESS: at 6.88% examples, 527571 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 11:00:06,428 : INFO : Loading new batch for index: 90000
# 2017-03-03 11:00:18,808 : INFO : Finished loading new batch
# 2017-03-03 11:00:18,884 : INFO : PROGRESS: at 7.01% examples, 520699 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:00:38,884 : INFO : PROGRESS: at 7.21% examples, 523765 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:00:58,896 : INFO : PROGRESS: at 7.42% examples, 528394 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:01:18,917 : INFO : PROGRESS: at 7.63% examples, 532910 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:01:35,640 : INFO : Loading new batch for index: 100000
# 2017-03-03 11:01:46,505 : INFO : Finished loading new batch
# 2017-03-03 11:01:51,775 : INFO : PROGRESS: at 7.79% examples, 526143 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 11:02:11,778 : INFO : PROGRESS: at 7.98% examples, 528125 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 11:02:31,788 : INFO : PROGRESS: at 8.17% examples, 530169 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:02:51,793 : INFO : PROGRESS: at 8.35% examples, 531704 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:03:11,800 : INFO : PROGRESS: at 8.53% examples, 533170 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:03:17,958 : INFO : Loading new batch for index: 110000
# 2017-03-03 11:03:30,393 : INFO : Finished loading new batch
# 2017-03-03 11:03:31,817 : INFO : PROGRESS: at 8.57% examples, 525797 words/s, in_qsize 48, out_qsize 7
# 2017-03-03 11:03:51,833 : INFO : PROGRESS: at 8.77% examples, 528406 words/s, in_qsize 48, out_qsize 3
# 2017-03-03 11:04:11,830 : INFO : PROGRESS: at 8.99% examples, 531645 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 11:04:31,847 : INFO : PROGRESS: at 9.21% examples, 535092 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:04:44,985 : INFO : Loading new batch for index: 120000
# 2017-03-03 11:04:55,769 : INFO : Finished loading new batch
# 2017-03-03 11:04:56,507 : INFO : PROGRESS: at 9.32% examples, 530626 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:05:16,511 : INFO : PROGRESS: at 9.51% examples, 532132 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:05:36,515 : INFO : PROGRESS: at 9.70% examples, 533777 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:05:56,543 : INFO : PROGRESS: at 9.86% examples, 534684 words/s, in_qsize 46, out_qsize 4
# 2017-03-03 11:06:16,587 : INFO : PROGRESS: at 10.04% examples, 535769 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:06:27,883 : INFO : Loading new batch for index: 130000
# 2017-03-03 11:06:39,381 : INFO : Finished loading new batch
# 2017-03-03 11:06:40,583 : INFO : PROGRESS: at 10.11% examples, 529641 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:07:00,599 : INFO : PROGRESS: at 10.28% examples, 530681 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 11:07:20,612 : INFO : PROGRESS: at 10.47% examples, 532383 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 11:07:40,654 : INFO : PROGRESS: at 10.65% examples, 533880 words/s, in_qsize 45, out_qsize 3
# 2017-03-03 11:08:00,637 : INFO : PROGRESS: at 10.84% examples, 535478 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:08:09,215 : INFO : Loading new batch for index: 140000
# 2017-03-03 11:08:19,604 : INFO : Finished loading new batch
# 2017-03-03 11:08:20,907 : INFO : PROGRESS: at 10.89% examples, 530360 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 11:08:40,911 : INFO : PROGRESS: at 11.08% examples, 531780 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:09:00,942 : INFO : PROGRESS: at 11.26% examples, 532859 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:09:20,986 : INFO : PROGRESS: at 11.44% examples, 533588 words/s, in_qsize 46, out_qsize 7
# 2017-03-03 11:09:40,982 : INFO : PROGRESS: at 11.61% examples, 534140 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:09:48,230 : INFO : Loading new batch for index: 150000
# 2017-03-03 11:09:59,002 : INFO : Finished loading new batch
# 2017-03-03 11:10:00,995 : INFO : PROGRESS: at 11.65% examples, 528844 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:10:21,014 : INFO : PROGRESS: at 11.82% examples, 528848 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:10:41,022 : INFO : PROGRESS: at 11.98% examples, 529158 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:11:01,032 : INFO : PROGRESS: at 12.15% examples, 530443 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:11:21,032 : INFO : PROGRESS: at 12.34% examples, 531907 words/s, in_qsize 46, out_qsize 0
# 2017-03-03 11:11:33,355 : INFO : Loading new batch for index: 160000
# 2017-03-03 11:11:44,943 : INFO : Finished loading new batch
# 2017-03-03 11:11:45,179 : INFO : PROGRESS: at 12.43% examples, 527823 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 11:12:05,194 : INFO : PROGRESS: at 12.64% examples, 530054 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:12:25,212 : INFO : PROGRESS: at 12.86% examples, 532778 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:12:45,221 : INFO : PROGRESS: at 13.09% examples, 535457 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 11:12:57,227 : INFO : Loading new batch for index: 170000
# 2017-03-03 11:13:08,350 : INFO : Finished loading new batch
# 2017-03-03 11:13:08,871 : INFO : PROGRESS: at 13.20% examples, 532153 words/s, in_qsize 41, out_qsize 0
# 2017-03-03 11:13:28,880 : INFO : PROGRESS: at 13.41% examples, 534038 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 11:13:48,900 : INFO : PROGRESS: at 13.61% examples, 536039 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 11:14:08,917 : INFO : PROGRESS: at 13.81% examples, 537866 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:14:27,860 : INFO : Loading new batch for index: 180000
# 2017-03-03 11:14:39,932 : INFO : Finished loading new batch
# 2017-03-03 11:14:40,651 : INFO : PROGRESS: at 13.98% examples, 534493 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:15:00,655 : INFO : PROGRESS: at 14.18% examples, 536389 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:15:20,657 : INFO : PROGRESS: at 14.39% examples, 538672 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:15:40,659 : INFO : PROGRESS: at 14.61% examples, 541002 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:15:58,003 : INFO : Loading new batch for index: 190000
# 2017-03-03 11:16:08,977 : INFO : Finished loading new batch
# 2017-03-03 11:16:09,726 : INFO : PROGRESS: at 14.77% examples, 538610 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:16:29,731 : INFO : PROGRESS: at 14.98% examples, 540675 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:16:49,747 : INFO : PROGRESS: at 15.20% examples, 543074 words/s, in_qsize 47, out_qsize 4
# 2017-03-03 11:17:09,744 : INFO : PROGRESS: at 15.42% examples, 545387 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:17:23,177 : INFO : Loading new batch for index: 200000
# 2017-03-03 11:17:34,899 : INFO : Finished loading new batch
# 2017-03-03 11:17:36,026 : INFO : PROGRESS: at 15.55% examples, 542247 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:17:56,028 : INFO : PROGRESS: at 15.77% examples, 544207 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:18:16,031 : INFO : PROGRESS: at 15.99% examples, 546368 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:18:36,041 : INFO : PROGRESS: at 16.22% examples, 548543 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:18:46,914 : INFO : Loading new batch for index: 210000
# 2017-03-03 11:18:57,163 : INFO : Finished loading new batch
# 2017-03-03 11:18:58,164 : INFO : PROGRESS: at 16.32% examples, 545768 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:19:18,164 : INFO : PROGRESS: at 16.55% examples, 547622 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:19:38,180 : INFO : PROGRESS: at 16.77% examples, 549645 words/s, in_qsize 44, out_qsize 5
# 2017-03-03 11:19:58,194 : INFO : PROGRESS: at 16.99% examples, 551511 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:20:10,727 : INFO : Loading new batch for index: 220000
# 2017-03-03 11:20:21,828 : INFO : Finished loading new batch
# 2017-03-03 11:20:23,766 : INFO : PROGRESS: at 17.10% examples, 548281 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:20:43,769 : INFO : PROGRESS: at 17.32% examples, 550076 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:21:03,782 : INFO : PROGRESS: at 17.55% examples, 552040 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:21:23,782 : INFO : PROGRESS: at 17.78% examples, 554082 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:21:33,978 : INFO : Loading new batch for index: 230000
# 2017-03-03 11:21:46,328 : INFO : Finished loading new batch
# 2017-03-03 11:21:46,503 : INFO : PROGRESS: at 17.86% examples, 551072 words/s, in_qsize 4, out_qsize 0
# 2017-03-03 11:22:06,504 : INFO : PROGRESS: at 18.07% examples, 552604 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:22:26,504 : INFO : PROGRESS: at 18.28% examples, 554158 words/s, in_qsize 45, out_qsize 0
# 2017-03-03 11:22:46,519 : INFO : PROGRESS: at 18.48% examples, 555441 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:23:07,293 : INFO : Loading new batch for index: 240000
# 2017-03-03 11:23:07,333 : INFO : PROGRESS: at 18.65% examples, 555463 words/s, in_qsize 47, out_qsize 14
# 2017-03-03 11:23:18,929 : INFO : Finished loading new batch
# 2017-03-03 11:23:27,317 : INFO : PROGRESS: at 18.74% examples, 553333 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:23:47,321 : INFO : PROGRESS: at 18.96% examples, 555113 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:24:07,325 : INFO : PROGRESS: at 19.19% examples, 556897 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:24:30,007 : INFO : Loading new batch for index: 250000
# 2017-03-03 11:24:30,027 : INFO : PROGRESS: at 19.42% examples, 558003 words/s, in_qsize 38, out_qsize 10
# 2017-03-03 11:24:40,946 : INFO : Finished loading new batch
# 2017-03-03 11:24:50,020 : INFO : PROGRESS: at 19.51% examples, 555869 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:25:10,021 : INFO : PROGRESS: at 19.70% examples, 556998 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:25:30,034 : INFO : PROGRESS: at 19.92% examples, 558122 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:25:50,030 : INFO : PROGRESS: at 20.11% examples, 558977 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:26:02,622 : INFO : Loading new batch for index: 260000
# 2017-03-03 11:26:14,106 : INFO : Finished loading new batch
# 2017-03-03 11:26:14,938 : INFO : PROGRESS: at 20.20% examples, 555890 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 11:26:34,942 : INFO : PROGRESS: at 20.38% examples, 556511 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:26:54,946 : INFO : PROGRESS: at 20.57% examples, 557114 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:27:14,956 : INFO : PROGRESS: at 20.74% examples, 557562 words/s, in_qsize 48, out_qsize 4
# 2017-03-03 11:27:34,956 : INFO : PROGRESS: at 20.93% examples, 558131 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 11:27:45,528 : INFO : Loading new batch for index: 270000
# 2017-03-03 11:27:56,307 : INFO : Finished loading new batch
# 2017-03-03 11:27:57,546 : INFO : PROGRESS: at 20.99% examples, 555122 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:28:17,548 : INFO : PROGRESS: at 21.19% examples, 556203 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:28:37,557 : INFO : PROGRESS: at 21.41% examples, 557747 words/s, in_qsize 43, out_qsize 0
# 2017-03-03 11:28:57,554 : INFO : PROGRESS: at 21.64% examples, 559377 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:29:11,118 : INFO : Loading new batch for index: 280000
# 2017-03-03 11:29:21,917 : INFO : Finished loading new batch
# 2017-03-03 11:29:23,764 : INFO : PROGRESS: at 21.77% examples, 557119 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:29:43,767 : INFO : PROGRESS: at 21.96% examples, 557788 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:30:03,782 : INFO : PROGRESS: at 22.14% examples, 558250 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:30:23,798 : INFO : PROGRESS: at 22.31% examples, 558644 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:30:43,803 : INFO : PROGRESS: at 22.49% examples, 558897 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:30:51,877 : INFO : Loading new batch for index: 290000
# 2017-03-03 11:31:04,058 : INFO : Finished loading new batch
# 2017-03-03 11:31:04,301 : INFO : PROGRESS: at 22.54% examples, 555881 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:31:24,312 : INFO : PROGRESS: at 22.75% examples, 556805 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 11:31:44,312 : INFO : PROGRESS: at 22.96% examples, 558067 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:32:04,322 : INFO : PROGRESS: at 23.20% examples, 559504 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:32:15,868 : INFO : Loading new batch for index: 300000
# 2017-03-03 11:32:27,768 : INFO : Finished loading new batch
# 2017-03-03 11:32:28,308 : INFO : PROGRESS: at 23.31% examples, 557249 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:32:48,320 : INFO : PROGRESS: at 23.46% examples, 557057 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:33:08,327 : INFO : PROGRESS: at 23.61% examples, 556767 words/s, in_qsize 46, out_qsize 5
# 2017-03-03 11:33:28,328 : INFO : PROGRESS: at 23.76% examples, 556491 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:33:48,351 : INFO : PROGRESS: at 23.92% examples, 556306 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:34:11,212 : INFO : Loading new batch for index: 310000
# 2017-03-03 11:34:11,269 : INFO : PROGRESS: at 24.08% examples, 555648 words/s, in_qsize 29, out_qsize 22
# 2017-03-03 11:34:23,339 : INFO : Finished loading new batch
# 2017-03-03 11:34:31,235 : INFO : PROGRESS: at 24.15% examples, 553576 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 11:34:51,243 : INFO : PROGRESS: at 24.37% examples, 554718 words/s, in_qsize 46, out_qsize 3
# 2017-03-03 11:35:11,246 : INFO : PROGRESS: at 24.59% examples, 556027 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:35:31,246 : INFO : PROGRESS: at 24.81% examples, 557385 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:35:38,700 : INFO : Loading new batch for index: 320000
# 2017-03-03 11:35:49,753 : INFO : Finished loading new batch
# 2017-03-03 11:35:51,255 : INFO : PROGRESS: at 24.87% examples, 555089 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:36:11,253 : INFO : PROGRESS: at 25.07% examples, 555988 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:36:31,269 : INFO : PROGRESS: at 25.27% examples, 556935 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:36:51,275 : INFO : PROGRESS: at 25.47% examples, 557902 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 11:37:11,053 : INFO : Loading new batch for index: 330000
# 2017-03-03 11:37:11,280 : INFO : PROGRESS: at 25.64% examples, 558009 words/s, in_qsize 27, out_qsize 0
# 2017-03-03 11:37:21,097 : INFO : Finished loading new batch
# 2017-03-03 11:37:31,285 : INFO : PROGRESS: at 25.74% examples, 556491 words/s, in_qsize 48, out_qsize 4
# 2017-03-03 11:37:51,291 : INFO : PROGRESS: at 25.96% examples, 557643 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:38:11,300 : INFO : PROGRESS: at 26.19% examples, 558789 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:38:32,847 : INFO : Loading new batch for index: 340000
# 2017-03-03 11:38:32,856 : INFO : PROGRESS: at 26.40% examples, 559375 words/s, in_qsize 46, out_qsize 4
# 2017-03-03 11:38:43,517 : INFO : Finished loading new batch
# 2017-03-03 11:38:52,876 : INFO : PROGRESS: at 26.49% examples, 557737 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:39:12,887 : INFO : PROGRESS: at 26.71% examples, 558831 words/s, in_qsize 46, out_qsize 0
# 2017-03-03 11:39:32,894 : INFO : PROGRESS: at 26.94% examples, 559930 words/s, in_qsize 44, out_qsize 4
# 2017-03-03 11:39:52,901 : INFO : PROGRESS: at 27.15% examples, 560927 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:39:57,515 : INFO : Loading new batch for index: 350000
# 2017-03-03 11:40:08,968 : INFO : Finished loading new batch
# 2017-03-03 11:40:12,906 : INFO : PROGRESS: at 27.21% examples, 558749 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 11:40:32,915 : INFO : PROGRESS: at 27.42% examples, 559729 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:40:52,932 : INFO : PROGRESS: at 27.63% examples, 560805 words/s, in_qsize 45, out_qsize 4
# 2017-03-03 11:41:12,934 : INFO : PROGRESS: at 27.84% examples, 561773 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:41:27,617 : INFO : Loading new batch for index: 360000
# 2017-03-03 11:41:38,864 : INFO : Finished loading new batch
# 2017-03-03 11:41:39,404 : INFO : PROGRESS: at 27.96% examples, 559863 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:41:59,412 : INFO : PROGRESS: at 28.17% examples, 560592 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:42:19,436 : INFO : PROGRESS: at 28.38% examples, 561519 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:42:39,439 : INFO : PROGRESS: at 28.59% examples, 562426 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:42:55,158 : INFO : Loading new batch for index: 370000
# 2017-03-03 11:43:06,251 : INFO : Finished loading new batch
# 2017-03-03 11:43:07,068 : INFO : PROGRESS: at 28.74% examples, 560716 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:43:27,096 : INFO : PROGRESS: at 28.88% examples, 560281 words/s, in_qsize 47, out_qsize 4
# 2017-03-03 11:43:47,101 : INFO : PROGRESS: at 29.03% examples, 559907 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:44:07,120 : INFO : PROGRESS: at 29.16% examples, 559475 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:44:27,175 : INFO : PROGRESS: at 29.30% examples, 559039 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:44:47,180 : INFO : PROGRESS: at 29.45% examples, 558951 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:44:57,896 : INFO : Loading new batch for index: 380000
# 2017-03-03 11:45:09,947 : INFO : Finished loading new batch
# 2017-03-03 11:45:10,972 : INFO : PROGRESS: at 29.52% examples, 556478 words/s, in_qsize 1, out_qsize 0
# 2017-03-03 11:45:30,974 : INFO : PROGRESS: at 29.71% examples, 556910 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:45:50,977 : INFO : PROGRESS: at 29.89% examples, 557324 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:46:10,986 : INFO : PROGRESS: at 30.08% examples, 557583 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:46:30,984 : INFO : PROGRESS: at 30.26% examples, 557894 words/s, in_qsize 45, out_qsize 0
# 2017-03-03 11:46:37,256 : INFO : Loading new batch for index: 390000
# 2017-03-03 11:46:48,656 : INFO : Finished loading new batch
# 2017-03-03 11:46:50,983 : INFO : PROGRESS: at 30.30% examples, 555702 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:47:10,984 : INFO : PROGRESS: at 30.44% examples, 555227 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:47:30,984 : INFO : PROGRESS: at 30.58% examples, 554799 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:47:50,991 : INFO : PROGRESS: at 30.72% examples, 554379 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:48:11,006 : INFO : PROGRESS: at 30.86% examples, 553970 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:48:31,016 : INFO : PROGRESS: at 31.00% examples, 553688 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:48:43,667 : INFO : Loading new batch for index: 400000
# 2017-03-03 11:48:54,940 : INFO : Finished loading new batch
# 2017-03-03 11:48:56,690 : INFO : PROGRESS: at 31.08% examples, 551286 words/s, in_qsize 4, out_qsize 1
# 2017-03-03 11:49:16,692 : INFO : PROGRESS: at 31.26% examples, 551558 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:49:36,694 : INFO : PROGRESS: at 31.45% examples, 552240 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:49:56,695 : INFO : PROGRESS: at 31.66% examples, 553073 words/s, in_qsize 45, out_qsize 1
# 2017-03-03 11:50:18,164 : INFO : Loading new batch for index: 410000
# 2017-03-03 11:50:18,174 : INFO : PROGRESS: at 31.85% examples, 553394 words/s, in_qsize 47, out_qsize 4
# 2017-03-03 11:50:27,710 : INFO : Finished loading new batch
# 2017-03-03 11:50:38,174 : INFO : PROGRESS: at 31.95% examples, 552172 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:50:58,180 : INFO : PROGRESS: at 32.14% examples, 552502 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:51:18,182 : INFO : PROGRESS: at 32.33% examples, 552911 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:51:38,196 : INFO : PROGRESS: at 32.51% examples, 553207 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:51:54,096 : INFO : Loading new batch for index: 420000
# 2017-03-03 11:52:06,573 : INFO : Finished loading new batch
# 2017-03-03 11:52:06,895 : INFO : PROGRESS: at 32.62% examples, 551208 words/s, in_qsize 0, out_qsize 1
# 2017-03-03 11:52:26,900 : INFO : PROGRESS: at 32.75% examples, 550683 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:52:46,901 : INFO : PROGRESS: at 32.89% examples, 550289 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:53:06,923 : INFO : PROGRESS: at 33.03% examples, 549960 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 11:53:26,934 : INFO : PROGRESS: at 33.17% examples, 549617 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 11:53:46,943 : INFO : PROGRESS: at 33.31% examples, 549215 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:54:03,586 : INFO : Loading new batch for index: 430000
# 2017-03-03 11:54:15,522 : INFO : Finished loading new batch
# 2017-03-03 11:54:16,200 : INFO : PROGRESS: at 33.40% examples, 546885 words/s, in_qsize 0, out_qsize 1
# 2017-03-03 11:54:36,210 : INFO : PROGRESS: at 33.55% examples, 546783 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:54:56,222 : INFO : PROGRESS: at 33.74% examples, 547426 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 11:55:16,235 : INFO : PROGRESS: at 33.95% examples, 548139 words/s, in_qsize 45, out_qsize 3
# 2017-03-03 11:55:36,249 : INFO : PROGRESS: at 34.15% examples, 548861 words/s, in_qsize 48, out_qsize 3
# 2017-03-03 11:55:43,079 : INFO : Loading new batch for index: 440000
# 2017-03-03 11:55:54,229 : INFO : Finished loading new batch
# 2017-03-03 11:55:56,275 : INFO : PROGRESS: at 34.20% examples, 547097 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:56:16,281 : INFO : PROGRESS: at 34.34% examples, 546719 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:56:36,285 : INFO : PROGRESS: at 34.48% examples, 546400 words/s, in_qsize 45, out_qsize 1
# 2017-03-03 11:56:56,302 : INFO : PROGRESS: at 34.62% examples, 546099 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:57:16,309 : INFO : PROGRESS: at 34.76% examples, 545788 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:57:36,331 : INFO : PROGRESS: at 34.92% examples, 545666 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:57:44,554 : INFO : Loading new batch for index: 450000
# 2017-03-03 11:57:55,652 : INFO : Finished loading new batch
# 2017-03-03 11:57:56,885 : INFO : PROGRESS: at 34.96% examples, 543733 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:58:16,891 : INFO : PROGRESS: at 35.12% examples, 543625 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 11:58:36,900 : INFO : PROGRESS: at 35.29% examples, 543797 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:58:56,903 : INFO : PROGRESS: at 35.48% examples, 544056 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 11:59:16,907 : INFO : PROGRESS: at 35.66% examples, 544371 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 11:59:26,253 : INFO : Loading new batch for index: 460000
# 2017-03-03 11:59:37,656 : INFO : Finished loading new batch
# 2017-03-03 11:59:38,989 : INFO : PROGRESS: at 35.73% examples, 542691 words/s, in_qsize 40, out_qsize 0
# 2017-03-03 11:59:58,977 : INFO : PROGRESS: at 35.89% examples, 542803 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:00:19,000 : INFO : PROGRESS: at 36.04% examples, 542799 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:00:39,021 : INFO : PROGRESS: at 36.19% examples, 542767 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:00:59,016 : INFO : PROGRESS: at 36.35% examples, 542804 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:01:18,877 : INFO : Loading new batch for index: 470000
# 2017-03-03 12:01:19,028 : INFO : PROGRESS: at 36.51% examples, 542720 words/s, in_qsize 29, out_qsize 0
# 2017-03-03 12:01:28,939 : INFO : Finished loading new batch
# 2017-03-03 12:01:39,039 : INFO : PROGRESS: at 36.60% examples, 541634 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 12:01:59,045 : INFO : PROGRESS: at 36.80% examples, 542288 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:02:19,050 : INFO : PROGRESS: at 37.01% examples, 542930 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 12:02:39,049 : INFO : PROGRESS: at 37.22% examples, 543623 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 12:02:47,856 : INFO : Loading new batch for index: 480000
# 2017-03-03 12:03:00,553 : INFO : Finished loading new batch
# 2017-03-03 12:03:00,987 : INFO : PROGRESS: at 37.29% examples, 542030 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 12:03:21,027 : INFO : PROGRESS: at 37.46% examples, 542396 words/s, in_qsize 46, out_qsize 4
# 2017-03-03 12:03:41,056 : INFO : PROGRESS: at 37.64% examples, 542639 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:04:01,057 : INFO : PROGRESS: at 37.81% examples, 542867 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:04:21,102 : INFO : PROGRESS: at 37.98% examples, 543018 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:04:37,197 : INFO : Loading new batch for index: 490000
# 2017-03-03 12:04:48,840 : INFO : Finished loading new batch
# 2017-03-03 12:04:49,380 : INFO : PROGRESS: at 38.08% examples, 541342 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:05:09,378 : INFO : PROGRESS: at 38.26% examples, 541760 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 12:05:29,383 : INFO : PROGRESS: at 38.48% examples, 542595 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:05:49,388 : INFO : PROGRESS: at 38.70% examples, 543494 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:06:05,063 : INFO : Loading new batch for index: 500000
# 2017-03-03 12:06:16,563 : INFO : Finished loading new batch
# 2017-03-03 12:06:17,502 : INFO : PROGRESS: at 38.86% examples, 542418 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:06:37,508 : INFO : PROGRESS: at 39.01% examples, 542203 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:06:57,521 : INFO : PROGRESS: at 39.16% examples, 542034 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:07:17,531 : INFO : PROGRESS: at 39.30% examples, 541874 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:07:37,536 : INFO : PROGRESS: at 39.45% examples, 541718 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:07:57,565 : INFO : PROGRESS: at 39.62% examples, 541933 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 12:08:02,003 : INFO : Loading new batch for index: 510000
# 2017-03-03 12:08:12,957 : INFO : Finished loading new batch
# 2017-03-03 12:08:17,613 : INFO : PROGRESS: at 39.66% examples, 540298 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:08:37,612 : INFO : PROGRESS: at 39.83% examples, 540578 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 12:08:57,656 : INFO : PROGRESS: at 40.04% examples, 541107 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:09:17,666 : INFO : PROGRESS: at 40.24% examples, 541674 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:09:36,453 : INFO : Loading new batch for index: 520000
# 2017-03-03 12:09:47,283 : INFO : Finished loading new batch
# 2017-03-03 12:09:48,820 : INFO : PROGRESS: at 40.41% examples, 540603 words/s, in_qsize 0, out_qsize 1
# 2017-03-03 12:10:08,816 : INFO : PROGRESS: at 40.60% examples, 541026 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:10:28,854 : INFO : PROGRESS: at 40.77% examples, 541312 words/s, in_qsize 48, out_qsize 2
# 2017-03-03 12:10:48,857 : INFO : PROGRESS: at 40.95% examples, 541583 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:11:08,860 : INFO : PROGRESS: at 41.13% examples, 541895 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:11:19,893 : INFO : Loading new batch for index: 530000
# 2017-03-03 12:11:32,316 : INFO : Finished loading new batch
# 2017-03-03 12:11:32,370 : INFO : PROGRESS: at 41.20% examples, 540392 words/s, in_qsize 1, out_qsize 0
# 2017-03-03 12:11:52,381 : INFO : PROGRESS: at 41.38% examples, 540784 words/s, in_qsize 45, out_qsize 2
# 2017-03-03 12:12:12,374 : INFO : PROGRESS: at 41.58% examples, 541506 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:12:32,376 : INFO : PROGRESS: at 41.80% examples, 542242 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:12:53,501 : INFO : Loading new batch for index: 540000
# 2017-03-03 12:12:53,518 : INFO : PROGRESS: at 41.99% examples, 542603 words/s, in_qsize 40, out_qsize 8
# 2017-03-03 12:13:03,937 : INFO : Finished loading new batch
# 2017-03-03 12:13:13,534 : INFO : PROGRESS: at 42.09% examples, 541783 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:13:33,528 : INFO : PROGRESS: at 42.28% examples, 542137 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:13:53,533 : INFO : PROGRESS: at 42.48% examples, 542487 words/s, in_qsize 45, out_qsize 2
# 2017-03-03 12:14:13,550 : INFO : PROGRESS: at 42.66% examples, 542706 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:14:27,415 : INFO : Loading new batch for index: 550000
# 2017-03-03 12:14:39,008 : INFO : Finished loading new batch
# 2017-03-03 12:14:39,597 : INFO : PROGRESS: at 42.76% examples, 541347 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:14:59,609 : INFO : PROGRESS: at 42.95% examples, 541683 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:15:19,620 : INFO : PROGRESS: at 43.15% examples, 542166 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:15:39,616 : INFO : PROGRESS: at 43.36% examples, 542794 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:15:58,763 : INFO : Loading new batch for index: 560000
# 2017-03-03 12:16:10,842 : INFO : Finished loading new batch
# 2017-03-03 12:16:11,970 : INFO : PROGRESS: at 43.54% examples, 541867 words/s, in_qsize 37, out_qsize 0
# 2017-03-03 12:16:31,973 : INFO : PROGRESS: at 43.74% examples, 542520 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:16:51,977 : INFO : PROGRESS: at 43.96% examples, 543235 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 12:17:11,989 : INFO : PROGRESS: at 44.17% examples, 543908 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:17:30,918 : INFO : Loading new batch for index: 570000
# 2017-03-03 12:17:41,729 : INFO : Finished loading new batch
# 2017-03-03 12:17:42,799 : INFO : PROGRESS: at 44.33% examples, 542945 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:18:02,803 : INFO : PROGRESS: at 44.52% examples, 543213 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:18:22,807 : INFO : PROGRESS: at 44.69% examples, 543465 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:18:42,824 : INFO : PROGRESS: at 44.87% examples, 543680 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:19:02,835 : INFO : PROGRESS: at 45.04% examples, 543860 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:19:14,652 : INFO : Loading new batch for index: 580000
# 2017-03-03 12:19:24,845 : INFO : Finished loading new batch
# 2017-03-03 12:19:26,192 : INFO : PROGRESS: at 45.11% examples, 542521 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:19:46,195 : INFO : PROGRESS: at 45.32% examples, 543118 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:20:06,197 : INFO : PROGRESS: at 45.55% examples, 543786 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:20:26,199 : INFO : PROGRESS: at 45.77% examples, 544484 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:20:37,486 : INFO : Loading new batch for index: 590000
# 2017-03-03 12:20:48,310 : INFO : Finished loading new batch
# 2017-03-03 12:20:50,257 : INFO : PROGRESS: at 45.87% examples, 543368 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:21:10,266 : INFO : PROGRESS: at 46.06% examples, 543748 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:21:30,270 : INFO : PROGRESS: at 46.27% examples, 544198 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:21:50,280 : INFO : PROGRESS: at 46.46% examples, 544598 words/s, in_qsize 44, out_qsize 3
# 2017-03-03 12:22:10,281 : INFO : PROGRESS: at 46.64% examples, 544883 words/s, in_qsize 45, out_qsize 3
# 2017-03-03 12:22:13,876 : INFO : Loading new batch for index: 600000
# 2017-03-03 12:22:26,352 : INFO : Finished loading new batch
# 2017-03-03 12:22:30,283 : INFO : PROGRESS: at 46.69% examples, 543486 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:22:50,291 : INFO : PROGRESS: at 46.89% examples, 544066 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 12:23:10,291 : INFO : PROGRESS: at 47.11% examples, 544685 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:23:30,294 : INFO : PROGRESS: at 47.34% examples, 545367 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:23:39,584 : INFO : Loading new batch for index: 610000
# 2017-03-03 12:23:51,779 : INFO : Finished loading new batch
# 2017-03-03 12:23:52,375 : INFO : PROGRESS: at 47.42% examples, 544199 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:24:12,378 : INFO : PROGRESS: at 47.56% examples, 544010 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:24:32,385 : INFO : PROGRESS: at 47.70% examples, 543897 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:24:52,399 : INFO : PROGRESS: at 47.85% examples, 543798 words/s, in_qsize 48, out_qsize 6
# 2017-03-03 12:25:12,418 : INFO : PROGRESS: at 48.00% examples, 543704 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:25:32,415 : INFO : PROGRESS: at 48.16% examples, 543678 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:25:39,133 : INFO : Loading new batch for index: 620000
# 2017-03-03 12:25:49,999 : INFO : Finished loading new batch
# 2017-03-03 12:25:52,425 : INFO : PROGRESS: at 48.20% examples, 542342 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:26:12,416 : INFO : PROGRESS: at 48.38% examples, 542436 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:26:32,426 : INFO : PROGRESS: at 48.58% examples, 542874 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 12:26:52,444 : INFO : PROGRESS: at 48.77% examples, 543335 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:27:14,088 : INFO : Loading new batch for index: 630000
# 2017-03-03 12:27:14,122 : INFO : PROGRESS: at 48.96% examples, 543500 words/s, in_qsize 47, out_qsize 8
# 2017-03-03 12:27:25,524 : INFO : Finished loading new batch
# 2017-03-03 12:27:34,106 : INFO : PROGRESS: at 49.02% examples, 542340 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:27:54,113 : INFO : PROGRESS: at 49.16% examples, 542132 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:28:14,124 : INFO : PROGRESS: at 49.29% examples, 541929 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:28:34,152 : INFO : PROGRESS: at 49.43% examples, 541760 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:28:54,163 : INFO : PROGRESS: at 49.58% examples, 541569 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:29:14,186 : INFO : PROGRESS: at 49.72% examples, 541360 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 12:29:20,370 : INFO : Loading new batch for index: 640000
# 2017-03-03 12:29:31,018 : INFO : Finished loading new batch
# 2017-03-03 12:29:34,208 : INFO : PROGRESS: at 49.76% examples, 540021 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:29:54,210 : INFO : PROGRESS: at 49.91% examples, 539965 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:30:14,233 : INFO : PROGRESS: at 50.08% examples, 539945 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:30:34,234 : INFO : PROGRESS: at 50.22% examples, 539929 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:30:54,244 : INFO : PROGRESS: at 50.38% examples, 539924 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:31:15,373 : INFO : Loading new batch for index: 650000
# 2017-03-03 12:31:15,394 : INFO : PROGRESS: at 50.53% examples, 539697 words/s, in_qsize 39, out_qsize 9
# 2017-03-03 12:31:25,200 : INFO : Finished loading new batch
# 2017-03-03 12:31:35,407 : INFO : PROGRESS: at 50.60% examples, 538861 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:31:55,411 : INFO : PROGRESS: at 50.79% examples, 538993 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:32:15,412 : INFO : PROGRESS: at 50.96% examples, 539098 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:32:35,421 : INFO : PROGRESS: at 51.12% examples, 539181 words/s, in_qsize 47, out_qsize 3
# 2017-03-03 12:32:55,429 : INFO : PROGRESS: at 51.29% examples, 539368 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:32:58,898 : INFO : Loading new batch for index: 660000
# 2017-03-03 12:33:11,916 : INFO : Finished loading new batch
# 2017-03-03 12:33:15,441 : INFO : PROGRESS: at 51.33% examples, 538078 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:33:35,452 : INFO : PROGRESS: at 51.53% examples, 538550 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:33:55,452 : INFO : PROGRESS: at 51.74% examples, 539129 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:34:15,458 : INFO : PROGRESS: at 51.95% examples, 539736 words/s, in_qsize 45, out_qsize 3
# 2017-03-03 12:34:30,664 : INFO : Loading new batch for index: 670000
# 2017-03-03 12:34:45,914 : INFO : Finished loading new batch
# 2017-03-03 12:34:46,210 : INFO : PROGRESS: at 52.09% examples, 538657 words/s, in_qsize 36, out_qsize 0
# 2017-03-03 12:35:06,211 : INFO : PROGRESS: at 52.30% examples, 539204 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:35:26,226 : INFO : PROGRESS: at 52.51% examples, 539793 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 12:35:46,243 : INFO : PROGRESS: at 52.71% examples, 540313 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 12:36:05,351 : INFO : Loading new batch for index: 680000
# 2017-03-03 12:36:15,948 : INFO : Finished loading new batch
# 2017-03-03 12:36:16,942 : INFO : PROGRESS: at 52.88% examples, 539507 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:36:36,946 : INFO : PROGRESS: at 53.09% examples, 539970 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:36:56,957 : INFO : PROGRESS: at 53.29% examples, 540462 words/s, in_qsize 46, out_qsize 0
# 2017-03-03 12:37:16,968 : INFO : PROGRESS: at 53.50% examples, 540937 words/s, in_qsize 48, out_qsize 4
# 2017-03-03 12:37:33,428 : INFO : Loading new batch for index: 690000
# 2017-03-03 12:37:45,126 : INFO : Finished loading new batch
# 2017-03-03 12:37:46,492 : INFO : PROGRESS: at 53.65% examples, 540048 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 12:38:06,498 : INFO : PROGRESS: at 53.79% examples, 539946 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:38:26,538 : INFO : PROGRESS: at 53.95% examples, 539844 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:38:46,538 : INFO : PROGRESS: at 54.09% examples, 539753 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:39:06,582 : INFO : PROGRESS: at 54.23% examples, 539660 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:39:26,623 : INFO : PROGRESS: at 54.38% examples, 539545 words/s, in_qsize 43, out_qsize 4
# 2017-03-03 12:39:37,055 : INFO : Loading new batch for index: 700000
# 2017-03-03 12:39:48,716 : INFO : Finished loading new batch
# 2017-03-03 12:39:50,696 : INFO : PROGRESS: at 54.43% examples, 538206 words/s, in_qsize 15, out_qsize 0
# 2017-03-03 12:40:10,712 : INFO : PROGRESS: at 54.61% examples, 538406 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 12:40:30,698 : INFO : PROGRESS: at 54.79% examples, 538746 words/s, in_qsize 46, out_qsize 3
# 2017-03-03 12:40:50,707 : INFO : PROGRESS: at 55.00% examples, 539248 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:41:10,719 : INFO : PROGRESS: at 55.20% examples, 539824 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:41:15,378 : INFO : Loading new batch for index: 710000
# 2017-03-03 12:41:26,138 : INFO : Finished loading new batch
# 2017-03-03 12:41:30,735 : INFO : PROGRESS: at 55.26% examples, 538787 words/s, in_qsize 48, out_qsize 6
# 2017-03-03 12:41:50,737 : INFO : PROGRESS: at 55.40% examples, 538641 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:42:10,796 : INFO : PROGRESS: at 55.55% examples, 538495 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:42:30,806 : INFO : PROGRESS: at 55.69% examples, 538360 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:42:50,818 : INFO : PROGRESS: at 55.84% examples, 538229 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:43:10,829 : INFO : PROGRESS: at 55.99% examples, 538115 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:43:14,708 : INFO : Loading new batch for index: 720000
# 2017-03-03 12:43:25,716 : INFO : Finished loading new batch
# 2017-03-03 12:43:30,833 : INFO : PROGRESS: at 56.03% examples, 537022 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:43:50,846 : INFO : PROGRESS: at 56.21% examples, 537238 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:44:10,865 : INFO : PROGRESS: at 56.41% examples, 537542 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:44:30,883 : INFO : PROGRESS: at 56.61% examples, 537881 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:44:47,333 : INFO : Loading new batch for index: 730000
# 2017-03-03 12:44:58,386 : INFO : Finished loading new batch
# 2017-03-03 12:44:59,179 : INFO : PROGRESS: at 56.76% examples, 537094 words/s, in_qsize 16, out_qsize 0
# 2017-03-03 12:45:19,183 : INFO : PROGRESS: at 56.93% examples, 537261 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:45:39,199 : INFO : PROGRESS: at 57.10% examples, 537373 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:45:59,229 : INFO : PROGRESS: at 57.26% examples, 537426 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:46:19,247 : INFO : PROGRESS: at 57.43% examples, 537515 words/s, in_qsize 45, out_qsize 6
# 2017-03-03 12:46:34,303 : INFO : Loading new batch for index: 740000
# 2017-03-03 12:46:45,995 : INFO : Finished loading new batch
# 2017-03-03 12:46:46,895 : INFO : PROGRESS: at 57.54% examples, 536520 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 12:47:06,898 : INFO : PROGRESS: at 57.75% examples, 537069 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:47:26,912 : INFO : PROGRESS: at 57.98% examples, 537709 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:47:46,915 : INFO : PROGRESS: at 58.21% examples, 538327 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:47:58,212 : INFO : Loading new batch for index: 750000
# 2017-03-03 12:48:09,089 : INFO : Finished loading new batch
# 2017-03-03 12:48:10,393 : INFO : PROGRESS: at 58.31% examples, 537523 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:48:30,395 : INFO : PROGRESS: at 58.45% examples, 537328 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 12:48:50,404 : INFO : PROGRESS: at 58.59% examples, 537169 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:49:10,414 : INFO : PROGRESS: at 58.73% examples, 537006 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:49:30,421 : INFO : PROGRESS: at 58.87% examples, 536839 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 12:49:50,435 : INFO : PROGRESS: at 59.02% examples, 536835 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 12:50:01,042 : INFO : Loading new batch for index: 760000
# 2017-03-03 12:50:11,196 : INFO : Finished loading new batch
# 2017-03-03 12:50:12,786 : INFO : PROGRESS: at 59.09% examples, 535824 words/s, in_qsize 45, out_qsize 3
# 2017-03-03 12:50:32,786 : INFO : PROGRESS: at 59.28% examples, 536112 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 12:50:52,793 : INFO : PROGRESS: at 59.48% examples, 536416 words/s, in_qsize 48, out_qsize 1
# ...
# 2017-03-03 17:54:23,462 : INFO : PROGRESS: at 24.86% examples, 603904 words/s, in_qsize 46, out_qsize 3
# 2017-03-03 17:54:43,460 : INFO : PROGRESS: at 25.07% examples, 604783 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 17:55:03,489 : INFO : PROGRESS: at 25.29% examples, 605785 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 17:55:23,517 : INFO : PROGRESS: at 25.51% examples, 606847 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 17:55:38,469 : INFO : Loading new batch for index: 330000
# 2017-03-03 17:55:52,109 : INFO : Finished loading new batch
# 2017-03-03 17:55:52,685 : INFO : PROGRESS: at 25.65% examples, 604010 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 17:56:12,686 : INFO : PROGRESS: at 25.87% examples, 604912 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 17:56:32,692 : INFO : PROGRESS: at 26.09% examples, 605899 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 17:56:52,712 : INFO : PROGRESS: at 26.32% examples, 606860 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 17:57:02,737 : INFO : Loading new batch for index: 340000
# 2017-03-03 17:57:16,480 : INFO : Finished loading new batch
# 2017-03-03 17:57:17,323 : INFO : PROGRESS: at 26.41% examples, 603633 words/s, in_qsize 16, out_qsize 0
# 2017-03-03 17:57:37,323 : INFO : PROGRESS: at 26.62% examples, 604549 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 17:57:57,343 : INFO : PROGRESS: at 26.86% examples, 605534 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 17:58:17,356 : INFO : PROGRESS: at 27.09% examples, 606536 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 17:58:27,351 : INFO : Loading new batch for index: 350000
# 2017-03-03 17:58:40,320 : INFO : Finished loading new batch
# 2017-03-03 17:58:41,256 : INFO : PROGRESS: at 27.17% examples, 603744 words/s, in_qsize 2, out_qsize 0
# 2017-03-03 17:59:01,262 : INFO : PROGRESS: at 27.39% examples, 604609 words/s, in_qsize 46, out_qsize 3
# 2017-03-03 17:59:21,266 : INFO : PROGRESS: at 27.61% examples, 605646 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 17:59:41,281 : INFO : PROGRESS: at 27.83% examples, 606643 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 17:59:56,492 : INFO : Loading new batch for index: 360000
# 2017-03-03 18:00:09,699 : INFO : Finished loading new batch
# 2017-03-03 18:00:11,535 : INFO : PROGRESS: at 27.96% examples, 603780 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:00:31,551 : INFO : PROGRESS: at 28.18% examples, 604601 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 18:00:51,552 : INFO : PROGRESS: at 28.40% examples, 605579 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:01:11,557 : INFO : PROGRESS: at 28.63% examples, 606484 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:01:23,903 : INFO : Loading new batch for index: 370000
# 2017-03-03 18:01:38,532 : INFO : Finished loading new batch
# 2017-03-03 18:01:38,626 : INFO : PROGRESS: at 28.74% examples, 603617 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:01:58,628 : INFO : PROGRESS: at 28.96% examples, 604444 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:02:18,641 : INFO : PROGRESS: at 29.17% examples, 605364 words/s, in_qsize 48, out_qsize 3
# 2017-03-03 18:02:38,649 : INFO : PROGRESS: at 29.39% examples, 606270 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:02:53,953 : INFO : Loading new batch for index: 380000
# 2017-03-03 18:03:08,296 : INFO : Finished loading new batch
# 2017-03-03 18:03:08,635 : INFO : PROGRESS: at 29.52% examples, 603568 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:03:28,641 : INFO : PROGRESS: at 29.74% examples, 604371 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:03:48,642 : INFO : PROGRESS: at 29.96% examples, 605248 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 18:04:08,646 : INFO : PROGRESS: at 30.19% examples, 606114 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:04:20,798 : INFO : Loading new batch for index: 390000
# 2017-03-03 18:04:34,515 : INFO : Finished loading new batch
# 2017-03-03 18:04:35,114 : INFO : PROGRESS: at 30.30% examples, 603578 words/s, in_qsize 21, out_qsize 0
# 2017-03-03 18:04:55,118 : INFO : PROGRESS: at 30.51% examples, 604291 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:05:15,130 : INFO : PROGRESS: at 30.72% examples, 605091 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:05:35,142 : INFO : PROGRESS: at 30.94% examples, 605873 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:05:50,675 : INFO : Loading new batch for index: 400000
# 2017-03-03 18:06:04,594 : INFO : Finished loading new batch
# 2017-03-03 18:06:11,014 : INFO : PROGRESS: at 31.08% examples, 602318 words/s, in_qsize 36, out_qsize 0
# 2017-03-03 18:06:31,011 : INFO : PROGRESS: at 31.29% examples, 602934 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:06:51,013 : INFO : PROGRESS: at 31.50% examples, 603697 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:07:11,031 : INFO : PROGRESS: at 31.71% examples, 604482 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:07:26,749 : INFO : Loading new batch for index: 410000
# 2017-03-03 18:07:38,748 : INFO : Finished loading new batch
# 2017-03-03 18:07:39,539 : INFO : PROGRESS: at 31.86% examples, 602388 words/s, in_qsize 33, out_qsize 0
# 2017-03-03 18:07:59,563 : INFO : PROGRESS: at 32.08% examples, 603044 words/s, in_qsize 48, out_qsize 4
# 2017-03-03 18:08:19,571 : INFO : PROGRESS: at 32.31% examples, 603843 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:08:39,577 : INFO : PROGRESS: at 32.53% examples, 604623 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 18:08:51,122 : INFO : Loading new batch for index: 420000
# 2017-03-03 18:09:04,290 : INFO : Finished loading new batch
# 2017-03-03 18:09:05,716 : INFO : PROGRESS: at 32.62% examples, 602132 words/s, in_qsize 0, out_qsize 0
# 2017-03-03 18:09:25,721 : INFO : PROGRESS: at 32.83% examples, 602774 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:09:45,719 : INFO : PROGRESS: at 33.05% examples, 603518 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:10:05,736 : INFO : PROGRESS: at 33.27% examples, 604265 words/s, in_qsize 46, out_qsize 1
# 2017-03-03 18:10:20,229 : INFO : Loading new batch for index: 430000
# 2017-03-03 18:10:32,552 : INFO : Finished loading new batch
# 2017-03-03 18:10:33,820 : INFO : PROGRESS: at 33.40% examples, 602197 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:10:53,818 : INFO : PROGRESS: at 33.61% examples, 602898 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:11:13,833 : INFO : PROGRESS: at 33.82% examples, 603707 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:11:33,843 : INFO : PROGRESS: at 34.04% examples, 604458 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:11:50,556 : INFO : Loading new batch for index: 440000
# 2017-03-03 18:12:04,190 : INFO : Finished loading new batch
# 2017-03-03 18:12:04,373 : INFO : PROGRESS: at 34.19% examples, 602363 words/s, in_qsize 37, out_qsize 0
# 2017-03-03 18:12:24,371 : INFO : PROGRESS: at 34.40% examples, 602996 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:12:44,388 : INFO : PROGRESS: at 34.63% examples, 603741 words/s, in_qsize 48, out_qsize 3
# 2017-03-03 18:13:04,389 : INFO : PROGRESS: at 34.85% examples, 604506 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:13:16,214 : INFO : Loading new batch for index: 450000
# 2017-03-03 18:13:28,103 : INFO : Finished loading new batch
# 2017-03-03 18:13:28,563 : INFO : PROGRESS: at 34.96% examples, 602619 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:13:48,570 : INFO : PROGRESS: at 35.18% examples, 603258 words/s, in_qsize 47, out_qsize 2
# 2017-03-03 18:14:08,571 : INFO : PROGRESS: at 35.40% examples, 604001 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:14:28,573 : INFO : PROGRESS: at 35.63% examples, 604719 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:14:39,592 : INFO : Loading new batch for index: 460000
# 2017-03-03 18:14:53,938 : INFO : Finished loading new batch
# 2017-03-03 18:14:54,777 : INFO : PROGRESS: at 35.73% examples, 602343 words/s, in_qsize 15, out_qsize 0
# 2017-03-03 18:15:14,775 : INFO : PROGRESS: at 35.93% examples, 602968 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:15:34,786 : INFO : PROGRESS: at 36.15% examples, 603697 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:15:54,799 : INFO : PROGRESS: at 36.37% examples, 604431 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:16:11,394 : INFO : Loading new batch for index: 470000
# 2017-03-03 18:16:24,694 : INFO : Finished loading new batch
# 2017-03-03 18:16:25,743 : INFO : PROGRESS: at 36.51% examples, 602327 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:16:45,752 : INFO : PROGRESS: at 36.73% examples, 602914 words/s, in_qsize 48, out_qsize 1
# 2017-03-03 18:17:05,754 : INFO : PROGRESS: at 36.95% examples, 603634 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:17:25,767 : INFO : PROGRESS: at 37.18% examples, 604323 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:17:37,892 : INFO : Loading new batch for index: 480000
# 2017-03-03 18:17:51,369 : INFO : Finished loading new batch
# 2017-03-03 18:17:52,684 : INFO : PROGRESS: at 37.29% examples, 602195 words/s, in_qsize 18, out_qsize 0
# 2017-03-03 18:18:12,675 : INFO : PROGRESS: at 37.49% examples, 602803 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:18:32,676 : INFO : PROGRESS: at 37.71% examples, 603561 words/s, in_qsize 46, out_qsize 2
# 2017-03-03 18:18:52,676 : INFO : PROGRESS: at 37.93% examples, 604292 words/s, in_qsize 48, out_qsize 0
# 2017-03-03 18:19:09,273 : INFO : Loading new batch for index: 490000
# 2017-03-03 18:19:22,030 : INFO : Finished loading new batch
# 2017-03-03 18:19:23,665 : INFO : PROGRESS: at 38.08% examples, 602347 words/s, in_qsize 47, out_qsize 0
# 2017-03-03 18:19:43,666 : INFO : PROGRESS: at 38.29% examples, 602989 words/s, in_qsize 47, out_qsize 1
# 2017-03-03 18:20:03,666 : INFO : PROGRESS: at 38.51% examples, 603715 words/s, in_qsize 48, out_qsize 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-216b1c156d5f> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'%matplotlib notebook\ngraph = MetricsGraph()\ngraph.init_graph(len(classifications) +2)\n# when resuming, resume from an epoch with a previously created doc2vec model to get the learning rate right\nstart_from = 1\nfor epoch in range(start_from, DOC2VEC_MAX_EPOCHS+1):\n    GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)\n    info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))\n    \n    # if we have the model, just load it, otherwise train the previous model\n    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):\n        doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))\n        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model\n    else:\n        # train the doc2vec model\n        training_docs_iterator = DocumentBatchGenerator(training_preprocessed_files_prefix, \n                                                        training_preprocessed_docids_files_prefix, batch_size=10000)\n        doc2vec_model.train(sentences=training_docs_iterator, report_delay=REPORT_DELAY)\n        doc2vec_model.alpha -= DOC2VEC_ALPHA_DECREASE  # decrease the learning rate\n        doc2vec_model.min_alpha = doc2vec_model.alpha  # fix the learning rate, no decay\n        ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))\n        doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))\n        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model\n        \n        # get the word2vec analogy accuracy score\n        word2vec_result = doc2vec_model.accuracy(word2vec_questions_file, restrict_vocab=None)\n        epoch_word2vec_metrics.append(word2vec_result)\n        pickle.dump(word2vec_result, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME,\n                                                       WORD2VEC_METRICS_FILENAME), \'w\'))\n\n\n    ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, \n                                             GLOBAL_VARS.SVM_MODEL_NAME))\n    \n    if not os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, \n                                                          GLOBAL_VARS.SVM_MODEL_NAME, CLASSIFIER)):\n\n        info(\'Getting training Data\')\n        X, y = get_training_data(doc2vec_model, classifications)\n        \n        info(\'Training Classifier\')\n        clf = OneVsRestClassifier(linear_model.SGDClassifier(loss=\'hinge\', penalty=\'l2\', \n                                                             #alpha is the 1/nC parameter\n                                                             alpha=SVM_REG, fit_intercept=True, n_iter=SVM_ITERATIONS,\n                                                             #n_jobs=-1 means use all cpus\n                                                             shuffle=True, verbose=0, n_jobs=1,\n                                                             #eta0 is the learning rate when we use constant configuration\n                                                             random_state=SVM_SEED, learning_rate=\'optimal\', eta0=0.0, \n                                                             class_weight=SVM_CLASS_WEIGHTS, warm_start=False), n_jobs=1)\n\n\n        # Training of a classifier\n        clf.fit(X,y)\n        pickle.dump(clf, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, \n                                                              GLOBAL_VARS.SVM_MODEL_NAME, CLASSIFIER), \'w\'))\n        \n    #     # Training Metrics\n    #     info(\'Evaluating on Training Data\')\n    #     yp = clf.predict(X)\n    #     yp_score = clf.decision_function(X)\n    #     print yp\n    #     training_metrics = get_metrics(y, yp_score, yp)\n    #     pr ...
#
# /home/s/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /home/s/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/s/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# /home/s/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/gensim/models/word2vec.pyc in train(self, sentences, total_words, word_count, total_examples, queue_factor, report_delay)
#     837
#     838         while unfinished_worker_count > 0:
# --> 839             report = progress_queue.get()  # blocks if workers too slow
#     840             if report is None:  # a thread reporting that it finished
#     841                 unfinished_worker_count -= 1
#
# /usr/lib/python2.7/Queue.pyc in get(self, block, timeout)
#     166             elif timeout is None:
#     167                 while not self._qsize():
# --> 168                     self.not_empty.wait()
#     169             elif timeout < 0:
#     170                 raise ValueError("'timeout' must be a non-negative number")
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:

# %%
GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(6)
info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))

# if we have the model, just load it, otherwise train the previous model
if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):
    doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
# Out:
# 2017-01-07 08:32:48,888 : INFO : ****************** Epoch 6 --- Working on doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6 *******************
# 2017-01-07 08:32:48,891 : INFO : loading Doc2Vec object from /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model
# 2017-01-07 08:33:14,046 : INFO : loading docvecs recursively from /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.docvecs.* with mmap=None
# 2017-01-07 08:33:14,048 : INFO : loading doctag_syn0 from /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.docvecs.doctag_syn0.npy with mmap=None
# 2017-01-07 08:33:21,936 : INFO : loading syn1neg from /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.syn1neg.npy with mmap=None
# 2017-01-07 08:33:24,446 : INFO : loading syn0 from /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.syn0.npy with mmap=None
# 2017-01-07 08:33:26,751 : INFO : setting ignored attribute syn0norm to None
# 2017-01-07 08:33:26,768 : INFO : setting ignored attribute cum_table to None

# %%
# %%time
ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))
doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model

# get the word2vec analogy accuracy score
# %time word2vec_result = doc2vec_model.accuracy(word2vec_questions_file, restrict_vocab=None)
epoch_word2vec_metrics.append(word2vec_result)
pickle.dump(word2vec_result, open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME,
                                               WORD2VEC_METRICS_FILENAME), 'w'))
# Out:
# 2017-01-07 08:05:32,383 : INFO : saving Doc2Vec object under /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model, separately None
# 2017-01-07 08:05:32,384 : INFO : storing numpy array 'doctag_syn0' to /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.docvecs.doctag_syn0.npy
# 2017-01-07 08:06:07,546 : INFO : storing numpy array 'syn1neg' to /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.syn1neg.npy
# 2017-01-07 08:06:22,413 : INFO : not storing attribute syn0norm
# 2017-01-07 08:06:22,414 : INFO : storing numpy array 'syn0' to /big/s/shalaby/parameter_search_doc2vec_models_new/full/doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None/epoch_6/model.syn0.npy
# 2017-01-07 08:06:37,511 : INFO : not storing attribute cum_table
# 2017-01-07 08:07:37,639 : INFO : precomputing L2-norms of word weight vectors
# 2017-01-07 08:08:36,552 : INFO : capital-common-countries: 9.2% (28/306)
# 2017-01-07 08:09:21,442 : INFO : capital-world: 6.8% (31/453)
# 2017-01-07 08:09:36,517 : INFO : currency: 0.0% (0/152)
# 2017-01-07 08:13:17,488 : INFO : city-in-state: 3.3% (75/2252)
# 2017-01-07 08:13:44,345 : INFO : family: 14.3% (39/272)
# 2017-01-07 08:15:09,837 : INFO : gram1-adjective-to-adverb: 6.8% (59/870)
# 2017-01-07 08:16:14,734 : INFO : gram2-opposite: 17.5% (114/650)
# 2017-01-07 08:18:26,319 : INFO : gram3-comparative: 72.7% (969/1332)
# 2017-01-07 08:19:40,242 : INFO : gram4-superlative: 34.1% (258/756)
# 2017-01-07 08:21:23,693 : INFO : gram5-present-participle: 23.0% (243/1056)
# 2017-01-07 08:23:05,897 : INFO : gram6-nationality-adjective: 11.7% (120/1030)
# 2017-01-07 08:25:25,383 : INFO : gram7-past-tense: 12.2% (172/1406)
# 2017-01-07 08:27:28,904 : INFO : gram8-plural: 43.9% (553/1260)
# 2017-01-07 08:28:50,549 : INFO : gram9-plural-verbs: 47.9% (389/812)
# 2017-01-07 08:28:50,553 : INFO : total: 24.2% (3050/12607)
# CPU times: user 3h 47min 44s, sys: 4h 31min 2s, total: 8h 18min 46s
# Wall time: 21min 14s
# CPU times: user 3h 48min 38s, sys: 4h 31min 12s, total: 8h 19min 51s
# Wall time: 23min 18s
