# %% [markdown]
# ## Remove y_true, y_score and y_binary_score from the saved metrics file

# %%
import pandas as pd
import os
import cPickle as pickle
import matplotlib.pylab as plt
from collections import defaultdict
import re
import numpy as np
from thesis.utils.metrics import *

# %%
ROOT_RESULTS_LOCATION = '/big/s/shalaby/parameter_search_doc2vec_models_new/sample_0.01/'
# ROOT_RESULTS_LOCATION = '/big/s/shalaby/parameter_search_doc2vec_models_new/full/'
CLASSIFICATION_TYPE = 'sections'
METRICS_PNG_FILE = '{}_validation_metrics.png'
METRICS_PKL_FILE = '{}_training_metrics.pkl'
DOC2VEC_FILES_PREFIX = 'model'
WORD2VEC_METRICS_FILE = 'word2vec_metrics.pkl'
EPOCH_PREFIX = 'epoch_{}'

DOC2VEC_MAX_EPOCHS = 20

CLASSIFICATION_SEPARATOR = ' ** '

CLASSIFICATION_TYPES_TO_USE = ['sections']
METRICS_TO_USE = ['coverage_error', 'f1_micro', 'f1_macro', 'top_3']
METRICS_BEST_VALUE_FUNC = {'coverage_error': np.min, 'f1_micro': np.max, 'f1_macro': np.max, 'top_3': np.max}
METRICS_BEST_INDEX_FUNC = {'coverage_error': np.argmin, 'f1_micro': np.argmax, 'f1_macro': np.argmax, 'top_3': np.argmax}

# %%
def get_subdirectories(d):
    #return filter(os.path.isdir, [f for f in os.listdir(d)])
    return [f for f in os.listdir(d) if os.path.isdir(os.path.join(d,f))]
def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower() 
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(l, key = alphanum_key)

# %%
get_subdirectories(ROOT_RESULTS_LOCATION)
# Out:
# ['doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'vocab_model_hs',
#  'vocab_model',
#  'doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_2000_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_100_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_1_neg_0_vocabsize_None',
#  'doc2vec_size_200_w_12_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None']

# %%
os.listdir(ROOT_RESULTS_LOCATION)
# Out:
# ['doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'vocab_model_hs',
#  'vocab_model',
#  'doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_2000_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_100_vocabsize_None',
#  'doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_1_neg_0_vocabsize_None',
#  'doc2vec_size_200_w_12_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None',
#  'doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None']

# %%
table_rows = []
table_index = []
for doc2vec_method in natural_sort(get_subdirectories(ROOT_RESULTS_LOCATION)):
    print doc2vec_method
    epochs_path = os.path.join(ROOT_RESULTS_LOCATION, doc2vec_method)
    # this will have the structure dict of classifiers -> dict of metrics -> list of values throughout the epoch
    epoch_metrics = dict()
    epoch_word2vec_results = []
    epochs_trained = 0
    for epoch in natural_sort(get_subdirectories(epochs_path)):
        print epoch
        epochs_trained += 1
        epoch_path =  os.path.join(epochs_path, epoch)
        if os.path.exists(os.path.join(epoch_path, WORD2VEC_METRICS_FILE)):
            method_word2vec_results = pickle.load(open(os.path.join(epoch_path, WORD2VEC_METRICS_FILE), 'r'))
            epoch_word2vec_results.append(method_word2vec_results)
        for classifier in get_subdirectories(epoch_path):
            # the values of a metric for a specific classifier throughout the epochs
            if not epoch_metrics.get(classifier): epoch_metrics[classifier] = defaultdict(list)
            
            for classf_type in CLASSIFICATION_TYPES_TO_USE:
                classifier_metrics_file = os.path.join(epoch_path, classifier, METRICS_PKL_FILE.format(classf_type))
                if os.path.exists(classifier_metrics_file):
                    classifier_metrics = pickle.load(open(classifier_metrics_file, 'r'))
                    
                    # Fix for adding the y_true, y_score and y_binary_score matrices to the metrics dump which inflated its size
                    if type(classifier_metrics) is list:
                        classifier_metrics = classifier_metrics[-1]
                    if classifier_metrics.get('y_true') is not None:
                        print 'y_true not None'
                        classifier_metrics.pop('y_true', None)
                        classifier_metrics.pop('y_score', None)
                        classifier_metrics.pop('y_binary_score', None)
                        pickle.dump(classifier_metrics, open(classifier_metrics_file, 'w'))
                    
                    # due to a mistake we made, some metrics files contain the whole history of metrics throughout the epochs
                    if type(classifier_metrics) is list:
                        classifier_metrics = classifier_metrics[-1]
                        pickle.dump(classifier_metrics, open(classifier_metrics_file, 'w'))
                    for metric_name in METRICS_TO_USE:
                        metric_full_name = classf_type + CLASSIFICATION_SEPARATOR + metric_name
                        epoch_metrics[classifier][metric_full_name].append(classifier_metrics[metric_name])
                        
    
    total = 0
    word2vec_epoch_correct_results = []
    for res in epoch_word2vec_results:
        total_result = [d for d in res if d['section'] == 'total'][0]
        total_correct = len(total_result['correct'])
        total_incorrect = len(total_result['incorrect'])
        if total == 0: total = total_correct + total_incorrect
        word2vec_epoch_correct_results.append(total_correct)
    best_word2vec_value = np.max(word2vec_epoch_correct_results) if len(word2vec_epoch_correct_results) else np.NaN
    best_word2vec_epoch = np.argmax(word2vec_epoch_correct_results) if len(word2vec_epoch_correct_results) else np.NaN
        
    # now that we are done with our epochs, lets figure out which epoch had the best value of every metric
    for classifier_name in sorted(epoch_metrics.keys()):
        classifier_metrics_dict = defaultdict(float)
        for metric_name in epoch_metrics[classifier_name].keys():
#             best_epoch = np.argmax(epoch_metrics[classifier_name][metric_name])
#             best_value = np.max(epoch_metrics[classifier_name][metric_name])
            just_metric = metric_name.split(CLASSIFICATION_SEPARATOR)[1]
            best_epoch = METRICS_BEST_INDEX_FUNC[just_metric](epoch_metrics[classifier_name][metric_name])
            best_value = METRICS_BEST_VALUE_FUNC[just_metric](epoch_metrics[classifier_name][metric_name])
            metric_range = abs(np.max(epoch_metrics[classifier_name][metric_name]) - np.min(epoch_metrics[classifier_name][metric_name]))
            classifier_metrics_dict[metric_name] = round(best_value, 3)
            classifier_metrics_dict[metric_name + ' -> epoch'] = best_epoch + 1
            classifier_metrics_dict[metric_name + ' range'] = round(metric_range, 3)

        classifier_metrics_dict['word2vec result'] = best_word2vec_value
        classifier_metrics_dict['word2vec result epoch'] = best_word2vec_epoch
        classifier_metrics_dict['Epochs'] = epochs_trained

        table_rows.append(classifier_metrics_dict)
        table_index.append(doc2vec_method + ' / ' + classifier_name)
        
            
df = pd.DataFrame(data=table_rows, index=table_index)            
df
# Out:
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# epoch_11
# y_true not None
# epoch_12
# y_true not None
# epoch_13
# y_true not None
# epoch_14
# y_true not None
# epoch_15
# y_true not None
# epoch_16
# y_true not None
# epoch_17
# y_true not None
# epoch_18
# y_true not None
# epoch_19
# y_true not None
# epoch_20
# y_true not None
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_2
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_3
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_4
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_5
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_6
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_7
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_8
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_9
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_10
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_11
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_12
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_13
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_14
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_15
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_16
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_17
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_18
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_19
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_20
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_100_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# epoch_11
# y_true not None
# epoch_12
# y_true not None
# epoch_13
# y_true not None
# epoch_14
# y_true not None
# epoch_15
# y_true not None
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_1_neg_0_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# epoch_11
# y_true not None
# epoch_12
# y_true not None
# epoch_13
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_2
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_3
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_4
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_5
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_6
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_7
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_8
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_9
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_10
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_11
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_12
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_13
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_14
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_15
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_16
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_17
# y_true not None
# y_true not None
# y_true not None
# y_true not None
# epoch_18
# y_true not None
# y_true not None
# y_true not None
# epoch_19
# y_true not None
# y_true not None
# y_true not None
# epoch_20
# y_true not None
# y_true not None
# y_true not None
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# y_true not None
# epoch_2
# y_true not None
# y_true not None
# epoch_3
# y_true not None
# y_true not None
# epoch_4
# y_true not None
# y_true not None
# epoch_5
# y_true not None
# y_true not None
# epoch_6
# y_true not None
# y_true not None
# epoch_7
# y_true not None
# y_true not None
# epoch_8
# y_true not None
# y_true not None
# epoch_9
# y_true not None
# y_true not None
# epoch_10
# y_true not None
# y_true not None
# epoch_11
# y_true not None
# y_true not None
# epoch_12
# y_true not None
# y_true not None
# epoch_13
# y_true not None
# y_true not None
# epoch_14
# y_true not None
# y_true not None
# epoch_15
# y_true not None
# y_true not None
# epoch_16
# y_true not None
# y_true not None
# epoch_17
# y_true not None
# y_true not None
# epoch_18
# y_true not None
# y_true not None
# epoch_19
# y_true not None
# y_true not None
# epoch_20
# y_true not None
# y_true not None
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# epoch_11
# y_true not None
# epoch_12
# y_true not None
# epoch_13
# y_true not None
# epoch_14
# y_true not None
# epoch_15
# y_true not None
# epoch_16
# y_true not None
# epoch_17
# y_true not None
# epoch_18
# y_true not None
# epoch_19
# y_true not None
# epoch_20
# y_true not None
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# y_true not None
# epoch_2
# y_true not None
# epoch_3
# y_true not None
# epoch_4
# y_true not None
# epoch_5
# y_true not None
# epoch_6
# y_true not None
# epoch_7
# y_true not None
# epoch_8
# y_true not None
# epoch_9
# y_true not None
# epoch_10
# y_true not None
# epoch_11
# y_true not None
# epoch_12
# y_true not None
# epoch_13
# y_true not None
# doc2vec_size_2000_w_5_type_pv-dbow_concat_1_mean_0_trainwords_0_hs_0_neg_10_vocabsize_None
# epoch_1
# vocab_model
# vocab_model_hs
#                                                     Epochs  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...      10
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...      15
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...       5
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...      13
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...      20
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...       9
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...      20
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...      13
#
#                                                     sections ** coverage_error  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                       3.310
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                       3.472
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       4.336
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       3.220
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       3.250
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       3.409
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       3.391
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       3.494
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                       3.324
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       3.186
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       3.229
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       4.255
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       3.182
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       4.221
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       3.179
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                       3.265
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                       3.171
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                       3.106
#
#                                                     sections ** coverage_error -> epoch  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                                   10
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                   15
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                                    5
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                                   12
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                                   17
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                                   20
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                                    8
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                                   10
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                                   13
#
#                                                     sections ** coverage_error range  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                             0.185
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                             0.071
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.500
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.162
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.157
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.147
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.116
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             0.046
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                             0.080
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             0.152
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             0.131
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             0.344
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             0.157
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             0.362
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             0.154
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                             0.067
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                             0.412
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                             0.185
#
#                                                     sections ** f1_macro  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                 0.535
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                 0.513
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.463
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.549
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.543
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.519
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.530
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.519
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                 0.535
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.554
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.546
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.473
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.556
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                 0.477
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                 0.557
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                 0.543
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                 0.554
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                 0.570
#
#                                                     sections ** f1_macro -> epoch  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                             10
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             15
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                              5
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                             12
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             17
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                              2
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                             19
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                             13
#
#                                                     sections ** f1_macro range  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                       0.020
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                       0.008
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.078
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.017
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.018
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.015
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.010
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.004
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                       0.008
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.017
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.014
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.042
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.016
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       0.043
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       0.018
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                       0.006
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                       0.048
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                       0.027
#
#                                                     sections ** f1_micro  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                 0.619
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                 0.592
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.656
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.635
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.628
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.597
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.614
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                 0.602
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                 0.619
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.640
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.632
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.665
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                 0.642
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                 0.668
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                 0.643
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                 0.626
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                 0.638
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                 0.654
#
#                                                     sections ** f1_micro -> epoch  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                             10
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                             15
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                              5
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                             12
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             17
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                             19
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                              2
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                             19
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                             13
#
#                                                     sections ** f1_micro range  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                       0.021
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                       0.009
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.054
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.020
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.019
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.016
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.012
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                       0.005
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                       0.009
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.018
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.016
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.037
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                       0.018
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       0.039
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                       0.020
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                       0.006
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                       0.062
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                       0.027
#
#                                                     sections ** top_3  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...              0.865
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...              0.833
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.784
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.880
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.873
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.839
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.860
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...              0.849
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...              0.864
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...              0.884
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...              0.875
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...              0.791
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...              0.885
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...              0.795
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...              0.885
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...              0.869
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...              0.879
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...              0.893
#
#                                                     sections ** top_3 -> epoch  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                           9
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                          15
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                           5
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                          12
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                          17
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                          20
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                           2
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                          17
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                          13
#
#                                                     sections ** top_3 range  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                    0.024
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                    0.013
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.046
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.017
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.021
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.022
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.011
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                    0.005
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                    0.010
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                    0.017
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                    0.015
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                    0.027
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                    0.016
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                    0.030
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                    0.016
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                    0.007
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                    0.075
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                    0.024
#
#                                                     word2vec result  \
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                0
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...             2413
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                0
#
#                                                     word2vec result epoch
# doc2vec_size_100_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_200_w_12_type_pv-dbow_concat_1_mea...                      0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_300_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_300_w_8_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_500_w_5_type_pv-dbow_concat_1_mean...                      0
# doc2vec_size_500_w_8_type_dm_concat_0_mean_1_tr...                      9
# doc2vec_size_1000_w_8_type_pv-dbow_concat_1_mea...                      0
