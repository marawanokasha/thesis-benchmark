# %%
import cPickle as pickle
import string
import os

# %matplotlib inline
import numpy as np
import random
import time

import logging
from logging import info

from multiprocessing import Pool as ThreadPool
import itertools

# %%
root = logging.getLogger()
for handler in root.handlers[:]:
    root.removeHandler(handler)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # adds a default StreamHanlder
#root.addHandler(logging.StreamHandler())

# %%
root_location = "/big/s/shalaby/"
preprocessed_data_location = root_location + "preprocessed_data/extended_pv_abs_desc_claims_full_chunks/"
new_preprocessed_data_location = root_location + "preprocessed_data/extended_pv_abs_desc_claims_full_chunks_merged/"

if not os.path.exists(new_preprocessed_data_location):
    os.makedirs(new_preprocessed_data_location)

# %%
LINES_PER_DOCUMENT = 34
BATCH_DOCS_SIZE = 10000
NEW_BATCH_DOCS_SIZE = 20000
BATCH_SIZE_LINES = LINES_PER_DOCUMENT * BATCH_DOCS_SIZE
NEW_BATCH_SIZE_LINES = LINES_PER_DOCUMENT * NEW_BATCH_DOCS_SIZE


TRAINING_PREPROCESSED_FILES_PREFIX = preprocessed_data_location + "extended_pv_training_docs_data_preprocessed-"
VALIDATION_PREPROCESSED_FILES_PREFIX = preprocessed_data_location + "validation_docs_data_preprocessed-"
TEST_PREPROCESSED_FILES_PREFIX = preprocessed_data_location + "test_docs_data_preprocessed-"


TRAINING_NEW_PREPROCESSED_FILES_PREFIX = new_preprocessed_data_location + "extended_pv_training_docs_data_preprocessed-"
VALIDATION_NEW_PREPROCESSED_FILES_PREFIX = new_preprocessed_data_location + "validation_docs_data_preprocessed-"
TEST_NEW_PREPROCESSED_FILES_PREFIX = new_preprocessed_data_location + "test_docs_data_preprocessed-"

# %%
FILE_PREFIX_TO_READ = TRAINING_PREPROCESSED_FILES_PREFIX
FILE_PREFIX_TO_WRITE = TRAINING_NEW_PREPROCESSED_FILES_PREFIX

# %%
FILE_PREFIX_TO_READ
# Out:
# '/big/s/shalaby/preprocessed_data/extended_pv_abs_desc_claims_full_chunks/extended_pv_training_docs_data_preprocessed-'

# %%
curr_index = 0
curr_read_file_index = 0
curr_write_file_index = 0

read_file = None
write_file = None

def read_line():
    global read_file, curr_read_file_index
    while True:
        if read_file is None:
            info("Reading new file for batch {}".format(curr_read_file_index))
            if os.path.exists(FILE_PREFIX_TO_READ + str(curr_read_file_index)):
                read_file = open(FILE_PREFIX_TO_READ + str(curr_read_file_index), "r")
            else: 
                raise StopIteration()
        for line in read_file:
            yield line
            
        curr_read_file_index += BATCH_DOCS_SIZE
        read_file.close()
        read_file = None

def write_line(line):
    global write_file, curr_write_file_index, curr_index
    if write_file is None:
        info("Writing to a new file for batch {}".format(curr_write_file_index))
        write_file = open(FILE_PREFIX_TO_WRITE + str(curr_write_file_index), "w")
    write_file.write(line)
    curr_index += 1
    if curr_index % NEW_BATCH_SIZE_LINES == 0:
        curr_write_file_index += NEW_BATCH_DOCS_SIZE
        write_file.close()
        write_file = None
    

for line in read_line():
    write_line(line)
# Out:
# 2017-04-05 13:12:25,504 : INFO : Reading new file for batch 0
# 2017-04-05 13:12:25,553 : INFO : Writing to a new file for batch 0
# 2017-04-05 13:12:53,143 : INFO : Reading new file for batch 10000
# 2017-04-05 13:13:35,729 : INFO : Reading new file for batch 20000
# 2017-04-05 13:13:35,821 : INFO : Writing to a new file for batch 20000
# 2017-04-05 13:13:52,384 : INFO : Reading new file for batch 30000
# 2017-04-05 13:14:42,721 : INFO : Reading new file for batch 40000
# 2017-04-05 13:14:42,795 : INFO : Writing to a new file for batch 40000
# 2017-04-05 13:14:59,127 : INFO : Reading new file for batch 50000
# 2017-04-05 13:15:53,557 : INFO : Reading new file for batch 60000
# 2017-04-05 13:15:53,673 : INFO : Writing to a new file for batch 60000
# 2017-04-05 13:16:10,076 : INFO : Reading new file for batch 70000
# 2017-04-05 13:16:47,610 : INFO : Reading new file for batch 80000
# 2017-04-05 13:16:47,612 : INFO : Writing to a new file for batch 80000
# 2017-04-05 13:16:50,607 : INFO : Reading new file for batch 90000
# 2017-04-05 13:17:27,877 : INFO : Reading new file for batch 100000
# 2017-04-05 13:17:27,984 : INFO : Writing to a new file for batch 100000
# 2017-04-05 13:17:45,658 : INFO : Reading new file for batch 110000
# 2017-04-05 13:18:37,844 : INFO : Reading new file for batch 120000
# 2017-04-05 13:18:37,988 : INFO : Writing to a new file for batch 120000
# 2017-04-05 13:18:54,104 : INFO : Reading new file for batch 130000
# 2017-04-05 13:19:47,205 : INFO : Reading new file for batch 140000
# 2017-04-05 13:19:47,261 : INFO : Writing to a new file for batch 140000
# 2017-04-05 13:20:03,268 : INFO : Reading new file for batch 150000
# 2017-04-05 13:20:55,648 : INFO : Reading new file for batch 160000
# 2017-04-05 13:20:55,652 : INFO : Writing to a new file for batch 160000
# 2017-04-05 13:21:11,833 : INFO : Reading new file for batch 170000
# 2017-04-05 13:22:04,902 : INFO : Reading new file for batch 180000
# 2017-04-05 13:22:05,020 : INFO : Writing to a new file for batch 180000
# 2017-04-05 13:22:21,715 : INFO : Reading new file for batch 190000
# 2017-04-05 13:23:15,225 : INFO : Reading new file for batch 200000
# 2017-04-05 13:23:15,308 : INFO : Writing to a new file for batch 200000
# 2017-04-05 13:23:31,549 : INFO : Reading new file for batch 210000
# 2017-04-05 13:24:24,768 : INFO : Reading new file for batch 220000
# 2017-04-05 13:24:24,876 : INFO : Writing to a new file for batch 220000
# 2017-04-05 13:24:40,917 : INFO : Reading new file for batch 230000
# 2017-04-05 13:25:31,739 : INFO : Reading new file for batch 240000
# 2017-04-05 13:25:31,793 : INFO : Writing to a new file for batch 240000
# 2017-04-05 13:25:48,399 : INFO : Reading new file for batch 250000
# 2017-04-05 13:26:39,723 : INFO : Reading new file for batch 260000
# 2017-04-05 13:26:39,766 : INFO : Writing to a new file for batch 260000
# 2017-04-05 13:26:55,891 : INFO : Reading new file for batch 270000
# 2017-04-05 13:27:48,425 : INFO : Reading new file for batch 280000
# 2017-04-05 13:27:48,467 : INFO : Writing to a new file for batch 280000
# 2017-04-05 13:28:04,508 : INFO : Reading new file for batch 290000
# 2017-04-05 13:28:56,378 : INFO : Reading new file for batch 300000
# 2017-04-05 13:28:56,560 : INFO : Writing to a new file for batch 300000
# 2017-04-05 13:29:12,814 : INFO : Reading new file for batch 310000
# 2017-04-05 13:30:05,390 : INFO : Reading new file for batch 320000
# 2017-04-05 13:30:05,545 : INFO : Writing to a new file for batch 320000
# 2017-04-05 13:30:21,582 : INFO : Reading new file for batch 330000
# 2017-04-05 13:31:14,408 : INFO : Reading new file for batch 340000
# 2017-04-05 13:31:14,493 : INFO : Writing to a new file for batch 340000
# 2017-04-05 13:31:30,689 : INFO : Reading new file for batch 350000
# 2017-04-05 13:32:23,225 : INFO : Reading new file for batch 360000
# 2017-04-05 14:07:49,673 : INFO : Reading new file for batch 990000
# 2017-04-05 14:08:41,893 : INFO : Reading new file for batch 1000000
# 2017-04-05 14:08:41,959 : INFO : Writing to a new file for batch 1000000
# 2017-04-05 14:09:00,780 : INFO : Reading new file for batch 1010000
# 2017-04-05 14:09:51,126 : INFO : Reading new file for batch 1020000
# 2017-04-05 14:09:51,133 : INFO : Writing to a new file for batch 1020000
# 2017-04-05 14:10:08,349 : INFO : Reading new file for batch 1030000
# 2017-04-05 14:10:58,881 : INFO : Reading new file for batch 1040000
# 2017-04-05 14:10:58,927 : INFO : Writing to a new file for batch 1040000
# 2017-04-05 14:11:16,805 : INFO : Reading new file for batch 1050000
# 2017-04-05 14:12:10,926 : INFO : Reading new file for batch 1060000
# 2017-04-05 14:12:10,959 : INFO : Writing to a new file for batch 1060000
# 2017-04-05 14:12:27,707 : INFO : Reading new file for batch 1070000
# 2017-04-05 14:13:16,057 : INFO : Reading new file for batch 1080000
# 2017-04-05 14:13:16,100 : INFO : Writing to a new file for batch 1080000
# 2017-04-05 14:13:33,361 : INFO : Reading new file for batch 1090000
# 2017-04-05 14:14:25,823 : INFO : Reading new file for batch 1100000
# 2017-04-05 14:14:25,873 : INFO : Writing to a new file for batch 1100000
# 2017-04-05 14:14:42,516 : INFO : Reading new file for batch 1110000
# 2017-04-05 14:15:32,462 : INFO : Reading new file for batch 1120000
# 2017-04-05 14:15:32,516 : INFO : Writing to a new file for batch 1120000
# 2017-04-05 14:15:49,678 : INFO : Reading new file for batch 1130000
# 2017-04-05 14:16:41,537 : INFO : Reading new file for batch 1140000
# 2017-04-05 14:16:41,571 : INFO : Writing to a new file for batch 1140000
# 2017-04-05 14:16:58,219 : INFO : Reading new file for batch 1150000
# 2017-04-05 14:17:50,566 : INFO : Reading new file for batch 1160000
# 2017-04-05 14:17:50,571 : INFO : Writing to a new file for batch 1160000
# 2017-04-05 14:18:06,792 : INFO : Reading new file for batch 1170000
# 2017-04-05 14:18:55,439 : INFO : Reading new file for batch 1180000
# 2017-04-05 14:18:55,442 : INFO : Writing to a new file for batch 1180000
# 2017-04-05 14:19:12,105 : INFO : Reading new file for batch 1190000
# 2017-04-05 14:20:04,426 : INFO : Reading new file for batch 1200000
# 2017-04-05 14:20:04,474 : INFO : Writing to a new file for batch 1200000
# 2017-04-05 14:20:20,768 : INFO : Reading new file for batch 1210000
# 2017-04-05 14:21:11,697 : INFO : Reading new file for batch 1220000
# 2017-04-05 14:21:11,749 : INFO : Writing to a new file for batch 1220000
# 2017-04-05 14:21:29,265 : INFO : Reading new file for batch 1230000
# 2017-04-05 14:22:18,899 : INFO : Reading new file for batch 1240000
# 2017-04-05 14:22:18,922 : INFO : Writing to a new file for batch 1240000
# 2017-04-05 14:22:34,674 : INFO : Reading new file for batch 1250000
# 2017-04-05 14:23:24,833 : INFO : Reading new file for batch 1260000
# 2017-04-05 14:23:24,859 : INFO : Writing to a new file for batch 1260000
# 2017-04-05 14:23:40,681 : INFO : Reading new file for batch 1270000
# 2017-04-05 14:24:31,491 : INFO : Reading new file for batch 1280000
# 2017-04-05 14:24:31,530 : INFO : Writing to a new file for batch 1280000
# 2017-04-05 14:24:41,936 : INFO : Reading new file for batch 1290000
