# %% [markdown]
# ## Creates the doc2vec vector embeddings for a specific configuration

# %%
import json
import nltk
from nltk.tokenize import RegexpTokenizer
import string
import math
import os
import time
from collections import namedtuple
import cPickle as pickle
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import random
import gzip

from multiprocessing import Process, Queue

from multiprocessing.dummy import Pool as ThreadPool
import itertools

from sklearn.metrics import coverage_error
import sklearn.metrics
from sklearn.multiclass import OneVsRestClassifier
from sklearn import linear_model
from sklearn.preprocessing import MultiLabelBinarizer

from gensim.models.doc2vec import Doc2Vec, LabeledSentence

import logging
from logging import info
from functools import partial

from thesis.utils.metrics import *
from thesis.utils.file import *

# %% [markdown]
# ## Global variables used throughout the script

# %%
root = logging.getLogger()
for handler in root.handlers[:]:
    root.removeHandler(handler)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # adds a default StreamHanlder
#root.addHandler(logging.StreamHandler())

# %%
SVM_SEED = 1234
DOC2VEC_SEED = 1234

# %%
MIN_WORD_COUNT = 100
NUM_CORES = 8

# %%
GLOBAL_VARS = namedtuple('GLOBAL_VARS', ['MODEL_NAME', 'DOC2VEC_MODEL_NAME', 'DOC2VEC_MODEL', 
                                         'SVM_MODEL_NAME', 'NN_MODEL_NAME'])

# %%
VOCAB_MODEL = "vocab_model"
MODEL_PREFIX = "model"
VALIDATION_DICT = "validation_dict.pkl"
TEST_MATRIX = "test_matrix.pkl"
TEST_DICT = "test_dict.pkl"
METRICS = "metrics.pkl"
CLASSIFIER = "classifier.pkl"

# %%
root_location = "/mnt/data/shalaby/"
# exports_location = root_location + "exported_data/"
exports_location = "/mnt/data2/shalaby/" + "exported_data/"

doc_classifications_map_file = exports_location + "doc_classification_map.pkl"
training_docs_list_file = exports_location + "training_docs_list.pkl"
validation_docs_list_file = exports_location + "validation_docs_list.pkl"
test_docs_list_file = exports_location + "test_docs_list.pkl"

preprocessed_location = root_location + "preprocessed_data/extended_pv_abs_desc_claims_full_chunks/"

training_preprocessed_files_prefix = preprocessed_location + "extended_pv_training_docs_data_preprocessed-"
validation_preprocessed_files_prefix = preprocessed_location + "extended_pv_validation_docs_data_preprocessed-"
test_preprocessed_files_prefix = preprocessed_location + "extended_pv_test_docs_data_preprocessed-"

# %% [markdown]
# ## Load general data required for classification

# %%
# %%time
doc_classification_map = pickle.load(open(doc_classifications_map_file))
training_docs_list = pickle.load(open(training_docs_list_file))
validation_docs_list = pickle.load(open(validation_docs_list_file))
test_docs_list = pickle.load(open(test_docs_list_file))
# Out:
# CPU times: user 19.7 s, sys: 1.35 s, total: 21 s
# Wall time: 21 s

# %%
len(training_docs_list)
# Out:
# 1286325

# %%
len(validation_docs_list)
# Out:
# 321473

# %%
len(test_docs_list)
# Out:
# 401877

# %% [markdown]
# # Utility functions for data loading

# %%
VALIDATION_MINI_BATCH_SIZE = 100000
def get_extended_docs_with_inference_data_only(doc2vec_model, file_to_write, preprocessed_files_prefix):
    """
    Use the trained doc2vec model to get the paragraph vector representations of the validation or test documents
    """

    def infer_one_doc(doc_tuple):
        # doc2vec_model.random = np.random.RandomState(DOC2VEC_SEED)
        doc_id, doc_tokens = doc_tuple
        rep = doc2vec_model.infer_vector(doc_tokens)
        return (doc_id, rep)

    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write)):
        info("===== Loading inference vectors")
        inference_documents_reps = pickle.load(open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write)))
        info("Loaded inference vectors matrix")
    else:
        inference_documents_reps = {}
        info("===== Getting vectors with inference")

        # Multi-threaded inference
#         inference_docs_iterator = ExtendedPVDocumentBatchGenerator(preprocessed_files_prefix, batch_size=None)
        inference_docs_iterator = BatchWrapper(preprocessed_files_prefix, batch_size=None)
        generator_func = inference_docs_iterator.__iter__()
        pool = ThreadPool(NUM_CORES)
        # map consumes the whole iterator on the spot, so we have to use itertools.islice to fake mini-batching
        mini_batch_size = VALIDATION_MINI_BATCH_SIZE
        batches_run = 1
        while True:
            threaded_reps_partial = pool.map(infer_one_doc, itertools.islice(generator_func, mini_batch_size))
            info("Finished: {} tags".format(batches_run * mini_batch_size))
            batches_run += 1
            if threaded_reps_partial:
                # threaded_reps.extend(threaded_reps_partial)
                inference_documents_reps.update(threaded_reps_partial)
            else:
                break

        pickle.dump(inference_documents_reps,
                    open(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, file_to_write), 'w'))

    return inference_documents_reps

# %%
class ExtendedPVDocumentBatchGenerator(Process):
    def __init__(self, filename_prefix, queue, batch_size=10000, start_file=0, offset=10000):
        super(ExtendedPVDocumentBatchGenerator, self).__init__()
        self.queue = queue
        self.offset = offset
        self.filename_prefix = filename_prefix
        self.files_loaded = start_file - offset

    def run(self):
        cur_file = None
        while True:
            try:
                if cur_file is None:
                    info("Loading new file for index: {}".format(str(self.files_loaded + self.offset)))
                    cur_file = gzip.open(self.filename_prefix + str(self.files_loaded + self.offset) + '.gz')
#                     cur_file = open(self.filename_prefix + str(self.files_loaded + self.offset))
                    self.files_loaded += self.offset
                for line in cur_file:
                    self.queue.put(line)
                cur_file.close()
                cur_file = None
            except IOError:
                self.queue.put(False, block=True, timeout=None)
                info("All files are loaded - last file: {}".format(str(self.files_loaded + self.offset)))
                return


class BatchWrapper(object):
    def __init__(self, training_preprocessed_files_prefix, buffer_size=10000, batch_size=10000, level=1, level_type=None):
        assert batch_size <= 10000 or batch_size is None
        self.level = level
        self.level_type = level_type[0]
        self.batch_size = batch_size
        self.q = Queue(maxsize=buffer_size)
        self.p = ExtendedPVDocumentBatchGenerator(training_preprocessed_files_prefix, queue=self.q,
                                                  batch_size=batch_size, start_file=0, offset=10000)
        self.p.start()
        self.cur_data = []

    def is_correct_type(self, doc_id):
        parts = doc_id.split("_")
        len_parts = len(parts)
        if len_parts == self.level:
            if len_parts == 1:
                return True
            if len_parts == self.level and (parts[1][0] == self.level_type or self.level_type is None):
                return True
        return False

    def return_sentences(self, line):
        line_array = tuple(line.split(" "))
        doc_id = line_array[0]
        if not self.is_correct_type(doc_id):
            return False
        line_array = line_array[1:]
        len_line_array = len(line_array)
        curr_batch_iter = 0
        # divide the document to batches according to the batch size
        sentences = []
        while curr_batch_iter < len_line_array:
            sentences.append(LabeledSentence(words=line_array[curr_batch_iter: curr_batch_iter + self.batch_size], tags=[doc_id]))
            curr_batch_iter += self.batch_size
        return tuple(sentences)

    def __iter__(self):
        while True:
            item = self.q.get(block=True)
            if item is False:
                raise StopIteration()
            else:
                sentences = self.return_sentences(item)
                if not sentences:
                    None
                else:
                    for sentence in sentences:
                        yield sentence

# %% [markdown]
# # Doc2vec and SVM Parameters

# %%
DOC2VEC_SIZE = 200
DOC2VEC_WINDOW = 2
DOC2VEC_MAX_VOCAB_SIZE = None
DOC2VEC_SAMPLE = 1e-3
DOC2VEC_TYPE = 1
DOC2VEC_HIERARCHICAL_SAMPLE = 0
DOC2VEC_NEGATIVE_SAMPLE_SIZE = 10
DOC2VEC_CONCAT = 0
DOC2VEC_MEAN = 1
DOC2VEC_TRAIN_WORDS = 0
DOC2VEC_EPOCHS = 1 # we do our training manually one epoch at a time
DOC2VEC_MAX_EPOCHS = 8
REPORT_DELAY = 20 # report the progress every x seconds
REPORT_VOCAB_PROGRESS = 100000 # report vocab progress every x documents

# %% [markdown]
# ## Create the Doc2vec model and create/load the vocab

# %%
models = [
    (3, 'claims')
]
level, model_name = models[0]

# %%
info("creating/loading vocabulary for " + str(level) + ' ' + model_name + ' in ')
doc2vec_model_save_location = os.path.join(root_location,
                                           "parameter_search_doc2vec_models_" + str(level) + '_' + model_name,
                                           "full")
if not os.path.exists(doc2vec_model_save_location):
    os.makedirs(doc2vec_model_save_location)
if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL)):
    os.makedirs(os.path.join(doc2vec_model_save_location, VOCAB_MODEL))

placeholder_model_name = 'doc2vec_size_{}_w_{}_type_{}_concat_{}_mean_{}_trainwords_{}_hs_{}_neg_{}_vocabsize_{}_model_{}'.format(DOC2VEC_SIZE,
                                                                DOC2VEC_WINDOW,
                                                                'dm' if DOC2VEC_TYPE == 1 else 'pv-dbow',
                                                                DOC2VEC_CONCAT, DOC2VEC_MEAN,
                                                                DOC2VEC_TRAIN_WORDS,
                                                                DOC2VEC_HIERARCHICAL_SAMPLE,DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                                                                str(DOC2VEC_MAX_VOCAB_SIZE),
                                                                str(level) + '_' + model_name
                                                                )
GLOBAL_VARS.DOC2VEC_MODEL_NAME = placeholder_model_name
placeholder_model_name = os.path.join(placeholder_model_name, "epoch_{}")
info("FILE " + os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
doc2vec_model = Doc2Vec(size=DOC2VEC_SIZE, window=DOC2VEC_WINDOW, min_count=MIN_WORD_COUNT,
                max_vocab_size= DOC2VEC_MAX_VOCAB_SIZE,
                sample=DOC2VEC_SAMPLE, seed=DOC2VEC_SEED, workers=NUM_CORES,
                # doc2vec algorithm dm=1 => PV-DM, dm=2 => PV-DBOW, PV-DM dictates CBOW for words
                dm=DOC2VEC_TYPE,
                # hs=0 => negative sampling, hs=1 => hierarchical softmax
                hs=DOC2VEC_HIERARCHICAL_SAMPLE, negative=DOC2VEC_NEGATIVE_SAMPLE_SIZE,
                dm_concat=DOC2VEC_CONCAT,
                # would train words with skip-gram on top of cbow, we don't need that for now
                dbow_words=DOC2VEC_TRAIN_WORDS,
                iter=DOC2VEC_EPOCHS)

GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model

if not os.path.exists(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX)):
    
    info("Creating vocab model")
    training_docs_iterator = BatchWrapper(training_preprocessed_files_prefix, batch_size=10000, level=level,
                                          level_type=model_name)
    doc2vec_model.build_vocab(sentences=training_docs_iterator, progress_per=REPORT_VOCAB_PROGRESS)
    doc2vec_model.save(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
else:
    info("Loading vocab model")
    doc2vec_model_vocab_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, VOCAB_MODEL, MODEL_PREFIX))
    doc2vec_model.reset_from(doc2vec_model_vocab_model)
# Out:
# 2017-04-09 18:10:38,746 : INFO : creating/loading vocabulary for 3 claims in
# 2017-04-09 18:10:38,749 : INFO : FILE /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model
# 2017-04-09 18:10:38,752 : INFO : Loading vocab model
# 2017-04-09 18:10:38,753 : INFO : loading Doc2Vec object from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model
# 2017-04-09 18:11:05,017 : INFO : loading docvecs recursively from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model.docvecs.* with mmap=None
# 2017-04-09 18:11:05,019 : INFO : loading doctag_syn0 from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model.docvecs.doctag_syn0.npy with mmap=None
# 2017-04-09 18:11:12,531 : INFO : loading wv recursively from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model.wv.* with mmap=None
# 2017-04-09 18:11:12,532 : INFO : loading syn0 from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model.wv.syn0.npy with mmap=None
# 2017-04-09 18:11:12,682 : INFO : setting ignored attribute syn0norm to None
# 2017-04-09 18:11:12,683 : INFO : loading syn1neg from /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model.syn1neg.npy with mmap=None
# 2017-04-09 18:11:12,820 : INFO : setting ignored attribute cum_table to None
# 2017-04-09 18:11:12,821 : INFO : loaded /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/vocab_model/model
# 2017-04-09 18:11:13,213 : INFO : resetting layer weights

# %% [markdown]
# ## Actual Training, validation and Metrics Loop

# %%
doc2vec_model.min_alpha = 0.025
DOC2VEC_ALPHA_DECREASE = 0.001

# %%
doc2vec_model.workers = NUM_CORES

# %%
# %%time
# when resuming, resume from an epoch with a previously created doc2vec model to get the learning rate right
start_from = 1
for epoch in range(start_from, DOC2VEC_MAX_EPOCHS+1):
    GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)
    info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))
    
    # if we have the model, just load it, otherwise train the previous model
    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):
        doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        doc2vec_model.workers = NUM_CORES
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
    else:
        # train the doc2vec model
        training_docs_iterator = BatchWrapper(training_preprocessed_files_prefix, batch_size=10000, level=level,
                                          level_type=model_name)
        # %time doc2vec_model.train(sentences=training_docs_iterator, report_delay=REPORT_DELAY)
        doc2vec_model.alpha -= DOC2VEC_ALPHA_DECREASE  # decrease the learning rate
        doc2vec_model.min_alpha = doc2vec_model.alpha  # fix the learning rate, no decay
        ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))
        doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))
        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model
        
    # only do the inference for higher epochs, as inference usually takes as much time as the actual training
    if epoch > 7:
        # Validation Embeddings
        info('Getting Validation Embeddings')
        Xv = get_extended_docs_with_inference_data_only(doc2vec_model, VALIDATION_DICT, 
                                         validation_preprocessed_files_prefix)
# Out:
# 2017-04-09 18:12:43,128 : INFO : ****************** Epoch 1 --- Working on doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1 *******************
# 2017-04-09 18:12:43,374 : INFO : training model with 8 workers on 67011 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=10 window=2
# 2017-04-09 18:12:43,378 : INFO : expecting 5145291 sentences, matching count from corpus used for vocabulary survey
# 2017-04-09 18:12:43,376 : INFO : Loading new file for index: 0
# 2017-04-09 18:12:44,387 : INFO : PROGRESS: at 0.01% examples, 88962 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:13:04,477 : INFO : PROGRESS: at 0.36% examples, 155074 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:13:24,553 : INFO : PROGRESS: at 0.73% examples, 160214 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:13:24,882 : INFO : Loading new file for index: 10000
# 2017-04-09 18:13:44,596 : INFO : PROGRESS: at 1.13% examples, 164978 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:14:04,607 : INFO : PROGRESS: at 1.49% examples, 164083 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:14:06,010 : INFO : Loading new file for index: 20000
# 2017-04-09 18:14:24,640 : INFO : PROGRESS: at 1.85% examples, 162936 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:14:44,714 : INFO : PROGRESS: at 2.21% examples, 162718 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:14:49,442 : INFO : Loading new file for index: 30000
# 2017-04-09 18:15:04,870 : INFO : PROGRESS: at 2.57% examples, 162262 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:15:24,952 : INFO : PROGRESS: at 2.93% examples, 162356 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:15:33,027 : INFO : Loading new file for index: 40000
# 2017-04-09 18:15:44,989 : INFO : PROGRESS: at 3.35% examples, 164788 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:16:05,000 : INFO : PROGRESS: at 3.74% examples, 166001 words/s, in_qsize 13, out_qsize 1
# 2017-04-09 18:16:10,927 : INFO : Loading new file for index: 50000
# 2017-04-09 18:16:25,058 : INFO : PROGRESS: at 4.10% examples, 165933 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:16:45,081 : INFO : PROGRESS: at 4.48% examples, 166414 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:16:52,650 : INFO : Loading new file for index: 60000
# 2017-04-09 18:17:05,129 : INFO : PROGRESS: at 4.89% examples, 168172 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:17:25,132 : INFO : PROGRESS: at 5.27% examples, 168090 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:17:32,468 : INFO : Loading new file for index: 70000
# 2017-04-09 18:17:45,170 : INFO : PROGRESS: at 5.64% examples, 168205 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:18:05,183 : INFO : PROGRESS: at 5.98% examples, 167217 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:18:16,095 : INFO : Loading new file for index: 80000
# 2017-04-09 18:18:25,184 : INFO : PROGRESS: at 6.36% examples, 167389 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:18:45,211 : INFO : PROGRESS: at 6.74% examples, 167764 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:18:56,504 : INFO : Loading new file for index: 90000
# 2017-04-09 18:19:05,225 : INFO : PROGRESS: at 7.13% examples, 168081 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:19:25,253 : INFO : PROGRESS: at 7.52% examples, 168375 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:19:38,005 : INFO : Loading new file for index: 100000
# 2017-04-09 18:19:45,282 : INFO : PROGRESS: at 7.89% examples, 168428 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:20:05,308 : INFO : PROGRESS: at 8.30% examples, 169017 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:20:16,581 : INFO : Loading new file for index: 110000
# 2017-04-09 18:20:25,322 : INFO : PROGRESS: at 8.71% examples, 169761 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:20:45,327 : INFO : PROGRESS: at 9.07% examples, 169449 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:20:57,261 : INFO : Loading new file for index: 120000
# 2017-04-09 18:21:05,343 : INFO : PROGRESS: at 9.45% examples, 169522 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:21:25,377 : INFO : PROGRESS: at 9.82% examples, 169539 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 18:21:37,964 : INFO : Loading new file for index: 130000
# 2017-04-09 18:21:45,389 : INFO : PROGRESS: at 10.22% examples, 169872 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:22:05,430 : INFO : PROGRESS: at 10.62% examples, 170134 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:22:16,668 : INFO : Loading new file for index: 140000
# 2017-04-09 18:22:25,443 : INFO : PROGRESS: at 11.02% examples, 170378 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:22:45,514 : INFO : PROGRESS: at 11.38% examples, 170113 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:22:57,904 : INFO : Loading new file for index: 150000
# 2017-04-09 18:23:05,625 : INFO : PROGRESS: at 11.78% examples, 170301 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:23:25,680 : INFO : PROGRESS: at 12.14% examples, 170202 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 18:23:39,802 : INFO : Loading new file for index: 160000
# 2017-04-09 18:23:45,717 : INFO : PROGRESS: at 12.51% examples, 170007 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:24:05,863 : INFO : PROGRESS: at 12.87% examples, 169711 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 18:24:22,257 : INFO : Loading new file for index: 170000
# 2017-04-09 18:24:25,896 : INFO : PROGRESS: at 13.24% examples, 169683 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:24:45,913 : INFO : PROGRESS: at 13.60% examples, 169430 words/s, in_qsize 15, out_qsize 1
# 2017-04-09 18:25:05,271 : INFO : Loading new file for index: 180000
# 2017-04-09 18:25:05,919 : INFO : PROGRESS: at 13.97% examples, 169356 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:25:25,931 : INFO : PROGRESS: at 14.36% examples, 169582 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:25:45,933 : INFO : PROGRESS: at 14.73% examples, 169455 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:25:46,373 : INFO : Loading new file for index: 190000
# 2017-04-09 18:26:06,038 : INFO : PROGRESS: at 15.11% examples, 169503 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:26:26,054 : INFO : PROGRESS: at 15.50% examples, 169636 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:26:27,018 : INFO : Loading new file for index: 200000
# 2017-04-09 18:26:46,065 : INFO : PROGRESS: at 15.88% examples, 169650 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:27:06,089 : INFO : PROGRESS: at 16.26% examples, 169721 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:27:07,886 : INFO : Loading new file for index: 210000
# 2017-04-09 18:27:26,146 : INFO : PROGRESS: at 16.65% examples, 169919 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:27:46,151 : INFO : PROGRESS: at 17.02% examples, 169781 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:27:49,214 : INFO : Loading new file for index: 220000
# 2017-04-09 18:28:06,157 : INFO : PROGRESS: at 17.40% examples, 169875 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 18:28:26,165 : INFO : PROGRESS: at 17.77% examples, 169804 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:28:30,850 : INFO : Loading new file for index: 230000
# 2017-04-09 18:28:46,180 : INFO : PROGRESS: at 18.15% examples, 169831 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 18:29:06,273 : INFO : PROGRESS: at 18.53% examples, 169855 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:29:10,403 : INFO : Loading new file for index: 240000
# 2017-04-09 18:29:26,341 : INFO : PROGRESS: at 18.91% examples, 169798 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 18:29:46,351 : INFO : PROGRESS: at 19.31% examples, 170042 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:29:51,149 : INFO : Loading new file for index: 250000
# 2017-04-09 18:30:06,370 : INFO : PROGRESS: at 19.71% examples, 170166 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:30:26,387 : INFO : PROGRESS: at 20.12% examples, 170513 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:30:29,343 : INFO : Loading new file for index: 260000
# 2017-04-09 18:30:46,419 : INFO : PROGRESS: at 20.54% examples, 170876 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:31:06,503 : INFO : PROGRESS: at 20.91% examples, 170877 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:31:08,705 : INFO : Loading new file for index: 270000
# 2017-04-09 18:31:26,557 : INFO : PROGRESS: at 21.30% examples, 170919 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 18:31:46,582 : INFO : PROGRESS: at 21.67% examples, 170801 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:31:50,350 : INFO : Loading new file for index: 280000
# 2017-04-09 18:32:06,583 : INFO : PROGRESS: at 22.03% examples, 170637 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:32:26,583 : INFO : PROGRESS: at 22.43% examples, 170725 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:32:30,556 : INFO : Loading new file for index: 290000
# 2017-04-09 18:32:46,609 : INFO : PROGRESS: at 22.81% examples, 170769 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:33:06,625 : INFO : PROGRESS: at 23.20% examples, 170763 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:33:11,426 : INFO : Loading new file for index: 300000
# 2017-04-09 18:33:26,652 : INFO : PROGRESS: at 23.59% examples, 170858 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:33:46,717 : INFO : PROGRESS: at 23.99% examples, 170985 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:33:51,162 : INFO : Loading new file for index: 310000
# 2017-04-09 18:34:06,722 : INFO : PROGRESS: at 24.37% examples, 170897 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 18:34:26,746 : INFO : PROGRESS: at 24.75% examples, 170982 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:34:31,568 : INFO : Loading new file for index: 320000
# 2017-04-09 18:34:46,780 : INFO : PROGRESS: at 25.17% examples, 171234 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:35:06,784 : INFO : PROGRESS: at 25.57% examples, 171332 words/s, in_qsize 0, out_qsize 1
# 2017-04-09 18:35:09,231 : INFO : Loading new file for index: 330000
# 2017-04-09 18:35:26,808 : INFO : PROGRESS: at 25.99% examples, 171591 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:35:46,772 : INFO : Loading new file for index: 340000
# 2017-04-09 18:35:46,839 : INFO : PROGRESS: at 26.40% examples, 171741 words/s, in_qsize 2, out_qsize 1
# 2017-04-09 18:36:06,862 : INFO : PROGRESS: at 26.82% examples, 171969 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:36:24,356 : INFO : Loading new file for index: 350000
# 2017-04-09 18:36:26,866 : INFO : PROGRESS: at 27.23% examples, 172132 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:36:46,927 : INFO : PROGRESS: at 27.63% examples, 172229 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:37:04,256 : INFO : Loading new file for index: 360000
# 2017-04-09 18:37:07,026 : INFO : PROGRESS: at 28.01% examples, 172206 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:37:27,038 : INFO : PROGRESS: at 28.41% examples, 172272 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 18:37:42,727 : INFO : Loading new file for index: 370000
# 2017-04-09 18:37:47,061 : INFO : PROGRESS: at 28.84% examples, 172543 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:38:07,069 : INFO : PROGRESS: at 29.23% examples, 172649 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:38:20,515 : INFO : Loading new file for index: 380000
# 2017-04-09 18:38:27,072 : INFO : PROGRESS: at 29.64% examples, 172856 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:38:47,111 : INFO : PROGRESS: at 30.04% examples, 172894 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:38:59,806 : INFO : Loading new file for index: 390000
# 2017-04-09 18:39:07,121 : INFO : PROGRESS: at 30.42% examples, 172854 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:39:27,138 : INFO : PROGRESS: at 30.80% examples, 172848 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 18:39:40,498 : INFO : Loading new file for index: 400000
# 2017-04-09 18:39:47,170 : INFO : PROGRESS: at 31.18% examples, 172870 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 18:40:07,186 : INFO : PROGRESS: at 31.55% examples, 172781 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:40:21,917 : INFO : Loading new file for index: 410000
# 2017-04-09 18:40:27,194 : INFO : PROGRESS: at 31.95% examples, 172897 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:40:47,252 : INFO : PROGRESS: at 32.32% examples, 172827 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:41:01,466 : INFO : Loading new file for index: 420000
# 2017-04-09 18:41:07,259 : INFO : PROGRESS: at 32.72% examples, 172864 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:41:27,278 : INFO : PROGRESS: at 33.07% examples, 172686 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 18:41:44,444 : INFO : Loading new file for index: 430000
# 2017-04-09 18:41:47,299 : INFO : PROGRESS: at 33.45% examples, 172634 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:42:07,331 : INFO : PROGRESS: at 33.82% examples, 172563 words/s, in_qsize 7, out_qsize 1
# 2017-04-09 18:42:24,657 : INFO : Loading new file for index: 440000
# 2017-04-09 18:42:27,358 : INFO : PROGRESS: at 34.23% examples, 172705 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:42:47,388 : INFO : PROGRESS: at 34.60% examples, 172596 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:43:05,910 : INFO : Loading new file for index: 450000
# 2017-04-09 18:43:07,514 : INFO : PROGRESS: at 34.98% examples, 172576 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:43:27,600 : INFO : PROGRESS: at 35.36% examples, 172536 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:43:46,138 : INFO : Loading new file for index: 460000
# 2017-04-09 18:43:47,604 : INFO : PROGRESS: at 35.76% examples, 172601 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 18:44:07,722 : INFO : PROGRESS: at 36.16% examples, 172706 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 18:44:25,340 : INFO : Loading new file for index: 470000
# 2017-04-09 18:44:27,740 : INFO : PROGRESS: at 36.56% examples, 172802 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:44:47,760 : INFO : PROGRESS: at 36.93% examples, 172717 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:45:06,779 : INFO : Loading new file for index: 480000
# 2017-04-09 18:45:07,784 : INFO : PROGRESS: at 37.31% examples, 172724 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:45:27,800 : INFO : PROGRESS: at 37.71% examples, 172786 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:45:44,439 : INFO : Loading new file for index: 490000
# 2017-04-09 18:45:47,817 : INFO : PROGRESS: at 38.13% examples, 172929 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 18:46:07,864 : INFO : PROGRESS: at 38.55% examples, 173069 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:46:22,990 : INFO : Loading new file for index: 500000
# 2017-04-09 18:46:27,895 : INFO : PROGRESS: at 38.93% examples, 173071 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:46:47,929 : INFO : PROGRESS: at 39.33% examples, 173116 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:47:02,991 : INFO : Loading new file for index: 510000
# 2017-04-09 18:47:07,945 : INFO : PROGRESS: at 39.70% examples, 173064 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:47:27,962 : INFO : PROGRESS: at 40.08% examples, 173009 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:47:44,658 : INFO : Loading new file for index: 520000
# 2017-04-09 18:47:47,965 : INFO : PROGRESS: at 40.46% examples, 172985 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:48:07,997 : INFO : PROGRESS: at 40.85% examples, 172981 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:48:24,560 : INFO : Loading new file for index: 530000
# 2017-04-09 18:48:28,059 : INFO : PROGRESS: at 41.23% examples, 172926 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:48:48,113 : INFO : PROGRESS: at 41.58% examples, 172802 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 18:49:07,351 : INFO : Loading new file for index: 540000
# 2017-04-09 18:49:08,129 : INFO : PROGRESS: at 41.97% examples, 172823 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:49:28,146 : INFO : PROGRESS: at 42.34% examples, 172807 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:49:47,879 : INFO : Loading new file for index: 550000
# 2017-04-09 18:49:48,252 : INFO : PROGRESS: at 42.73% examples, 172838 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:50:08,253 : INFO : PROGRESS: at 43.11% examples, 172806 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:50:26,786 : INFO : Loading new file for index: 560000
# 2017-04-09 18:50:28,288 : INFO : PROGRESS: at 43.52% examples, 172947 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:50:48,313 : INFO : PROGRESS: at 43.91% examples, 172955 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:51:08,029 : INFO : Loading new file for index: 570000
# 2017-04-09 18:51:08,331 : INFO : PROGRESS: at 44.28% examples, 172898 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:51:28,349 : INFO : PROGRESS: at 44.68% examples, 172969 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:51:47,934 : INFO : Loading new file for index: 580000
# 2017-04-09 18:51:48,357 : INFO : PROGRESS: at 45.06% examples, 172951 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 18:52:08,365 : INFO : PROGRESS: at 45.45% examples, 172971 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:52:27,918 : INFO : Loading new file for index: 590000
# 2017-04-09 18:52:28,377 : INFO : PROGRESS: at 45.84% examples, 172991 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 18:52:48,396 : INFO : PROGRESS: at 46.22% examples, 172974 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 18:53:08,457 : INFO : PROGRESS: at 46.61% examples, 173017 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:53:08,845 : INFO : Loading new file for index: 600000
# 2017-04-09 18:53:28,481 : INFO : PROGRESS: at 47.03% examples, 173151 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 18:53:47,535 : INFO : Loading new file for index: 610000
# 2017-04-09 18:53:48,483 : INFO : PROGRESS: at 47.41% examples, 173141 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:54:08,522 : INFO : PROGRESS: at 47.80% examples, 173171 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 18:54:26,865 : INFO : Loading new file for index: 620000
# 2017-04-09 18:54:28,522 : INFO : PROGRESS: at 48.21% examples, 173243 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:54:48,636 : INFO : PROGRESS: at 48.61% examples, 173317 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:55:05,474 : INFO : Loading new file for index: 630000
# 2017-04-09 18:55:08,745 : INFO : PROGRESS: at 49.00% examples, 173311 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:55:28,835 : INFO : PROGRESS: at 49.40% examples, 173337 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:55:45,184 : INFO : Loading new file for index: 640000
# 2017-04-09 18:55:48,848 : INFO : PROGRESS: at 49.79% examples, 173386 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 18:56:08,853 : INFO : PROGRESS: at 50.17% examples, 173389 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:56:27,367 : INFO : Loading new file for index: 650000
# 2017-04-09 18:56:28,866 : INFO : PROGRESS: at 50.53% examples, 173313 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:56:48,914 : INFO : PROGRESS: at 50.92% examples, 173287 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:57:07,489 : INFO : Loading new file for index: 660000
# 2017-04-09 18:57:09,033 : INFO : PROGRESS: at 51.30% examples, 173287 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 18:57:29,048 : INFO : PROGRESS: at 51.67% examples, 173248 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 18:57:49,069 : INFO : PROGRESS: at 52.04% examples, 173203 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 18:57:49,417 : INFO : Loading new file for index: 670000
# 2017-04-09 18:58:09,084 : INFO : PROGRESS: at 52.41% examples, 173179 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 18:58:29,136 : INFO : PROGRESS: at 52.80% examples, 173194 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 18:58:30,100 : INFO : Loading new file for index: 680000
# 2017-04-09 18:58:49,212 : INFO : PROGRESS: at 53.20% examples, 173277 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 18:59:09,261 : INFO : PROGRESS: at 53.56% examples, 173154 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 18:59:11,800 : INFO : Loading new file for index: 690000
# 2017-04-09 18:59:29,305 : INFO : PROGRESS: at 53.93% examples, 173084 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 18:59:49,341 : INFO : PROGRESS: at 54.31% examples, 173075 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 18:59:52,677 : INFO : Loading new file for index: 700000
# 2017-04-09 19:00:09,346 : INFO : PROGRESS: at 54.71% examples, 173119 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:00:29,434 : INFO : PROGRESS: at 55.12% examples, 173157 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:00:32,296 : INFO : Loading new file for index: 710000
# 2017-04-09 19:00:49,451 : INFO : PROGRESS: at 55.47% examples, 173063 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:01:09,532 : INFO : PROGRESS: at 55.85% examples, 173034 words/s, in_qsize 0, out_qsize 1
# 2017-04-09 19:01:13,932 : INFO : Loading new file for index: 720000
# 2017-04-09 19:01:29,553 : INFO : PROGRESS: at 56.23% examples, 173006 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:01:49,628 : INFO : PROGRESS: at 56.62% examples, 173019 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 19:01:54,342 : INFO : Loading new file for index: 730000
# 2017-04-09 19:02:09,641 : INFO : PROGRESS: at 57.02% examples, 173028 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:02:29,672 : INFO : PROGRESS: at 57.38% examples, 172967 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:02:35,648 : INFO : Loading new file for index: 740000
# 2017-04-09 19:02:49,696 : INFO : PROGRESS: at 57.75% examples, 172925 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:03:09,700 : INFO : PROGRESS: at 58.12% examples, 172853 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:03:17,922 : INFO : Loading new file for index: 750000
# 2017-04-09 19:03:29,707 : INFO : PROGRESS: at 58.52% examples, 172908 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:03:49,747 : INFO : PROGRESS: at 58.92% examples, 172940 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:03:56,466 : INFO : Loading new file for index: 760000
# 2017-04-09 19:04:09,757 : INFO : PROGRESS: at 59.31% examples, 172998 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:04:29,773 : INFO : PROGRESS: at 59.74% examples, 173106 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:04:34,913 : INFO : Loading new file for index: 770000
# 2017-04-09 19:04:49,773 : INFO : PROGRESS: at 60.14% examples, 173161 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:05:09,839 : INFO : PROGRESS: at 60.53% examples, 173180 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:05:13,234 : INFO : Loading new file for index: 780000
# 2017-04-09 19:05:29,870 : INFO : PROGRESS: at 60.92% examples, 173185 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:05:49,875 : INFO : PROGRESS: at 61.31% examples, 173212 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:05:53,521 : INFO : Loading new file for index: 790000
# 2017-04-09 19:06:09,889 : INFO : PROGRESS: at 61.70% examples, 173232 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:06:29,895 : INFO : PROGRESS: at 62.13% examples, 173342 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:06:31,562 : INFO : Loading new file for index: 800000
# 2017-04-09 19:06:50,008 : INFO : PROGRESS: at 62.52% examples, 173347 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:07:10,046 : INFO : PROGRESS: at 62.88% examples, 173258 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:07:13,146 : INFO : Loading new file for index: 810000
# 2017-04-09 19:07:30,084 : INFO : PROGRESS: at 63.25% examples, 173226 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:07:50,157 : INFO : PROGRESS: at 63.68% examples, 173337 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:07:52,259 : INFO : Loading new file for index: 820000
# 2017-04-09 19:08:10,169 : INFO : PROGRESS: at 64.07% examples, 173362 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:08:30,208 : INFO : PROGRESS: at 64.50% examples, 173460 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:08:30,271 : INFO : Loading new file for index: 830000
# 2017-04-09 19:08:50,233 : INFO : PROGRESS: at 64.90% examples, 173493 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:09:08,397 : INFO : Loading new file for index: 840000
# 2017-04-09 19:09:10,263 : INFO : PROGRESS: at 65.31% examples, 173557 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:09:30,269 : INFO : PROGRESS: at 65.72% examples, 173619 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:09:46,331 : INFO : Loading new file for index: 850000
# 2017-04-09 19:09:50,277 : INFO : PROGRESS: at 66.14% examples, 173675 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:10:10,330 : INFO : PROGRESS: at 66.55% examples, 173735 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:10:23,691 : INFO : Loading new file for index: 860000
# 2017-04-09 19:10:30,390 : INFO : PROGRESS: at 66.97% examples, 173815 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:10:50,454 : INFO : PROGRESS: at 67.35% examples, 173796 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:11:03,779 : INFO : Loading new file for index: 870000
# 2017-04-09 19:11:10,472 : INFO : PROGRESS: at 67.74% examples, 173801 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:11:30,477 : INFO : PROGRESS: at 68.14% examples, 173825 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:11:42,820 : INFO : Loading new file for index: 880000
# 2017-04-09 19:11:50,483 : INFO : PROGRESS: at 68.54% examples, 173889 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:12:10,506 : INFO : PROGRESS: at 68.95% examples, 173955 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:12:20,318 : INFO : Loading new file for index: 890000
# 2017-04-09 19:12:30,547 : INFO : PROGRESS: at 69.34% examples, 173948 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:12:50,608 : INFO : PROGRESS: at 69.74% examples, 173956 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:13:01,608 : INFO : Loading new file for index: 900000
# 2017-04-09 19:13:10,642 : INFO : PROGRESS: at 70.13% examples, 173959 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:13:30,717 : INFO : PROGRESS: at 70.50% examples, 173936 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:13:41,733 : INFO : Loading new file for index: 910000
# 2017-04-09 19:13:50,797 : INFO : PROGRESS: at 70.90% examples, 173939 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:14:10,805 : INFO : PROGRESS: at 71.28% examples, 173944 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:14:20,623 : INFO : Loading new file for index: 920000
# 2017-04-09 19:14:30,905 : INFO : PROGRESS: at 71.69% examples, 173969 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:14:50,933 : INFO : PROGRESS: at 72.10% examples, 174006 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:14:59,557 : INFO : Loading new file for index: 930000
# 2017-04-09 19:15:10,990 : INFO : PROGRESS: at 72.50% examples, 174051 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:15:31,007 : INFO : PROGRESS: at 72.92% examples, 174111 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:15:36,598 : INFO : Loading new file for index: 940000
# 2017-04-09 19:15:51,015 : INFO : PROGRESS: at 73.33% examples, 174163 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:16:11,040 : INFO : PROGRESS: at 73.71% examples, 174155 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:16:16,057 : INFO : Loading new file for index: 950000
# 2017-04-09 19:16:31,087 : INFO : PROGRESS: at 74.13% examples, 174238 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:16:51,128 : INFO : PROGRESS: at 74.51% examples, 174244 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:16:54,952 : INFO : Loading new file for index: 960000
# 2017-04-09 19:17:11,160 : INFO : PROGRESS: at 74.90% examples, 174230 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:17:31,171 : INFO : PROGRESS: at 75.31% examples, 174275 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:17:34,854 : INFO : Loading new file for index: 970000
# 2017-04-09 19:17:51,183 : INFO : PROGRESS: at 75.71% examples, 174321 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:18:11,212 : INFO : PROGRESS: at 76.10% examples, 174326 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:18:13,544 : INFO : Loading new file for index: 980000
# 2017-04-09 19:18:31,268 : INFO : PROGRESS: at 76.50% examples, 174324 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:18:51,338 : INFO : PROGRESS: at 76.90% examples, 174382 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:18:52,855 : INFO : Loading new file for index: 990000
# 2017-04-09 19:19:11,352 : INFO : PROGRESS: at 77.29% examples, 174387 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:19:31,412 : INFO : PROGRESS: at 77.64% examples, 174297 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:19:34,931 : INFO : Loading new file for index: 1000000
# 2017-04-09 19:19:51,429 : INFO : PROGRESS: at 78.02% examples, 174247 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:20:11,445 : INFO : PROGRESS: at 78.40% examples, 174221 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:20:16,160 : INFO : Loading new file for index: 1010000
# 2017-04-09 19:20:31,495 : INFO : PROGRESS: at 78.76% examples, 174178 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:20:51,533 : INFO : PROGRESS: at 79.15% examples, 174205 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:20:56,413 : INFO : Loading new file for index: 1020000
# 2017-04-09 19:21:11,564 : INFO : PROGRESS: at 79.57% examples, 174272 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 19:21:31,609 : INFO : PROGRESS: at 79.96% examples, 174301 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:21:35,684 : INFO : Loading new file for index: 1030000
# 2017-04-09 19:21:51,705 : INFO : PROGRESS: at 80.35% examples, 174309 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:22:11,784 : INFO : PROGRESS: at 80.75% examples, 174329 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:22:14,946 : INFO : Loading new file for index: 1040000
# 2017-04-09 19:22:31,926 : INFO : PROGRESS: at 81.17% examples, 174365 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:22:51,945 : INFO : PROGRESS: at 81.50% examples, 174247 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:22:56,457 : INFO : Loading new file for index: 1050000
# 2017-04-09 19:23:11,947 : INFO : PROGRESS: at 81.90% examples, 174250 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:23:32,027 : INFO : PROGRESS: at 82.27% examples, 174216 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:23:36,599 : INFO : Loading new file for index: 1060000
# 2017-04-09 19:23:52,057 : INFO : PROGRESS: at 82.68% examples, 174245 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:24:12,103 : INFO : PROGRESS: at 83.09% examples, 174289 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:24:15,294 : INFO : Loading new file for index: 1070000
# 2017-04-09 19:24:32,161 : INFO : PROGRESS: at 83.48% examples, 174300 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:24:52,186 : INFO : PROGRESS: at 83.88% examples, 174295 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:24:54,972 : INFO : Loading new file for index: 1080000
# 2017-04-09 19:25:12,210 : INFO : PROGRESS: at 84.27% examples, 174326 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:25:32,224 : INFO : PROGRESS: at 84.65% examples, 174299 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:25:34,783 : INFO : Loading new file for index: 1090000
# 2017-04-09 19:25:52,226 : INFO : PROGRESS: at 85.04% examples, 174297 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:26:12,235 : INFO : PROGRESS: at 85.44% examples, 174319 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:26:14,375 : INFO : Loading new file for index: 1100000
# 2017-04-09 19:26:32,287 : INFO : PROGRESS: at 85.84% examples, 174324 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:26:52,299 : INFO : PROGRESS: at 86.21% examples, 174292 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:26:54,967 : INFO : Loading new file for index: 1110000
# 2017-04-09 19:27:12,302 : INFO : PROGRESS: at 86.61% examples, 174304 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:27:32,314 : INFO : PROGRESS: at 86.97% examples, 174261 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 19:27:35,400 : INFO : Loading new file for index: 1120000
# 2017-04-09 19:27:52,324 : INFO : PROGRESS: at 87.36% examples, 174245 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 19:28:12,394 : INFO : PROGRESS: at 87.73% examples, 174204 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:28:16,544 : INFO : Loading new file for index: 1130000
# 2017-04-09 19:28:32,405 : INFO : PROGRESS: at 88.10% examples, 174152 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:28:52,407 : INFO : PROGRESS: at 88.51% examples, 174190 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:28:56,154 : INFO : Loading new file for index: 1140000
# 2017-04-09 19:29:12,450 : INFO : PROGRESS: at 88.87% examples, 174154 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:29:32,457 : INFO : PROGRESS: at 89.26% examples, 174148 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:29:37,872 : INFO : Loading new file for index: 1150000
# 2017-04-09 19:29:52,509 : INFO : PROGRESS: at 89.64% examples, 174148 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:30:12,528 : INFO : PROGRESS: at 90.06% examples, 174204 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:30:16,857 : INFO : Loading new file for index: 1160000
# 2017-04-09 19:30:32,556 : INFO : PROGRESS: at 90.47% examples, 174246 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:30:52,572 : INFO : PROGRESS: at 90.83% examples, 174215 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:30:57,487 : INFO : Loading new file for index: 1170000
# 2017-04-09 19:31:12,585 : INFO : PROGRESS: at 91.25% examples, 174255 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:31:32,605 : INFO : PROGRESS: at 91.64% examples, 174241 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:31:36,149 : INFO : Loading new file for index: 1180000
# 2017-04-09 19:31:52,671 : INFO : PROGRESS: at 92.02% examples, 174246 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:32:12,693 : INFO : PROGRESS: at 92.41% examples, 174243 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:32:16,210 : INFO : Loading new file for index: 1190000
# 2017-04-09 19:32:32,707 : INFO : PROGRESS: at 92.77% examples, 174197 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:32:52,732 : INFO : PROGRESS: at 93.13% examples, 174137 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:32:58,741 : INFO : Loading new file for index: 1200000
# 2017-04-09 19:33:12,742 : INFO : PROGRESS: at 93.51% examples, 174133 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:33:32,776 : INFO : PROGRESS: at 93.88% examples, 174083 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:33:40,975 : INFO : Loading new file for index: 1210000
# 2017-04-09 19:33:52,969 : INFO : PROGRESS: at 94.26% examples, 174069 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:34:13,069 : INFO : PROGRESS: at 94.65% examples, 174062 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:34:21,864 : INFO : Loading new file for index: 1220000
# 2017-04-09 19:34:33,114 : INFO : PROGRESS: at 95.01% examples, 174028 words/s, in_qsize 0, out_qsize 1
# 2017-04-09 19:34:53,321 : INFO : PROGRESS: at 95.37% examples, 173978 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:35:04,206 : INFO : Loading new file for index: 1230000
# 2017-04-09 19:35:13,359 : INFO : PROGRESS: at 95.77% examples, 174000 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:35:33,362 : INFO : PROGRESS: at 96.14% examples, 173989 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:35:44,655 : INFO : Loading new file for index: 1240000
# 2017-04-09 19:35:53,409 : INFO : PROGRESS: at 96.54% examples, 174011 words/s, in_qsize 10, out_qsize 1
# 2017-04-09 19:36:13,411 : INFO : PROGRESS: at 96.92% examples, 173993 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:36:24,807 : INFO : Loading new file for index: 1250000
# 2017-04-09 19:36:33,442 : INFO : PROGRESS: at 97.33% examples, 174038 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:36:53,467 : INFO : PROGRESS: at 97.72% examples, 174019 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:37:03,970 : INFO : Loading new file for index: 1260000
# 2017-04-09 19:37:13,479 : INFO : PROGRESS: at 98.09% examples, 174013 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:37:33,503 : INFO : PROGRESS: at 98.53% examples, 174092 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:37:42,781 : INFO : Loading new file for index: 1270000
# 2017-04-09 19:37:53,550 : INFO : PROGRESS: at 98.92% examples, 174092 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 19:38:13,551 : INFO : PROGRESS: at 99.29% examples, 174067 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:38:23,166 : INFO : Loading new file for index: 1280000
# 2017-04-09 19:38:33,561 : INFO : PROGRESS: at 99.67% examples, 174053 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:38:49,874 : INFO : Loading new file for index: 1290000
# 2017-04-09 19:38:49,886 : INFO : All files are loaded - last file: 1290000
# 2017-04-09 19:38:51,007 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2017-04-09 19:38:51,015 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-04-09 19:38:51,021 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-04-09 19:38:51,031 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-04-09 19:38:51,034 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-04-09 19:38:51,037 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-04-09 19:38:51,049 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-04-09 19:38:51,052 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-04-09 19:38:51,054 : INFO : training on 1393295375 raw words (899492205 effective words) took 5167.7s, 174062 effective words/s
# 2017-04-09 19:38:51,091 : INFO : saving Doc2Vec object under /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1/model, separately None
# 2017-04-09 19:38:51,092 : INFO : storing np array 'doctag_syn0' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1/model.docvecs.doctag_syn0.npy
# CPU times: user 2h 40min 26s, sys: 16min 2s, total: 2h 56min 29s
# Wall time: 1h 26min 7s
# 2017-04-09 19:38:54,994 : INFO : not storing attribute syn0norm
# 2017-04-09 19:38:54,995 : INFO : storing np array 'syn0' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1/model.wv.syn0.npy
# 2017-04-09 19:38:55,028 : INFO : storing np array 'syn1neg' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1/model.syn1neg.npy
# 2017-04-09 19:38:55,059 : INFO : not storing attribute cum_table
# 2017-04-09 19:39:37,369 : INFO : saved /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_1/model
# 2017-04-09 19:39:37,372 : INFO : ****************** Epoch 2 --- Working on doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_2 *******************
# 2017-04-09 19:39:37,590 : INFO : Loading new file for index: 0
# 2017-04-09 19:39:37,632 : INFO : training model with 8 workers on 67011 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=10 window=2
# 2017-04-09 19:39:37,634 : INFO : expecting 5145291 sentences, matching count from corpus used for vocabulary survey
# 2017-04-09 19:39:38,664 : INFO : PROGRESS: at 0.01% examples, 93338 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:39:58,687 : INFO : PROGRESS: at 0.38% examples, 163763 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:40:18,315 : INFO : Loading new file for index: 10000
# 2017-04-09 19:40:18,706 : INFO : PROGRESS: at 0.76% examples, 166264 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:40:38,724 : INFO : PROGRESS: at 1.19% examples, 174548 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:40:55,573 : INFO : Loading new file for index: 20000
# 2017-04-09 19:40:58,735 : INFO : PROGRESS: at 1.58% examples, 174449 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:41:18,804 : INFO : PROGRESS: at 1.95% examples, 172127 words/s, in_qsize 15, out_qsize 1
# 2017-04-09 19:41:37,358 : INFO : Loading new file for index: 30000
# 2017-04-09 19:41:38,919 : INFO : PROGRESS: at 2.32% examples, 171372 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:41:59,044 : INFO : PROGRESS: at 2.69% examples, 170489 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:42:19,063 : INFO : Loading new file for index: 40000
# 2017-04-09 19:42:19,071 : INFO : PROGRESS: at 3.07% examples, 170425 words/s, in_qsize 14, out_qsize 0
# 2017-04-09 19:42:39,093 : INFO : PROGRESS: at 3.46% examples, 170695 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:42:59,105 : INFO : PROGRESS: at 3.81% examples, 169037 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:43:01,224 : INFO : Loading new file for index: 50000
# 2017-04-09 19:43:19,138 : INFO : PROGRESS: at 4.17% examples, 169154 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:43:39,159 : INFO : PROGRESS: at 4.55% examples, 169461 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:43:43,072 : INFO : Loading new file for index: 60000
# 2017-04-09 19:43:59,181 : INFO : PROGRESS: at 4.95% examples, 170118 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:44:19,199 : INFO : PROGRESS: at 5.33% examples, 170208 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:44:22,877 : INFO : Loading new file for index: 70000
# 2017-04-09 19:44:39,224 : INFO : PROGRESS: at 5.70% examples, 170054 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:44:59,236 : INFO : PROGRESS: at 6.07% examples, 169735 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:45:05,211 : INFO : Loading new file for index: 80000
# 2017-04-09 19:45:19,358 : INFO : PROGRESS: at 6.45% examples, 169708 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 19:45:39,384 : INFO : PROGRESS: at 6.84% examples, 170321 words/s, in_qsize 1, out_qsize 0
# 2017-04-09 19:45:45,774 : INFO : Loading new file for index: 90000
# 2017-04-09 19:45:59,450 : INFO : PROGRESS: at 7.24% examples, 170754 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:46:19,485 : INFO : PROGRESS: at 7.61% examples, 170556 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:46:26,689 : INFO : Loading new file for index: 100000
# 2017-04-09 19:46:39,511 : INFO : PROGRESS: at 7.99% examples, 170588 words/s, in_qsize 11, out_qsize 1
# 2017-04-09 19:46:59,521 : INFO : PROGRESS: at 8.34% examples, 170050 words/s, in_qsize 9, out_qsize 1
# 2017-04-09 19:47:09,124 : INFO : Loading new file for index: 110000
# 2017-04-09 19:47:19,583 : INFO : PROGRESS: at 8.70% examples, 169661 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:47:39,593 : INFO : PROGRESS: at 9.05% examples, 169210 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:47:53,473 : INFO : Loading new file for index: 120000
# 2017-04-09 19:47:59,619 : INFO : PROGRESS: at 9.41% examples, 168875 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:48:19,622 : INFO : PROGRESS: at 9.79% examples, 168979 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:48:35,023 : INFO : Loading new file for index: 130000
# 2017-04-09 19:48:39,640 : INFO : PROGRESS: at 10.17% examples, 168951 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:48:59,674 : INFO : PROGRESS: at 10.57% examples, 169388 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:49:14,271 : INFO : Loading new file for index: 140000
# 2017-04-09 19:49:19,689 : INFO : PROGRESS: at 10.96% examples, 169474 words/s, in_qsize 8, out_qsize 0
# 2017-04-09 19:49:39,696 : INFO : PROGRESS: at 11.36% examples, 169719 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:49:53,460 : INFO : Loading new file for index: 150000
# 2017-04-09 19:49:59,807 : INFO : PROGRESS: at 11.76% examples, 170000 words/s, in_qsize 4, out_qsize 0
# 2017-04-09 19:50:19,810 : INFO : PROGRESS: at 12.15% examples, 170318 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:50:33,212 : INFO : Loading new file for index: 160000
# 2017-04-09 19:50:39,841 : INFO : PROGRESS: at 12.54% examples, 170321 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:50:59,894 : INFO : PROGRESS: at 12.92% examples, 170450 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:51:13,828 : INFO : Loading new file for index: 170000
# 2017-04-09 19:51:20,077 : INFO : PROGRESS: at 13.29% examples, 170332 words/s, in_qsize 2, out_qsize 0
# 2017-04-09 19:51:40,131 : INFO : PROGRESS: at 13.67% examples, 170286 words/s, in_qsize 1, out_qsize 1
# 2017-04-09 19:51:55,715 : INFO : Loading new file for index: 180000
# 2017-04-09 19:52:00,208 : INFO : PROGRESS: at 14.06% examples, 170458 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:52:20,224 : INFO : PROGRESS: at 14.44% examples, 170529 words/s, in_qsize 10, out_qsize 0
# 2017-04-09 19:52:36,008 : INFO : Loading new file for index: 190000
# 2017-04-09 19:52:40,271 : INFO : PROGRESS: at 14.81% examples, 170450 words/s, in_qsize 7, out_qsize 0
# 2017-04-09 19:53:00,355 : INFO : PROGRESS: at 15.24% examples, 170912 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:53:14,648 : INFO : Loading new file for index: 200000
# 2017-04-09 19:53:20,394 : INFO : PROGRESS: at 15.63% examples, 170991 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:53:40,410 : INFO : PROGRESS: at 16.01% examples, 171003 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:53:54,015 : INFO : Loading new file for index: 210000
# 2017-04-09 19:54:00,456 : INFO : PROGRESS: at 16.40% examples, 171159 words/s, in_qsize 5, out_qsize 0
# 2017-04-09 19:54:20,499 : INFO : PROGRESS: at 16.78% examples, 171243 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:54:35,240 : INFO : Loading new file for index: 220000
# 2017-04-09 19:54:40,498 : INFO : PROGRESS: at 17.16% examples, 171272 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:55:00,503 : INFO : PROGRESS: at 17.54% examples, 171199 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:55:16,186 : INFO : Loading new file for index: 230000
# 2017-04-09 19:55:20,563 : INFO : PROGRESS: at 17.92% examples, 171187 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 19:55:40,576 : INFO : PROGRESS: at 18.27% examples, 170939 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 19:55:59,230 : INFO : Loading new file for index: 240000
# 2017-04-09 19:56:00,583 : INFO : PROGRESS: at 18.65% examples, 170920 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:56:20,622 : INFO : PROGRESS: at 19.02% examples, 170794 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:56:39,998 : INFO : Loading new file for index: 250000
# 2017-04-09 19:56:40,641 : INFO : PROGRESS: at 19.42% examples, 171038 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:57:00,679 : INFO : PROGRESS: at 19.79% examples, 170907 words/s, in_qsize 8, out_qsize 1
# 2017-04-09 19:57:20,078 : INFO : Loading new file for index: 260000
# 2017-04-09 19:57:20,692 : INFO : PROGRESS: at 20.19% examples, 171065 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 19:57:40,778 : INFO : PROGRESS: at 20.57% examples, 171123 words/s, in_qsize 16, out_qsize 0
# 2017-04-09 19:58:00,311 : INFO : Loading new file for index: 270000
# 2017-04-09 19:58:00,790 : INFO : PROGRESS: at 20.97% examples, 171285 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:58:20,880 : INFO : PROGRESS: at 21.36% examples, 171466 words/s, in_qsize 0, out_qsize 0
# 2017-04-09 19:58:40,918 : INFO : PROGRESS: at 21.74% examples, 171312 words/s, in_qsize 3, out_qsize 0
# 2017-04-09 19:58:41,080 : INFO : Loading new file for index: 280000
# 2017-04-09 19:59:00,935 : INFO : PROGRESS: at 22.11% examples, 171269 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 19:59:20,352 : INFO : Loading new file for index: 290000
# 2017-04-09 19:59:20,951 : INFO : PROGRESS: at 22.52% examples, 171447 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:59:41,022 : INFO : PROGRESS: at 22.91% examples, 171475 words/s, in_qsize 6, out_qsize 0
# 2017-04-09 19:59:59,483 : INFO : Loading new file for index: 300000
# 2017-04-09 20:00:01,049 : INFO : PROGRESS: at 23.32% examples, 171646 words/s, in_qsize 12, out_qsize 0
# 2017-04-09 20:00:21,065 : INFO : PROGRESS: at 23.70% examples, 171660 words/s, in_qsize 15, out_qsize 0
# 2017-04-09 20:00:39,889 : INFO : Loading new file for index: 310000
# 2017-04-09 20:00:41,123 : INFO : PROGRESS: at 24.08% examples, 171588 words/s, in_qsize 11, out_qsize 0
# 2017-04-09 20:01:01,135 : INFO : PROGRESS: at 24.46% examples, 171535 words/s, in_qsize 9, out_qsize 0
# 2017-04-09 20:01:20,489 : INFO : Loading new file for index: 320000
# 2017-04-09 20:01:21,149 : INFO : PROGRESS: at 24.85% examples, 171657 words/s, in_qsize 13, out_qsize 0
# 2017-04-09 20:01:41,230 : INFO : PROGRESS: at 25.24% examples, 171675 words/s, in_qsize 5, out_qsize 0
# ...
# 2017-04-10 06:21:32,581 : INFO : PROGRESS: at 83.69% examples, 110491 words/s, in_qsize 14, out_qsize 0
# 2017-04-10 06:21:46,411 : INFO : Loading new file for index: 1080000
# 2017-04-10 06:21:52,658 : INFO : PROGRESS: at 84.01% examples, 110581 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:22:12,800 : INFO : PROGRESS: at 84.32% examples, 110677 words/s, in_qsize 11, out_qsize 0
# 2017-04-10 06:22:32,946 : INFO : PROGRESS: at 84.62% examples, 110734 words/s, in_qsize 16, out_qsize 0
# 2017-04-10 06:22:38,619 : INFO : Loading new file for index: 1090000
# 2017-04-10 06:22:52,966 : INFO : PROGRESS: at 84.89% examples, 110769 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:23:12,982 : INFO : PROGRESS: at 85.13% examples, 110751 words/s, in_qsize 12, out_qsize 0
# 2017-04-10 06:23:33,009 : INFO : PROGRESS: at 85.43% examples, 110824 words/s, in_qsize 10, out_qsize 1
# 2017-04-10 06:23:35,669 : INFO : Loading new file for index: 1100000
# 2017-04-10 06:23:53,136 : INFO : PROGRESS: at 85.65% examples, 110769 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:24:13,221 : INFO : PROGRESS: at 85.90% examples, 110783 words/s, in_qsize 12, out_qsize 1
# 2017-04-10 06:24:33,351 : INFO : PROGRESS: at 86.17% examples, 110806 words/s, in_qsize 11, out_qsize 0
# 2017-04-10 06:24:40,142 : INFO : Loading new file for index: 1110000
# 2017-04-10 06:24:53,429 : INFO : PROGRESS: at 86.43% examples, 110824 words/s, in_qsize 14, out_qsize 0
# 2017-04-10 06:25:14,206 : INFO : PROGRESS: at 86.48% examples, 110554 words/s, in_qsize 14, out_qsize 0
# 2017-04-10 06:25:34,399 : INFO : PROGRESS: at 86.49% examples, 110255 words/s, in_qsize 12, out_qsize 0
# 2017-04-10 06:25:54,432 : INFO : PROGRESS: at 86.50% examples, 109959 words/s, in_qsize 7, out_qsize 0
# 2017-04-10 06:26:26,353 : INFO : PROGRESS: at 86.51% examples, 109478 words/s, in_qsize 6, out_qsize 0
# 2017-04-10 06:26:47,103 : INFO : PROGRESS: at 86.52% examples, 109172 words/s, in_qsize 1, out_qsize 0
# 2017-04-10 06:27:08,640 : INFO : PROGRESS: at 86.53% examples, 108853 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:27:31,149 : INFO : PROGRESS: at 86.54% examples, 108522 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:27:55,704 : INFO : PROGRESS: at 86.54% examples, 108158 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:28:17,297 : INFO : PROGRESS: at 86.55% examples, 107846 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:28:39,974 : INFO : PROGRESS: at 86.56% examples, 107514 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:29:00,331 : INFO : PROGRESS: at 86.56% examples, 107219 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:29:22,822 : INFO : PROGRESS: at 86.57% examples, 106898 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:29:42,841 : INFO : PROGRESS: at 86.64% examples, 106691 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:30:02,866 : INFO : PROGRESS: at 86.72% examples, 106498 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:30:22,942 : INFO : PROGRESS: at 86.78% examples, 106278 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:30:43,041 : INFO : PROGRESS: at 86.86% examples, 106083 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:31:03,068 : INFO : PROGRESS: at 86.94% examples, 105894 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:31:23,079 : INFO : PROGRESS: at 87.02% examples, 105705 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:31:28,996 : INFO : Loading new file for index: 1120000
# 2017-04-10 06:31:43,274 : INFO : PROGRESS: at 87.11% examples, 105524 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:32:03,314 : INFO : PROGRESS: at 87.19% examples, 105343 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:32:23,388 : INFO : PROGRESS: at 87.29% examples, 105177 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:32:43,416 : INFO : PROGRESS: at 87.40% examples, 105017 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:33:03,432 : INFO : PROGRESS: at 87.51% examples, 104872 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:33:23,454 : INFO : PROGRESS: at 87.64% examples, 104740 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:33:44,677 : INFO : PROGRESS: at 87.76% examples, 104585 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:33:54,916 : INFO : Loading new file for index: 1130000
# 2017-04-10 06:34:04,750 : INFO : PROGRESS: at 87.89% examples, 104462 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:34:25,018 : INFO : PROGRESS: at 88.02% examples, 104331 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:34:45,086 : INFO : PROGRESS: at 88.15% examples, 104216 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:35:05,094 : INFO : PROGRESS: at 88.31% examples, 104114 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:35:25,142 : INFO : PROGRESS: at 88.47% examples, 104029 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:35:40,844 : INFO : Loading new file for index: 1140000
# 2017-04-10 06:35:45,352 : INFO : PROGRESS: at 88.64% examples, 103963 words/s, in_qsize 0, out_qsize 1
# 2017-04-10 06:36:05,378 : INFO : PROGRESS: at 88.82% examples, 103915 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:36:25,400 : INFO : PROGRESS: at 89.00% examples, 103858 words/s, in_qsize 14, out_qsize 0
# 2017-04-10 06:36:45,442 : INFO : PROGRESS: at 89.19% examples, 103803 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:37:02,867 : INFO : Loading new file for index: 1150000
# 2017-04-10 06:37:05,492 : INFO : PROGRESS: at 89.41% examples, 103785 words/s, in_qsize 0, out_qsize 1
# 2017-04-10 06:37:25,520 : INFO : PROGRESS: at 89.63% examples, 103779 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:37:45,533 : INFO : PROGRESS: at 89.86% examples, 103785 words/s, in_qsize 3, out_qsize 0
# 2017-04-10 06:38:05,615 : INFO : PROGRESS: at 90.09% examples, 103780 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:38:10,945 : INFO : Loading new file for index: 1160000
# 2017-04-10 06:38:25,618 : INFO : PROGRESS: at 90.33% examples, 103783 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:38:45,725 : INFO : PROGRESS: at 90.60% examples, 103834 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:39:05,808 : INFO : PROGRESS: at 90.87% examples, 103880 words/s, in_qsize 10, out_qsize 0
# 2017-04-10 06:39:09,997 : INFO : Loading new file for index: 1170000
# 2017-04-10 06:39:25,858 : INFO : PROGRESS: at 91.14% examples, 103925 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:39:45,858 : INFO : PROGRESS: at 91.40% examples, 103954 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:40:05,885 : INFO : PROGRESS: at 91.69% examples, 104015 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:40:06,889 : INFO : Loading new file for index: 1180000
# 2017-04-10 06:40:25,911 : INFO : PROGRESS: at 91.99% examples, 104092 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:40:45,936 : INFO : PROGRESS: at 92.30% examples, 104175 words/s, in_qsize 4, out_qsize 0
# 2017-04-10 06:40:58,156 : INFO : Loading new file for index: 1190000
# 2017-04-10 06:41:05,983 : INFO : PROGRESS: at 92.61% examples, 104274 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:41:26,054 : INFO : PROGRESS: at 92.92% examples, 104358 words/s, in_qsize 7, out_qsize 0
# 2017-04-10 06:41:46,146 : INFO : PROGRESS: at 93.25% examples, 104462 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:41:46,903 : INFO : Loading new file for index: 1200000
# 2017-04-10 06:42:17,305 : INFO : PROGRESS: at 93.53% examples, 104373 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:42:37,354 : INFO : PROGRESS: at 93.88% examples, 104497 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:42:45,785 : INFO : Loading new file for index: 1210000
# 2017-04-10 06:42:57,368 : INFO : PROGRESS: at 94.26% examples, 104665 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:43:17,385 : INFO : PROGRESS: at 94.62% examples, 104801 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:43:27,867 : INFO : Loading new file for index: 1220000
# 2017-04-10 06:43:37,402 : INFO : PROGRESS: at 94.98% examples, 104947 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:43:57,423 : INFO : PROGRESS: at 95.33% examples, 105081 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:44:12,288 : INFO : Loading new file for index: 1230000
# 2017-04-10 06:44:17,438 : INFO : PROGRESS: at 95.69% examples, 105227 words/s, in_qsize 8, out_qsize 0
# 2017-04-10 06:44:37,474 : INFO : PROGRESS: at 96.05% examples, 105372 words/s, in_qsize 15, out_qsize 0
# 2017-04-10 06:44:54,136 : INFO : Loading new file for index: 1240000
# 2017-04-10 06:44:57,499 : INFO : PROGRESS: at 96.43% examples, 105534 words/s, in_qsize 1, out_qsize 0
# 2017-04-10 06:45:17,525 : INFO : PROGRESS: at 96.80% examples, 105676 words/s, in_qsize 5, out_qsize 0
# 2017-04-10 06:45:37,037 : INFO : Loading new file for index: 1250000
# 2017-04-10 06:45:37,564 : INFO : PROGRESS: at 97.15% examples, 105804 words/s, in_qsize 3, out_qsize 0
# 2017-04-10 06:45:57,594 : INFO : PROGRESS: at 97.52% examples, 105944 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:46:17,615 : INFO : PROGRESS: at 97.88% examples, 106078 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:46:20,110 : INFO : Loading new file for index: 1260000
# 2017-04-10 06:46:37,628 : INFO : PROGRESS: at 98.25% examples, 106227 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:46:57,694 : INFO : PROGRESS: at 98.63% examples, 106372 words/s, in_qsize 0, out_qsize 0
# 2017-04-10 06:47:01,750 : INFO : Loading new file for index: 1270000
# 2017-04-10 06:47:17,706 : INFO : PROGRESS: at 99.01% examples, 106519 words/s, in_qsize 1, out_qsize 0
# 2017-04-10 06:47:37,721 : INFO : PROGRESS: at 99.39% examples, 106678 words/s, in_qsize 5, out_qsize 0
# 2017-04-10 06:47:42,834 : INFO : Loading new file for index: 1280000
# 2017-04-10 06:47:57,741 : INFO : PROGRESS: at 99.75% examples, 106822 words/s, in_qsize 5, out_qsize 0
# 2017-04-10 06:48:09,630 : INFO : Loading new file for index: 1290000
# 2017-04-10 06:48:09,691 : INFO : All files are loaded - last file: 1290000
# 2017-04-10 06:48:11,745 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2017-04-10 06:48:11,967 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-04-10 06:48:11,978 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-04-10 06:48:12,029 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-04-10 06:48:12,076 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-04-10 06:48:12,098 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-04-10 06:48:12,111 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-04-10 06:48:12,158 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-04-10 06:48:12,180 : INFO : training on 1393295375 raw words (899486202 effective words) took 8413.3s, 106912 effective words/s
# CPU times: user 2h 50min 27s, sys: 15min 52s, total: 3h 6min 19s
# 2017-04-10 06:48:14,241 : INFO : saving Doc2Vec object under /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_8/model, separately None
# 2017-04-10 06:48:14,776 : INFO : storing np array 'doctag_syn0' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_8/model.docvecs.doctag_syn0.npy
# 2017-04-10 07:04:27,791 : INFO : not storing attribute syn0norm
# 2017-04-10 07:04:27,811 : INFO : storing np array 'syn0' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_8/model.wv.syn0.npy
# 2017-04-10 07:04:28,112 : INFO : storing np array 'syn1neg' to /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_8/model.syn1neg.npy
# 2017-04-10 07:04:28,197 : INFO : not storing attribute cum_table
# 2017-04-10 07:42:02,865 : INFO : saved /mnt/data/shalaby/parameter_search_doc2vec_models_3_claims/full/doc2vec_size_200_w_2_type_dm_concat_0_mean_1_trainwords_0_hs_0_neg_10_vocabsize_None_model_3_claims/epoch_8/model
# 2017-04-10 07:42:02,866 : INFO : Getting Validation Embeddings
# 2017-04-10 07:42:02,867 : INFO : ===== Getting vectors with inference
# Wall time: 2h 20min 13s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b19de240424b> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'# when resuming, resume from an epoch with a previously created doc2vec model to get the learning rate right\nstart_from = 1\nfor epoch in range(start_from, DOC2VEC_MAX_EPOCHS+1):\n    GLOBAL_VARS.MODEL_NAME = placeholder_model_name.format(epoch)\n    info("****************** Epoch {} --- Working on {} *******************".format(epoch, GLOBAL_VARS.MODEL_NAME))\n    \n    # if we have the model, just load it, otherwise train the previous model\n    if os.path.exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX)):\n        doc2vec_model = Doc2Vec.load(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))\n        doc2vec_model.workers = NUM_CORES\n        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model\n    else:\n        # train the doc2vec model\n        training_docs_iterator = BatchWrapper(training_preprocessed_files_prefix, batch_size=10000, level=level,\n                                          level_type=model_name)\n        %time doc2vec_model.train(sentences=training_docs_iterator, report_delay=REPORT_DELAY)\n        doc2vec_model.alpha -= DOC2VEC_ALPHA_DECREASE  # decrease the learning rate\n        doc2vec_model.min_alpha = doc2vec_model.alpha  # fix the learning rate, no decay\n        ensure_disk_location_exists(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME))\n        doc2vec_model.save(os.path.join(doc2vec_model_save_location, GLOBAL_VARS.MODEL_NAME, MODEL_PREFIX))\n        GLOBAL_VARS.DOC2VEC_MODEL = doc2vec_model\n        \n    # only do the inference for higher epochs, as inference usually takes as much time as the actual training\n    if epoch > 7:\n        # Validation Embeddings\n        info(\'Getting Validation Embeddings\')\n        Xv = get_extended_docs_with_inference_data_only(doc2vec_model, VALIDATION_DICT, \n                                         validation_preprocessed_files_prefix)')
#
# /home/stud/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /home/stud/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/stud/shalaby/.virtualenv/thesis-env/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-12-c99b925f3377> in get_extended_docs_with_inference_data_only(doc2vec_model, file_to_write, preprocessed_files_prefix)
#      21         # Multi-threaded inference
#      22 #         inference_docs_iterator = ExtendedPVDocumentBatchGenerator(preprocessed_files_prefix, batch_size=None)
# ---> 23         inference_docs_iterator = BatchClass(preprocessed_files_prefix, batch_size=None)
#      24         generator_func = inference_docs_iterator.__iter__()
#      25         pool = ThreadPool(NUM_CORES)
#
# NameError: global name 'BatchClass' is not defined

# %%
NUM_CORES = 32

# %%
Xv = get_extended_docs_with_inference_data_only(doc2vec_model, VALIDATION_DICT, 
                                         validation_preprocessed_files_prefix)
# Out:
# 2017-04-09 00:47:30,381 : INFO : ===== Getting vectors with inference
# 2017-04-09 00:47:32,316 : INFO : Loading new file for index: 0
# 2017-04-09 00:48:09,470 : INFO : Finished: 100000 tags
# 2017-04-09 00:48:46,768 : INFO : Finished: 200000 tags
# 2017-04-09 00:49:24,072 : INFO : Finished: 300000 tags
# 2017-04-09 00:49:30,546 : INFO : Loading new file for index: 10000
# 2017-04-09 00:50:01,360 : INFO : Finished: 400000 tags
# 2017-04-09 00:50:39,518 : INFO : Finished: 500000 tags
# 2017-04-09 00:51:17,982 : INFO : Finished: 600000 tags
# 2017-04-09 00:51:31,647 : INFO : Loading new file for index: 20000
# 2017-04-09 00:51:56,195 : INFO : Finished: 700000 tags
# 2017-04-09 00:52:32,945 : INFO : Finished: 800000 tags
# 2017-04-09 00:53:10,328 : INFO : Finished: 900000 tags
# 2017-04-09 00:53:47,587 : INFO : Finished: 1000000 tags
# 2017-04-09 00:53:51,325 : INFO : Loading new file for index: 30000
# 2017-04-09 00:54:25,132 : INFO : Finished: 1100000 tags
# 2017-04-09 00:55:03,058 : INFO : Finished: 1200000 tags
# 2017-04-09 00:55:39,845 : INFO : Finished: 1300000 tags
# 2017-04-09 00:55:49,827 : INFO : Loading new file for index: 40000
# 2017-04-09 00:56:17,719 : INFO : Finished: 1400000 tags
# 2017-04-09 00:56:56,656 : INFO : Finished: 1500000 tags
# 2017-04-09 00:57:33,701 : INFO : Finished: 1600000 tags
# 2017-04-09 00:57:50,133 : INFO : Loading new file for index: 50000
# 2017-04-09 00:58:11,085 : INFO : Finished: 1700000 tags
# 2017-04-09 00:58:47,924 : INFO : Finished: 1800000 tags
# 2017-04-09 00:59:25,367 : INFO : Finished: 1900000 tags
# 2017-04-09 01:00:02,766 : INFO : Finished: 2000000 tags
# 2017-04-09 01:00:09,417 : INFO : Loading new file for index: 60000
# 2017-04-09 01:00:09,419 : INFO : All files are loaded - last file: 60000
# 2017-04-09 01:00:17,815 : INFO : Finished: 2100000 tags
# 2017-04-09 01:00:18,398 : INFO : Finished: 2200000 tags
